# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# /bin/bash: línea 1: /home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/.venv/bin/pip3: no se puede ejecutar: no se ha encontrado el fichero requerido

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                #,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=47815
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
len(train_loader.dataset)
# Out:
# 60000

# %%
len(train_loader)
# Out:
# 600

# %%
# 3.2)
train_iter = iter(train_loader)
images, labels = next(train_iter)
print(type(images))
print(images.shape)
print(labels.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([100, 1, 28, 28])
# torch.Size([100])

# %%
plt.imshow(images[1].squeeze(),cmap='Greys_r')

# %%
images[0].shape
# Out:
# torch.Size([1, 28, 28])

# %%
images[0].squeeze().shape
# Out:
# torch.Size([28, 28])

# %%
labels
# Out:
# tensor([8, 3, 1, 6, 5, 9, 2, 2, 5, 8, 9, 5, 4, 2, 6, 3, 7, 5, 8, 2, 3, 9, 4, 9,
#         5, 7, 9, 4, 0, 2, 4, 3, 5, 7, 9, 1, 5, 6, 5, 6, 0, 2, 9, 8, 2, 9, 3, 4,
#         2, 9, 5, 1, 3, 8, 0, 9, 4, 1, 7, 2, 4, 4, 8, 0, 2, 8, 2, 0, 9, 1, 6, 8,
#         3, 6, 7, 6, 7, 2, 7, 8, 8, 1, 5, 6, 3, 4, 2, 5, 0, 5, 4, 7, 0, 6, 8, 8,
#         8, 6, 1, 2])

# %%
labels.numpy()
# Out:
# array([8, 3, 1, 6, 5, 9, 2, 2, 5, 8, 9, 5, 4, 2, 6, 3, 7, 5, 8, 2, 3, 9,
#        4, 9, 5, 7, 9, 4, 0, 2, 4, 3, 5, 7, 9, 1, 5, 6, 5, 6, 0, 2, 9, 8,
#        2, 9, 3, 4, 2, 9, 5, 1, 3, 8, 0, 9, 4, 1, 7, 2, 4, 4, 8, 0, 2, 8,
#        2, 0, 9, 1, 6, 8, 3, 6, 7, 6, 7, 2, 7, 8, 8, 1, 5, 6, 3, 4, 2, 5,
#        0, 5, 4, 7, 0, 6, 8, 8, 8, 6, 1, 2])

# %%
labels.numpy().shape
# Out:
# (100,)

# %%
labels[0]
# Out:
# tensor(8)

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
# 4)
class Clasificadora(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1),  # (1, 28, 28) -> (32, 28, 28)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (32, 28, 28) -> (32, 14, 14)
            nn.Dropout(0.2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),  # (32, 14, 14) -> (64, 14, 14)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (64, 14, 14) -> (64, 7, 7)
        )
        
        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),
            
            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Capa 2
            nn.Linear(in_features = 512, out_features = 256),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Capa 3
            nn.Linear(in_features = 256, out_features = 10)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
model = Clasificadora()

# %%
# 5.6)
learning_rate = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# 5.8) y 5.9)
import torch
import json
import os

# Crear carpeta de resultados si no existe
os.makedirs("resultados", exist_ok=True)

num_epochs = 40

list_avg_train_loss_incorrecta = []
list_avg_train_loss = []
list_avg_valid_loss = []
list_train_precision_incorrecta = []
list_train_precision = []
list_valid_precision = []

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}\n-------------------------------')

    train_avg_loss_incorrecta, train_precision_incorrecta = train_loop(
        train_loader, model, loss_fn, optimizer
    )

    train_avg_loss, train_precision = eval_loop(
        train_loader, model, loss_fn
    )

    valid_avg_loss, valid_precision = eval_loop(
        valid_loader, model, loss_fn
    )

    list_avg_train_loss_incorrecta.append(train_avg_loss_incorrecta)
    list_avg_train_loss.append(train_avg_loss)
    list_avg_valid_loss.append(valid_avg_loss)
    list_train_precision_incorrecta.append(train_precision_incorrecta)
    list_train_precision.append(train_precision)
    list_valid_precision.append(valid_precision)

print("Done!")


# ===============================================================
#          🔥 GUARDAR MODELO Y MÉTRICAS (FORMATO EXPERIMENTOS)
# ===============================================================

# 1) Guardar sólo pesos del modelo
model_path = "resultados/modelo.pt"
torch.save(model.state_dict(), model_path)

# 1b) Guardar checkpoint completo (pesos + optimizador + config)
checkpoint_path = "resultados/checkpoint.pt"
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": {
        "num_epochs": num_epochs,
        "learning_rate": learning_rate,
        "batch_size": batch_size
    }
}, checkpoint_path)

# 2) Guardar métricas
metrics_path = "resultados/metricas.pt"
torch.save({
    "train_loss_incorrecta": list_avg_train_loss_incorrecta,
    "train_loss": list_avg_train_loss,
    "valid_loss": list_avg_valid_loss,
    "train_precision_incorrecta": list_train_precision_incorrecta,
    "train_precision": list_train_precision,
    "valid_precision": list_valid_precision,
    "num_epochs": num_epochs
}, metrics_path)

# 3) Guardar JSON con resumen
resumen = {
    "final_train_precision": list_train_precision[-1],
    "final_valid_precision": list_valid_precision[-1],
    "final_valid_loss": list_avg_valid_loss[-1],
    "model_path": model_path,
    "checkpoint_path": checkpoint_path,
    "metrics_path": metrics_path
}

json_path = "resultados/resumen.json"
with open(json_path, "w") as f:
    json.dump(resumen, f, indent=4)

print("✔ Modelo guardado en:", model_path)
print("✔ Checkpoint guardado en:", checkpoint_path)
print("✔ Métricas guardadas en:", metrics_path)
print("✔ Resumen guardado en:", json_path)
# Out:
# Epoch 1
# -------------------------------
# @train_loop batch=    0 avrg_loss=2.299929 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.119421 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.881853 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.777453 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.709595 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.661021 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.624819 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.595478 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.572789 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.552827 processed samples= 90.2%
# @eval_loop avg_loss=0.336905 precision=87.4%
# @eval_loop avg_loss=0.365159 precision=86.5%
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.431762 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.363950 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.356407 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.354114 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.349151 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.339759 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.335644 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.331290 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.328761 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.325980 processed samples= 90.2%
# @eval_loop avg_loss=0.273797 precision=89.9%
# @eval_loop avg_loss=0.311803 precision=88.6%
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.191786 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.271116 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.271109 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.273378 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.276073 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.278218 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.278359 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.278547 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.277990 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.276038 processed samples= 90.2%
# @eval_loop avg_loss=0.214871 precision=92.0%
# @eval_loop avg_loss=0.263608 precision=90.2%
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.217380 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.255084 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.252382 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.252296 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.248630 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.251482 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.250723 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.249114 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.249013 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.248757 processed samples= 90.2%
# @eval_loop avg_loss=0.189166 precision=93.0%
# @eval_loop avg_loss=0.243389 precision=91.0%
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.167830 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.233472 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.230942 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.223943 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.226694 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.225773 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.224684 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.223827 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.222520 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.221767 processed samples= 90.2%
# @eval_loop avg_loss=0.200833 precision=92.6%
# @eval_loop avg_loss=0.270129 precision=90.6%
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.311869 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.198204 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.195406 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.195320 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.193475 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.198628 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.199289 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.198332 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.200408 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.201184 processed samples= 90.2%
# @eval_loop avg_loss=0.151482 precision=94.7%
# @eval_loop avg_loss=0.220374 precision=92.0%
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.147822 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.183883 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.187132 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.188141 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.185663 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.183107 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.183516 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.183646 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.182889 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.182753 processed samples= 90.2%
# @eval_loop avg_loss=0.137089 precision=94.9%
# @eval_loop avg_loss=0.219300 precision=92.2%
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.121155 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.166434 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.165944 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.164950 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.165488 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.165478 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.165153 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.165412 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.166321 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.167675 processed samples= 90.2%
# @eval_loop avg_loss=0.120208 precision=95.7%
# @eval_loop avg_loss=0.213957 precision=92.4%
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.113453 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.143679 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.147624 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.151817 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.152115 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.151542 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.150432 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.150428 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.152081 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.153643 processed samples= 90.2%
# @eval_loop avg_loss=0.106884 precision=96.2%
# @eval_loop avg_loss=0.212764 precision=92.4%
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.146604 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.130413 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.130804 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.129811 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.130818 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.135827 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.138472 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.140779 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.142216 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.143641 processed samples= 90.2%
# @eval_loop avg_loss=0.113299 precision=95.7%
# @eval_loop avg_loss=0.253889 precision=92.0%
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.113683 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.123941 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.126768 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.125376 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.124488 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.127906 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.129194 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.130323 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.130368 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.130625 processed samples= 90.2%
# @eval_loop avg_loss=0.085698 precision=96.9%
# @eval_loop avg_loss=0.232921 precision=92.3%
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.099005 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.112397 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.112994 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.112864 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.116130 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.117158 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.117723 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.118450 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.120679 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.121390 processed samples= 90.2%
# @eval_loop avg_loss=0.075391 precision=97.3%
# @eval_loop avg_loss=0.224163 precision=92.5%
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.075146 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.102930 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.103991 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.106289 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.107899 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.107921 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.107891 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.106712 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.108512 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.109882 processed samples= 90.2%
# @eval_loop avg_loss=0.077860 precision=97.3%
# @eval_loop avg_loss=0.245042 precision=92.1%
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.073542 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.109045 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.104462 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.104377 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.106242 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.106298 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.105812 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.105160 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.105175 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.105402 processed samples= 90.2%
# @eval_loop avg_loss=0.063018 precision=97.6%
# @eval_loop avg_loss=0.253490 precision=92.5%
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.076270 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.097267 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.094078 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.093190 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.093989 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.095164 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.098079 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.098757 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.098730 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.099272 processed samples= 90.2%
# @eval_loop avg_loss=0.050032 precision=98.2%
# @eval_loop avg_loss=0.243033 precision=92.6%
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.040261 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.077696 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.081990 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.081478 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.083785 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.083986 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.086331 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.086621 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.086718 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.087275 processed samples= 90.2%
# @eval_loop avg_loss=0.046129 precision=98.4%
# @eval_loop avg_loss=0.266380 precision=92.7%
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.101830 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.076645 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.079497 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.076874 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.078413 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.078968 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.080666 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.083000 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.081509 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.082767 processed samples= 90.2%
# @eval_loop avg_loss=0.040003 precision=98.6%
# @eval_loop avg_loss=0.271585 precision=92.6%
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.051067 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.071790 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.075152 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.076886 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.077406 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.076281 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.076358 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.075933 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.075515 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.076959 processed samples= 90.2%
# @eval_loop avg_loss=0.038810 precision=98.6%
# @eval_loop avg_loss=0.304738 precision=92.6%
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.077069 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.062773 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.067483 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.069283 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.071658 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.072637 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.072859 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.073802 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.074757 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.074061 processed samples= 90.2%
# @eval_loop avg_loss=0.032761 precision=98.9%
# @eval_loop avg_loss=0.287165 precision=92.9%
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.031716 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.067081 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.068427 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.066025 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.068750 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.069187 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.069417 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.071123 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.071228 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.071697 processed samples= 90.2%
# @eval_loop avg_loss=0.035629 precision=98.9%
# @eval_loop avg_loss=0.287427 precision=92.2%
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.019400 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.066061 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.063773 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.064519 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.064751 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.066249 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.067183 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.067013 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.067282 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.067527 processed samples= 90.2%
# @eval_loop avg_loss=0.028487 precision=99.0%
# @eval_loop avg_loss=0.307485 precision=93.0%
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.037884 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.054730 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.057111 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.063148 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.066080 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.067935 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.066976 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.066005 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.064838 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.064761 processed samples= 90.2%
# @eval_loop avg_loss=0.028128 precision=99.0%
# @eval_loop avg_loss=0.325917 precision=92.6%
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.056632 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.061889 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.057708 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.057985 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.059757 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.059288 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.058242 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.059075 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.059311 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.058993 processed samples= 90.2%
# @eval_loop avg_loss=0.023419 precision=99.3%
# @eval_loop avg_loss=0.306981 precision=92.7%
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.062990 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.063192 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.063725 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.062785 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.060369 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.059221 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.057283 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.057706 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.058536 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.059086 processed samples= 90.2%
# @eval_loop avg_loss=0.026160 precision=99.1%
# @eval_loop avg_loss=0.346022 precision=92.4%
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.036029 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.051572 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.051961 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.051325 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.053629 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.054560 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.054238 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.055087 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.056023 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.057081 processed samples= 90.2%
# @eval_loop avg_loss=0.020988 precision=99.3%
# @eval_loop avg_loss=0.310647 precision=92.8%
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.104449 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.044545 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.042820 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.047330 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.048358 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.047879 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.048029 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.049305 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.049545 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.051187 processed samples= 90.2%
# @eval_loop avg_loss=0.024988 precision=99.1%
# @eval_loop avg_loss=0.363714 precision=92.5%
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.043643 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.047150 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.048560 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.051264 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.050136 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.049180 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.050258 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.050906 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.051595 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.051926 processed samples= 90.2%
# @eval_loop avg_loss=0.022366 precision=99.3%
# @eval_loop avg_loss=0.338783 precision=92.5%
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.046281 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.050202 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.044292 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.047106 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.048303 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.046510 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.046776 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.047446 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.047916 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.048879 processed samples= 90.2%
# @eval_loop avg_loss=0.014423 precision=99.6%
# @eval_loop avg_loss=0.326493 precision=92.6%
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.109534 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.045093 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.046062 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.047562 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.049860 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.047931 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.047376 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.049949 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.049606 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.049546 processed samples= 90.2%
# @eval_loop avg_loss=0.014207 precision=99.6%
# @eval_loop avg_loss=0.322852 precision=92.7%
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.079471 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.049448 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.046112 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044611 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.045022 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.046060 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.047693 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.047777 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.047925 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.047439 processed samples= 90.2%
# @eval_loop avg_loss=0.011979 precision=99.6%
# @eval_loop avg_loss=0.359623 precision=92.9%
# Epoch 31
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.044165 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.044033 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043779 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044790 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.045620 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.045251 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045030 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.045080 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.045524 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.045402 processed samples= 90.2%
# @eval_loop avg_loss=0.012331 precision=99.6%
# @eval_loop avg_loss=0.370511 precision=92.8%
# Epoch 32
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.057380 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.040462 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.039718 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044039 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.043645 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.043196 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.042843 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.043166 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.043571 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.044562 processed samples= 90.2%
# @eval_loop avg_loss=0.013981 precision=99.6%
# @eval_loop avg_loss=0.364514 precision=92.6%
# Epoch 33
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.010975 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.039992 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.038467 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.038234 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.040120 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.041838 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.042408 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.042226 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.041989 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.042358 processed samples= 90.2%
# @eval_loop avg_loss=0.014003 precision=99.6%
# @eval_loop avg_loss=0.355604 precision=92.4%
# Epoch 34
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.025265 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.044958 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043728 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.043662 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.043299 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.045215 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.044666 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.044700 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.044581 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.043823 processed samples= 90.2%
# @eval_loop avg_loss=0.013171 precision=99.6%
# @eval_loop avg_loss=0.365013 precision=92.5%
# Epoch 35
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.017265 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.038712 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.040312 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.041065 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.039984 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039190 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.040280 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.040910 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.040189 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.039748 processed samples= 90.2%
# @eval_loop avg_loss=0.012750 precision=99.6%
# @eval_loop avg_loss=0.407346 precision=92.5%
# Epoch 36
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.020535 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.032169 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.038421 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.038679 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.040432 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.040735 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.041526 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.041080 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.040951 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.040702 processed samples= 90.2%
# @eval_loop avg_loss=0.010214 precision=99.8%
# @eval_loop avg_loss=0.351473 precision=92.6%
# Epoch 37
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.035510 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.035577 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.037195 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.038049 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.036873 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.037632 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.037309 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.036874 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.037509 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.038239 processed samples= 90.2%
# @eval_loop avg_loss=0.008400 precision=99.8%
# @eval_loop avg_loss=0.365631 precision=92.5%
# Epoch 38
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.004007 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.028641 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.035993 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.038459 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.038160 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039271 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.038125 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.037964 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.038602 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.039291 processed samples= 90.2%
# @eval_loop avg_loss=0.006862 precision=99.9%
# @eval_loop avg_loss=0.379255 precision=92.6%
# Epoch 39
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.024059 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.034787 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.036636 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.037360 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.037977 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.037281 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.037431 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.038694 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.039441 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.039912 processed samples= 90.2%
# @eval_loop avg_loss=0.006691 precision=99.8%
# @eval_loop avg_loss=0.399697 precision=92.7%
# Epoch 40
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.010977 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.031037 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.030676 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.033706 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.035472 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.036652 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.035973 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.035853 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.036319 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.036836 processed samples= 90.2%
# @eval_loop avg_loss=0.007739 precision=99.8%
# @eval_loop avg_loss=0.370401 precision=92.7%
# Done!
# ✔ Modelo guardado en: resultados/modelo.pt
# ✔ Checkpoint guardado en: resultados/checkpoint.pt
# ✔ Métricas guardadas en: resultados/metricas.pt
# ✔ Resumen guardado en: resultados/resumen.json

# %%
# 5.10)
import matplotlib.pyplot as plt
import os

# Crear carpeta si no existe
os.makedirs("resultados", exist_ok=True)

plt.figure(figsize=(10, 6))

# Colores y estilos (coherentes con el gráfico comparativo)
plt.plot(
    range(1, len(list_avg_train_loss_incorrecta) + 1),
    list_avg_train_loss_incorrecta,
    linestyle=":",
    color="tab:red",
    label="Train loss incorrecta"
)

plt.plot(
    range(1, len(list_avg_train_loss) + 1),
    list_avg_train_loss,
    linestyle="--",
    color="tab:green",
    label="Train loss"
)

plt.plot(
    range(1, len(list_avg_valid_loss) + 1),
    list_avg_valid_loss,
    linestyle="-",
    color="tab:blue",
    label="Valid loss"
)

plt.title("Evolución del Loss – Entrenamiento completo sin pre-entrenamiento ")
plt.xlabel("Epoch")
plt.ylabel("Loss (Cross Entropy)")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Guardar el gráfico
plt.savefig("resultados/loss.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en resultados/loss.png")
# Out:
# ✔ Gráfico guardado en resultados/loss.png

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("resultados", exist_ok=True)

plt.figure(figsize=(10, 6))

# Línea objetivo
plt.axhline(y=0.9, color="grey", linestyle="--")

# Colores tabulados (consistentes)
plt.plot(
    range(1, len(list_train_precision_incorrecta) + 1),
    list_train_precision_incorrecta,
    linestyle=":",
    color="tab:red",
    label="Train accuracy incorrecta"
)

plt.plot(
    range(1, len(list_train_precision) + 1),
    list_train_precision,
    linestyle="--",
    color="tab:green",
    label="Train accuracy"
)

plt.plot(
    range(1, len(list_valid_precision) + 1),
    list_valid_precision,
    linestyle="-",
    color="tab:blue",
    label="Valid accuracy"
)

plt.title("Evolución de Accuracy – Entrenamiento completo sin pre-entrenamiento")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim(-0.1, len(list_valid_precision) + 0.1)
plt.ylim(0.7, 1.0)

plt.legend()
plt.grid(True)
plt.tight_layout()

save_path = "resultados/accuracy.png"
plt.savefig(save_path, dpi=300)
plt.show()

print("✔ Gráfico de accuracy guardado en:", save_path)
# Out:
# ✔ Gráfico de accuracy guardado en: resultados/accuracy.png

# %%
import torch
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------------------------------------
#   1) Cargar el modelo entrenado
# ---------------------------------------------------------
model_path = "resultados/modelo.pt"

clasificador = model.to(device)
clasificador.load_state_dict(torch.load(model_path, map_location=device))
clasificador.eval()

print("✔ Modelo cargado desde:", model_path)

# ---------------------------------------------------------
#   2) Obtener predicciones sobre conjunto VALID
# ---------------------------------------------------------
y_true = []
y_pred = []

with torch.no_grad():
    for x, labels in valid_loader:
        x, labels = x.to(device), labels.to(device)

        outputs = clasificador(x)
        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ---------------------------------------------------------
#   3) Matriz de confusión
# ---------------------------------------------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")

plt.title("Matriz de Confusión – Entrenamiento completo sin pre-entrenamiento")
plt.tight_layout()

out_png = "resultados/matriz_confusion_5_11.png"
plt.savefig(out_png, dpi=300)
plt.show()

print("✔ Matriz de confusión guardada en:", out_png)
# Out:
# ✔ Modelo cargado desde: resultados/modelo.pt
# ✔ Matriz de confusión guardada en: resultados/matriz_confusion_5_11.png
