# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# /bin/bash: línea 1: /home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/.venv/bin/pip3: no se puede ejecutar: no se ha encontrado el fichero requerido

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                ,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=438
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
len(train_loader.dataset)
# Out:
# 60000

# %%
len(train_loader)
# Out:
# 600

# %%
# 3.2)
train_iter = iter(train_loader)
images, labels = next(train_iter)
print(type(images))
print(images.shape)
print(labels.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([100, 1, 28, 28])
# torch.Size([100])

# %%
plt.imshow(images[1].squeeze(),cmap='Greys_r')

# %%
images[0].shape
# Out:
# torch.Size([1, 28, 28])

# %%
images[0].squeeze().shape
# Out:
# torch.Size([28, 28])

# %%
labels
# Out:
# tensor([1, 8, 3, 3, 8, 4, 4, 0, 5, 0, 0, 8, 2, 3, 9, 7, 3, 4, 1, 0, 2, 2, 0, 7,
#         8, 7, 9, 1, 5, 5, 6, 9, 7, 4, 1, 4, 1, 4, 9, 9, 2, 3, 7, 8, 1, 4, 7, 1,
#         3, 8, 5, 3, 2, 5, 1, 5, 0, 2, 2, 7, 9, 0, 7, 8, 4, 4, 1, 8, 0, 9, 4, 2,
#         3, 6, 1, 4, 7, 1, 6, 1, 1, 5, 3, 2, 1, 1, 5, 5, 3, 5, 4, 9, 4, 3, 9, 9,
#         3, 1, 6, 3])

# %%
labels.numpy()
# Out:
# array([1, 8, 3, 3, 8, 4, 4, 0, 5, 0, 0, 8, 2, 3, 9, 7, 3, 4, 1, 0, 2, 2,
#        0, 7, 8, 7, 9, 1, 5, 5, 6, 9, 7, 4, 1, 4, 1, 4, 9, 9, 2, 3, 7, 8,
#        1, 4, 7, 1, 3, 8, 5, 3, 2, 5, 1, 5, 0, 2, 2, 7, 9, 0, 7, 8, 4, 4,
#        1, 8, 0, 9, 4, 2, 3, 6, 1, 4, 7, 1, 6, 1, 1, 5, 3, 2, 1, 1, 5, 5,
#        3, 5, 4, 9, 4, 3, 9, 9, 3, 1, 6, 3])

# %%
labels.numpy().shape
# Out:
# (100,)

# %%
labels[0]
# Out:
# tensor(1)

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
# 4)
class Clasificadora(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1),  # (1, 28, 28) -> (32, 28, 28)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (32, 28, 28) -> (32, 14, 14)
            nn.Dropout(0.2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),  # (32, 14, 14) -> (64, 14, 14)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),  # (64, 14, 14) -> (64, 7, 7)
        )

        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),
            
            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Capa 2
            nn.Linear(in_features = 256, out_features = 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Capa 2
            nn.Linear(in_features = 128, out_features = 64),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Capa 3
            nn.Linear(in_features = 64, out_features = 10)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
model = Clasificadora()

# %%
# 5.6)
learning_rate = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# 5.8) y 5.9)
import torch
import json
import os

# Crear carpeta de resultados si no existe
os.makedirs("resultados", exist_ok=True)

num_epochs = 60

list_avg_train_loss_incorrecta = []
list_avg_train_loss = []
list_avg_valid_loss = []
list_train_precision_incorrecta = []
list_train_precision = []
list_valid_precision = []

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}\n-------------------------------')

    train_avg_loss_incorrecta, train_precision_incorrecta = train_loop(
        train_loader, model, loss_fn, optimizer
    )

    train_avg_loss, train_precision = eval_loop(
        train_loader, model, loss_fn
    )

    valid_avg_loss, valid_precision = eval_loop(
        valid_loader, model, loss_fn
    )

    list_avg_train_loss_incorrecta.append(train_avg_loss_incorrecta)
    list_avg_train_loss.append(train_avg_loss)
    list_avg_valid_loss.append(valid_avg_loss)
    list_train_precision_incorrecta.append(train_precision_incorrecta)
    list_train_precision.append(train_precision)
    list_valid_precision.append(valid_precision)

print("Done!")


# ===============================================================
#          🔥 GUARDAR MODELO Y MÉTRICAS (FORMATO EXPERIMENTOS)
# ===============================================================

# 1) Guardar sólo pesos del modelo
model_path = "resultados/modelo.pt"
torch.save(model.state_dict(), model_path)

# 1b) Guardar checkpoint completo (pesos + optimizador + config)
checkpoint_path = "resultados/checkpoint.pt"
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": {
        "num_epochs": num_epochs,
        "learning_rate": learning_rate,
        "batch_size": batch_size
    }
}, checkpoint_path)

# 2) Guardar métricas
metrics_path = "resultados/metricas.pt"
torch.save({
    "train_loss_incorrecta": list_avg_train_loss_incorrecta,
    "train_loss": list_avg_train_loss,
    "valid_loss": list_avg_valid_loss,
    "train_precision_incorrecta": list_train_precision_incorrecta,
    "train_precision": list_train_precision,
    "valid_precision": list_valid_precision,
    "num_epochs": num_epochs
}, metrics_path)

# 3) Guardar JSON con resumen
resumen = {
    "final_train_precision": list_train_precision[-1],
    "final_valid_precision": list_valid_precision[-1],
    "final_valid_loss": list_avg_valid_loss[-1],
    "model_path": model_path,
    "checkpoint_path": checkpoint_path,
    "metrics_path": metrics_path
}

json_path = "resultados/resumen.json"
with open(json_path, "w") as f:
    json.dump(resumen, f, indent=4)

print("✔ Modelo guardado en:", model_path)
print("✔ Checkpoint guardado en:", checkpoint_path)
print("✔ Métricas guardadas en:", metrics_path)
print("✔ Resumen guardado en:", json_path)
# Out:
# Epoch 1
# -------------------------------
# @train_loop batch=    0 avrg_loss=2.297493 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.319280 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=1.319280 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=1.031730 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=1.031730 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.902927 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.902927 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.826348 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.826348 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.770073 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.770073 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.721752 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.721752 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.686339 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.686339 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.656911 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.656911 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.633348 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.633348 processed samples= 90.2%
# @eval_loop avg_loss=0.362506 precision=86.3%
# @eval_loop avg_loss=0.362506 precision=86.3%
# @eval_loop avg_loss=0.384235 precision=85.5%
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.429386 processed samples=  0.2%
# @eval_loop avg_loss=0.384235 precision=85.5%
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.429386 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.407291 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.407291 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.402998 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.402998 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.397936 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.397936 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.386301 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.386301 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.383845 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.383845 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.379068 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.379068 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.375930 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.375930 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.375109 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.375109 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.371808 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.371808 processed samples= 90.2%
# @eval_loop avg_loss=0.267580 precision=90.3%
# @eval_loop avg_loss=0.267580 precision=90.3%
# @eval_loop avg_loss=0.303699 precision=88.9%
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.149967 processed samples=  0.2%
# @eval_loop avg_loss=0.303699 precision=88.9%
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.149967 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.325252 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.325252 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.328232 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.328232 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.324573 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.324573 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.319618 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.319618 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.321194 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.321194 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.319235 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.319235 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.316518 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.316518 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.316574 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.316574 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.315871 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.315871 processed samples= 90.2%
# @eval_loop avg_loss=0.253299 precision=90.6%
# @eval_loop avg_loss=0.253299 precision=90.6%
# @eval_loop avg_loss=0.295855 precision=89.3%
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.317727 processed samples=  0.2%
# @eval_loop avg_loss=0.295855 precision=89.3%
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.317727 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.279844 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.279844 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.289197 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.289197 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.289563 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.289563 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.289033 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.289033 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.287092 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.287092 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.284321 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.284321 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.284798 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.284798 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.281062 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.281062 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.280689 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.280689 processed samples= 90.2%
# @eval_loop avg_loss=0.224241 precision=92.1%
# @eval_loop avg_loss=0.224241 precision=92.1%
# @eval_loop avg_loss=0.269635 precision=90.3%
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.268271 processed samples=  0.2%
# @eval_loop avg_loss=0.269635 precision=90.3%
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.268271 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.248514 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.248514 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.247823 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.247823 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.248877 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.248877 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.247906 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.247906 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.247192 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.247192 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.247932 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.247932 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.249930 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.249930 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.249501 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.249501 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.250509 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.250509 processed samples= 90.2%
# @eval_loop avg_loss=0.184936 precision=93.0%
# @eval_loop avg_loss=0.184936 precision=93.0%
# @eval_loop avg_loss=0.248135 precision=90.9%
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.273648 processed samples=  0.2%
# @eval_loop avg_loss=0.248135 precision=90.9%
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.273648 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.241555 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.241555 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.238447 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.238447 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.238919 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.238919 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.235989 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.235989 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.233522 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.233522 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.233686 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.233686 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.232716 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.232716 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.231155 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.231155 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.229948 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.229948 processed samples= 90.2%
# @eval_loop avg_loss=0.173561 precision=93.6%
# @eval_loop avg_loss=0.173561 precision=93.6%
# @eval_loop avg_loss=0.241322 precision=91.0%
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.234695 processed samples=  0.2%
# @eval_loop avg_loss=0.241322 precision=91.0%
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.234695 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.213897 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.213897 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.210481 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.210481 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.209764 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.209764 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.206023 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.206023 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.206928 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.206928 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.211091 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.211091 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.213414 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.213414 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.214057 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.214057 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.214739 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.214739 processed samples= 90.2%
# @eval_loop avg_loss=0.164934 precision=93.7%
# @eval_loop avg_loss=0.164934 precision=93.7%
# @eval_loop avg_loss=0.254789 precision=91.1%
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.139431 processed samples=  0.2%
# @eval_loop avg_loss=0.254789 precision=91.1%
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.139431 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.177637 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.177637 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.186023 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.186023 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.189270 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.189270 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.193205 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.193205 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.195414 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.195414 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.195085 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.195085 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.195263 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.195263 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.194723 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.194723 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.196268 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.196268 processed samples= 90.2%
# @eval_loop avg_loss=0.139959 precision=94.8%
# @eval_loop avg_loss=0.139959 precision=94.8%
# @eval_loop avg_loss=0.227351 precision=91.9%
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.193802 processed samples=  0.2%
# @eval_loop avg_loss=0.227351 precision=91.9%
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.193802 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.197480 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.197480 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.188888 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.188888 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.189527 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.189527 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.186287 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.186287 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.185572 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.185572 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.187124 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.187124 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.187101 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.187101 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.186172 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.186172 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.184992 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.184992 processed samples= 90.2%
# @eval_loop avg_loss=0.142470 precision=94.7%
# @eval_loop avg_loss=0.142470 precision=94.7%
# @eval_loop avg_loss=0.232689 precision=91.5%
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.152051 processed samples=  0.2%
# @eval_loop avg_loss=0.232689 precision=91.5%
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.152051 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.159301 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.159301 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.163655 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.163655 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.168585 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.168585 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.169407 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.169407 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.170040 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.170040 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.170343 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.170343 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.170770 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.170770 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.173172 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.173172 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.173112 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.173112 processed samples= 90.2%
# @eval_loop avg_loss=0.116607 precision=95.7%
# @eval_loop avg_loss=0.116607 precision=95.7%
# @eval_loop avg_loss=0.224963 precision=92.3%
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.168579 processed samples=  0.2%
# @eval_loop avg_loss=0.224963 precision=92.3%
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.168579 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.158109 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.158109 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.155851 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.155851 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.156624 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.156624 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.157335 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.157335 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.159150 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.159150 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.161142 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.161142 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.160390 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.160390 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.161217 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.161217 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.161275 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.161275 processed samples= 90.2%
# @eval_loop avg_loss=0.111577 precision=95.7%
# @eval_loop avg_loss=0.111577 precision=95.7%
# @eval_loop avg_loss=0.237786 precision=92.2%
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.154362 processed samples=  0.2%
# @eval_loop avg_loss=0.237786 precision=92.2%
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.154362 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.152317 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.152317 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.147344 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.147344 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.143688 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.143688 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.145510 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.145510 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.149356 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.149356 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.147968 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.147968 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.149189 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.149189 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.150204 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.150204 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.150022 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.150022 processed samples= 90.2%
# @eval_loop avg_loss=0.093276 precision=96.7%
# @eval_loop avg_loss=0.093276 precision=96.7%
# @eval_loop avg_loss=0.228246 precision=92.7%
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.256130 processed samples=  0.2%
# @eval_loop avg_loss=0.228246 precision=92.7%
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.256130 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.134152 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.134152 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.141238 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.141238 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.142835 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.142835 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.143261 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.143261 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.144334 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.144334 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.144734 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.144734 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.147078 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.147078 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.145499 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.145499 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.147274 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.147274 processed samples= 90.2%
# @eval_loop avg_loss=0.100216 precision=96.4%
# @eval_loop avg_loss=0.100216 precision=96.4%
# @eval_loop avg_loss=0.249617 precision=92.0%
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.143478 processed samples=  0.2%
# @eval_loop avg_loss=0.249617 precision=92.0%
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.143478 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.134534 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.134534 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.131160 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.131160 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.134662 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.134662 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.133097 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.133097 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.129619 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.129619 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.132644 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.132644 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.133524 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.133524 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.135235 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.135235 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.136511 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.136511 processed samples= 90.2%
# @eval_loop avg_loss=0.084812 precision=96.9%
# @eval_loop avg_loss=0.084812 precision=96.9%
# @eval_loop avg_loss=0.240658 precision=92.5%
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.089029 processed samples=  0.2%
# @eval_loop avg_loss=0.240658 precision=92.5%
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.089029 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.115567 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.115567 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.114530 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.114530 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.118717 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.118717 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.122757 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.122757 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.124580 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.124580 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.124397 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.124397 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.126505 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.126505 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.126945 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.126945 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.128616 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.128616 processed samples= 90.2%
# @eval_loop avg_loss=0.086167 precision=96.9%
# @eval_loop avg_loss=0.086167 precision=96.9%
# @eval_loop avg_loss=0.240722 precision=92.3%
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.072908 processed samples=  0.2%
# @eval_loop avg_loss=0.240722 precision=92.3%
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.072908 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.120089 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.120089 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.118578 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.118578 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.121440 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.121440 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.120618 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.120618 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.120278 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.120278 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.121796 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.121796 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.121517 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.121517 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.123428 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.123428 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.123299 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.123299 processed samples= 90.2%
# @eval_loop avg_loss=0.068684 precision=97.6%
# @eval_loop avg_loss=0.068684 precision=97.6%
# @eval_loop avg_loss=0.235540 precision=92.9%
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.047837 processed samples=  0.2%
# @eval_loop avg_loss=0.235540 precision=92.9%
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.047837 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.112147 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.112147 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.114950 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.114950 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.119573 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.119573 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.120120 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.120120 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.117715 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.117715 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.119626 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.119626 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.121984 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.121984 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.122005 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.122005 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.120700 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.120700 processed samples= 90.2%
# @eval_loop avg_loss=0.064060 precision=97.7%
# @eval_loop avg_loss=0.064060 precision=97.7%
# @eval_loop avg_loss=0.242073 precision=92.5%
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.129855 processed samples=  0.2%
# @eval_loop avg_loss=0.242073 precision=92.5%
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.129855 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.111995 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.111995 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.110504 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.110504 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.112025 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.112025 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.112068 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.112068 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.110174 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.110174 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.111226 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.111226 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.110502 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.110502 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.112373 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.112373 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.111282 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.111282 processed samples= 90.2%
# @eval_loop avg_loss=0.065272 precision=97.6%
# @eval_loop avg_loss=0.065272 precision=97.6%
# @eval_loop avg_loss=0.247776 precision=92.5%
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.054828 processed samples=  0.2%
# @eval_loop avg_loss=0.247776 precision=92.5%
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.054828 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.107905 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.107905 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.111047 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.111047 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.112227 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.112227 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.110401 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.110401 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.108433 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.108433 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.108379 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.108379 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.109016 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.109016 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.109474 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.109474 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.109723 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.109723 processed samples= 90.2%
# @eval_loop avg_loss=0.062403 precision=97.8%
# @eval_loop avg_loss=0.062403 precision=97.8%
# @eval_loop avg_loss=0.246448 precision=92.3%
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.038894 processed samples=  0.2%
# @eval_loop avg_loss=0.246448 precision=92.3%
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.038894 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.091426 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.091426 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.094982 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.094982 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.095285 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.095285 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.095000 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.095000 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.096646 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.096646 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.098804 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.098804 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.099110 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.099110 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.099463 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.099463 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.101530 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.101530 processed samples= 90.2%
# @eval_loop avg_loss=0.052476 precision=98.2%
# @eval_loop avg_loss=0.052476 precision=98.2%
# @eval_loop avg_loss=0.263607 precision=92.2%
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.101140 processed samples=  0.2%
# @eval_loop avg_loss=0.263607 precision=92.2%
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.101140 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.098175 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.098175 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.097743 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.097743 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.097625 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.097625 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.098262 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.098262 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.095918 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.095918 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.096464 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.096464 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.097007 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.097007 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.098402 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.098402 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.099357 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.099357 processed samples= 90.2%
# @eval_loop avg_loss=0.048674 precision=98.3%
# @eval_loop avg_loss=0.048674 precision=98.3%
# @eval_loop avg_loss=0.277306 precision=92.4%
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.067497 processed samples=  0.2%
# @eval_loop avg_loss=0.277306 precision=92.4%
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.067497 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.081288 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.081288 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.085914 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.085914 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.088600 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.088600 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.089961 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.089961 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.092138 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.092138 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.093147 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.093147 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.095533 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.095533 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.095097 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.095097 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.094970 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.094970 processed samples= 90.2%
# @eval_loop avg_loss=0.048100 precision=98.5%
# @eval_loop avg_loss=0.048100 precision=98.5%
# @eval_loop avg_loss=0.249995 precision=92.4%
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.046198 processed samples=  0.2%
# @eval_loop avg_loss=0.249995 precision=92.4%
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.046198 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.086141 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.086141 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.086490 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.086490 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.087732 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.087732 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.089007 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.089007 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.090937 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.090937 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.092654 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.092654 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.093257 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.093257 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.091708 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.091708 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.092370 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.092370 processed samples= 90.2%
# @eval_loop avg_loss=0.043555 precision=98.4%
# @eval_loop avg_loss=0.043555 precision=98.4%
# @eval_loop avg_loss=0.278634 precision=92.6%
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.099942 processed samples=  0.2%
# @eval_loop avg_loss=0.278634 precision=92.6%
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.099942 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.085900 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.085900 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.091431 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.091431 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.091583 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.091583 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.090379 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.090379 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.089088 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.089088 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.089727 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.089727 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.090358 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.090358 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.090266 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.090266 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.089975 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.089975 processed samples= 90.2%
# @eval_loop avg_loss=0.042177 precision=98.5%
# @eval_loop avg_loss=0.042177 precision=98.5%
# @eval_loop avg_loss=0.270598 precision=92.6%
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.083523 processed samples=  0.2%
# @eval_loop avg_loss=0.270598 precision=92.6%
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.083523 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.076000 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.076000 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.076158 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.076158 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.080050 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.080050 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.082705 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.082705 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.084730 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.084730 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.086246 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.086246 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.086348 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.086348 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.086732 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.086732 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.086925 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.086925 processed samples= 90.2%
# @eval_loop avg_loss=0.041966 precision=98.5%
# @eval_loop avg_loss=0.041966 precision=98.5%
# @eval_loop avg_loss=0.288029 precision=92.6%
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.066712 processed samples=  0.2%
# @eval_loop avg_loss=0.288029 precision=92.6%
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.066712 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.080768 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.080768 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.080191 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.080191 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.078639 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.078639 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.080372 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.080372 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.081232 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.081232 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.082241 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.082241 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.082345 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.082345 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.081432 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.081432 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.082895 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.082895 processed samples= 90.2%
# @eval_loop avg_loss=0.035210 precision=98.8%
# @eval_loop avg_loss=0.035210 precision=98.8%
# @eval_loop avg_loss=0.297115 precision=92.6%
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.037251 processed samples=  0.2%
# @eval_loop avg_loss=0.297115 precision=92.6%
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.037251 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.080260 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.080260 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.075886 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.075886 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.076917 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.076917 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.078786 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.078786 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.078679 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.078679 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.079976 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.079976 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.079333 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.079333 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.080407 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.080407 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.081512 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.081512 processed samples= 90.2%
# @eval_loop avg_loss=0.033183 precision=98.9%
# @eval_loop avg_loss=0.033183 precision=98.9%
# @eval_loop avg_loss=0.285262 precision=92.5%
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.080849 processed samples=  0.2%
# @eval_loop avg_loss=0.285262 precision=92.5%
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.080849 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.075010 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.075010 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.073659 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.073659 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.072467 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.072467 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.073426 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.073426 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.074221 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.074221 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.075665 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.075665 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.075905 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.075905 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.076336 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.076336 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.077081 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.077081 processed samples= 90.2%
# @eval_loop avg_loss=0.032218 precision=99.0%
# @eval_loop avg_loss=0.032218 precision=99.0%
# @eval_loop avg_loss=0.286610 precision=92.7%
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.079450 processed samples=  0.2%
# @eval_loop avg_loss=0.286610 precision=92.7%
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.079450 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.077525 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.077525 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.071971 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.071971 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.072701 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.072701 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.073803 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.073803 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.074665 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.074665 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.072882 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.072882 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.074273 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.074273 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.076224 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.076224 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.077271 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.077271 processed samples= 90.2%
# @eval_loop avg_loss=0.029515 precision=99.0%
# @eval_loop avg_loss=0.029515 precision=99.0%
# @eval_loop avg_loss=0.300776 precision=92.7%
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.086762 processed samples=  0.2%
# @eval_loop avg_loss=0.300776 precision=92.7%
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.086762 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.069335 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.069335 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.068315 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.068315 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.075747 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.075747 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.075711 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.075711 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.074123 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.074123 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.074742 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.074742 processed samples= 60.2%
# ...
# @train_loop batch=  240 avrg_loss=0.047866 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.047866 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.047933 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.047933 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.049475 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.049475 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.048476 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.048476 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.048973 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.048973 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.048225 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.048225 processed samples= 90.2%
# @eval_loop avg_loss=0.009672 precision=99.8%
# @eval_loop avg_loss=0.009672 precision=99.8%
# @eval_loop avg_loss=0.339095 precision=92.5%
# Epoch 52
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.006453 processed samples=  0.2%
# @eval_loop avg_loss=0.339095 precision=92.5%
# Epoch 52
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.006453 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.039677 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.039677 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.044170 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.044170 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.045954 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.045954 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046471 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.046471 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.046364 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.046364 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.046265 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.046265 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.046160 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.046160 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.045953 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.045953 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.046727 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.046727 processed samples= 90.2%
# @eval_loop avg_loss=0.011119 precision=99.7%
# @eval_loop avg_loss=0.011119 precision=99.7%
# @eval_loop avg_loss=0.355803 precision=92.5%
# Epoch 53
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.050887 processed samples=  0.2%
# @eval_loop avg_loss=0.355803 precision=92.5%
# Epoch 53
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.050887 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.043708 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.043708 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.042759 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.042759 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044297 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.044297 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.044830 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.044830 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.045575 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.045575 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045090 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.045090 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.046261 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.046261 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.048014 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.048014 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.048059 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.048059 processed samples= 90.2%
# @eval_loop avg_loss=0.010084 precision=99.7%
# @eval_loop avg_loss=0.010084 precision=99.7%
# @eval_loop avg_loss=0.354399 precision=92.5%
# Epoch 54
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.005176 processed samples=  0.2%
# @eval_loop avg_loss=0.354399 precision=92.5%
# Epoch 54
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.005176 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.045987 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.045987 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.040769 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.040769 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.039644 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.039644 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.040428 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.040428 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.041987 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.041987 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.044009 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.044009 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.044893 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.044893 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.045883 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.045883 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.045961 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.045961 processed samples= 90.2%
# @eval_loop avg_loss=0.010821 precision=99.7%
# @eval_loop avg_loss=0.010821 precision=99.7%
# @eval_loop avg_loss=0.348138 precision=92.8%
# Epoch 55
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.111384 processed samples=  0.2%
# @eval_loop avg_loss=0.348138 precision=92.8%
# Epoch 55
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.111384 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.047314 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.047314 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.049352 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.049352 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.048535 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.048535 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.047690 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.047690 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.049522 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.049522 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.049168 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.049168 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.049034 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.049034 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.049903 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.049903 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.048978 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.048978 processed samples= 90.2%
# @eval_loop avg_loss=0.010573 precision=99.7%
# @eval_loop avg_loss=0.010573 precision=99.7%
# @eval_loop avg_loss=0.374858 precision=92.4%
# Epoch 56
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.060069 processed samples=  0.2%
# @eval_loop avg_loss=0.374858 precision=92.4%
# Epoch 56
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.060069 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.043535 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.043535 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043423 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.043423 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.040834 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.040834 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.044688 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.044688 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.044817 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.044817 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045817 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.045817 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.046553 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.046553 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.046267 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.046267 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.046683 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.046683 processed samples= 90.2%
# @eval_loop avg_loss=0.007175 precision=99.9%
# @eval_loop avg_loss=0.007175 precision=99.9%
# @eval_loop avg_loss=0.363617 precision=92.7%
# Epoch 57
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.018016 processed samples=  0.2%
# @eval_loop avg_loss=0.363617 precision=92.7%
# Epoch 57
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.018016 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.035698 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.035698 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.035298 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.035298 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.034982 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.034982 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.037283 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.037283 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039793 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.039793 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.041320 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.041320 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.042665 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.042665 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.043644 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.043644 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.043439 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.043439 processed samples= 90.2%
# @eval_loop avg_loss=0.010235 precision=99.7%
# @eval_loop avg_loss=0.010235 precision=99.7%
# @eval_loop avg_loss=0.344003 precision=92.6%
# Epoch 58
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.093089 processed samples=  0.2%
# @eval_loop avg_loss=0.344003 precision=92.6%
# Epoch 58
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.093089 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.044347 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.044347 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.045813 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.045813 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046220 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.046220 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.045777 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.045777 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.044013 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.044013 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.043298 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.043298 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.043771 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.043771 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.042773 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.042773 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.042683 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.042683 processed samples= 90.2%
# @eval_loop avg_loss=0.009537 precision=99.7%
# @eval_loop avg_loss=0.009537 precision=99.7%
# @eval_loop avg_loss=0.380198 precision=92.3%
# Epoch 59
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.018666 processed samples=  0.2%
# @eval_loop avg_loss=0.380198 precision=92.3%
# Epoch 59
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.018666 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.042532 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.042532 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.045918 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.045918 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.048769 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.048769 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046921 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.046921 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.046695 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.046695 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.044842 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.044842 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.044438 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.044438 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.044139 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.044139 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.044194 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.044194 processed samples= 90.2%
# @eval_loop avg_loss=0.011630 precision=99.6%
# @eval_loop avg_loss=0.011630 precision=99.6%
# @eval_loop avg_loss=0.359086 precision=92.6%
# Epoch 60
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.055088 processed samples=  0.2%
# @eval_loop avg_loss=0.359086 precision=92.6%
# Epoch 60
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.055088 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.046075 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.046075 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.042886 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.042886 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.042672 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.042672 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.041662 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.041662 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.041448 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.041448 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.041853 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.041853 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.042166 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.042166 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.041914 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.041914 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.040926 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.040926 processed samples= 90.2%
# @eval_loop avg_loss=0.007817 precision=99.8%
# @eval_loop avg_loss=0.007817 precision=99.8%
# @eval_loop avg_loss=0.346670 precision=92.8%
# Done!
# ✔ Modelo guardado en: resultados/modelo.pt
# ✔ Checkpoint guardado en: resultados/checkpoint.pt
# ✔ Métricas guardadas en: resultados/metricas.pt
# ✔ Resumen guardado en: resultados/resumen.json
# @eval_loop avg_loss=0.346670 precision=92.8%
# Done!
# ✔ Modelo guardado en: resultados/modelo.pt
# ✔ Checkpoint guardado en: resultados/checkpoint.pt
# ✔ Métricas guardadas en: resultados/metricas.pt
# ✔ Resumen guardado en: resultados/resumen.json

# %%
# 5.10)
import matplotlib.pyplot as plt
import os

# Crear carpeta si no existe
os.makedirs("resultados", exist_ok=True)

plt.figure(figsize=(10, 6))

# Colores y estilos (coherentes con el gráfico comparativo)
plt.plot(
    range(1, len(list_avg_train_loss_incorrecta) + 1),
    list_avg_train_loss_incorrecta,
    linestyle=":",
    color="tab:red",
    label="Train loss incorrecta"
)

plt.plot(
    range(1, len(list_avg_train_loss) + 1),
    list_avg_train_loss,
    linestyle="--",
    color="tab:green",
    label="Train loss"
)

plt.plot(
    range(1, len(list_avg_valid_loss) + 1),
    list_avg_valid_loss,
    linestyle="-",
    color="tab:blue",
    label="Valid loss"
)

plt.title("Evolución del Loss – Entrenamiento completo sin pre-entrenamiento ")
plt.xlabel("Epoch")
plt.ylabel("Loss (Cross Entropy)")
plt.legend()
plt.grid(True)
plt.tight_layout()

# Guardar el gráfico
plt.savefig("resultados/loss.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en resultados/loss.png")
# Out:
# ✔ Gráfico guardado en resultados/loss.png

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("resultados", exist_ok=True)

plt.figure(figsize=(10, 6))

# Línea objetivo
plt.axhline(y=0.9, color="grey", linestyle="--")

# Colores tabulados (consistentes)
plt.plot(
    range(1, len(list_train_precision_incorrecta) + 1),
    list_train_precision_incorrecta,
    linestyle=":",
    color="tab:red",
    label="Train accuracy incorrecta"
)

plt.plot(
    range(1, len(list_train_precision) + 1),
    list_train_precision,
    linestyle="--",
    color="tab:green",
    label="Train accuracy"
)

plt.plot(
    range(1, len(list_valid_precision) + 1),
    list_valid_precision,
    linestyle="-",
    color="tab:blue",
    label="Valid accuracy"
)

plt.title("Evolución de Accuracy – Entrenamiento completo sin pre-entrenamiento")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim(-0.1, len(list_valid_precision) + 0.1)
plt.ylim(0.7, 1.0)

plt.legend()
plt.grid(True)
plt.tight_layout()

save_path = "resultados/accuracy.png"
plt.savefig(save_path, dpi=300)
plt.show()

print("✔ Gráfico de accuracy guardado en:", save_path)
# Out:
# ✔ Gráfico de accuracy guardado en: resultados/accuracy.png

# %%
import torch
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------------------------------------
#   1) Cargar el modelo entrenado
# ---------------------------------------------------------
model_path = "resultados/modelo.pt"

clasificador = model.to(device)
clasificador.load_state_dict(torch.load(model_path, map_location=device))
clasificador.eval()

print("✔ Modelo cargado desde:", model_path)

# ---------------------------------------------------------
#   2) Obtener predicciones sobre conjunto VALID
# ---------------------------------------------------------
y_true = []
y_pred = []

with torch.no_grad():
    for x, labels in valid_loader:
        x, labels = x.to(device), labels.to(device)

        outputs = clasificador(x)
        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ---------------------------------------------------------
#   3) Matriz de confusión
# ---------------------------------------------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")

plt.title("Matriz de Confusión – Entrenamiento completo sin pre-entrenamiento")
plt.tight_layout()

out_png = "resultados/matriz_confusion_5_11.png"
plt.savefig(out_png, dpi=300)
plt.show()

print("✔ Matriz de confusión guardada en:", out_png)
# Out:
# ✔ Modelo cargado desde: resultados/modelo.pt
# ✔ Matriz de confusión guardada en: resultados/matriz_confusion_5_11.png
