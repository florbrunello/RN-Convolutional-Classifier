# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# /bin/bash: línea 1: /home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/.venv/bin/pip3: no se puede ejecutar: no se ha encontrado el fichero requerido

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                ,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=33516
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
# Cargar únicamente los pesos del Autoencoder preentrenado
import torch
from torch import nn
# Debes tener la misma definición de Autoencoder que se usó al entrenar
from autoencoder import Autoencoder  # o copia la clase Autoencoder a tu notebook

checkpoint_path = "/home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/Autoencoder/3_final/resultados/loss_results.pt"
checkpoint = torch.load(checkpoint_path, map_location="cpu")

# Fijamos manualmente el hiperparámetro de dropout (por ejemplo 0.15)
dropout_autoencoder = 0.15
autoencoder = Autoencoder(dropout=dropout_autoencoder)
autoencoder.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
class Clasificadora(nn.Module):
    def __init__(self, encoder=None):
        super().__init__()
        self.encoder = encoder

        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),
            
            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Capa 2
            nn.Linear(in_features = 256, out_features = 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Capa 2
            nn.Linear(in_features = 128, out_features = 64),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Capa 3
            nn.Linear(in_features = 64, out_features = 10)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

num_train_batches = len(train_loader)
num_valid_batches = len(valid_loader)
print(f'num_train_batches={num_train_batches}')
print(f'num_valid_batches={num_valid_batches}')
# Out:
# num_train_batches=600
# num_valid_batches=100

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
# Ejemplo: pasar encoder a tu modelo Clasificadora con dropout fijo en la clasificadora
# p_dropout_clf = 0.2
# clasificador = Clasificadora(p=p_dropout_clf, n1=128, n2=64, encoder=autoencoder.encoder)

# %%
# 5.6)
# learning_rate = 1e-4
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.Adam(clasificador.classifier.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#clasificador = clasificador.to(device)

# %%
# 5.8) y 5.9)
import torch
import json
import os

# Crear carpeta de resultados si no existe
os.makedirs("resultados", exist_ok=True)

# Inicializar el modelo Clasificadora con el encoder del Autoencoder preentrenado
p_dropout_clf = 0.2
learning_rate = 1e-3
model = Clasificadora(encoder=autoencoder.encoder)
model = model.to(device)

# 2) IMPORTANTE: Permitir que el encoder también se entrene (fine-tuning completo)
# Por defecto, todos los parámetros están habilitados para entrenamiento
# Si quisieras congelar el encoder, harías: 
# for param in model.encoder.parameters():
#     param.requires_grad = False

# 3) Configurar optimizador para TODOS los parámetros (encoder + clasificador)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=1e-08, weight_decay=0, amsgrad=False)

num_epochs = 60

list_avg_train_loss_incorrecta = []
list_avg_train_loss = []
list_avg_valid_loss = []
list_train_precision_incorrecta = []
list_train_precision = []
list_valid_precision = []

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}\n-------------------------------')

    train_avg_loss_incorrecta, train_precision_incorrecta = train_loop(
        train_loader, model, loss_fn, optimizer
    )

    train_avg_loss, train_precision = eval_loop(
        train_loader, model, loss_fn
    )

    valid_avg_loss, valid_precision = eval_loop(
        valid_loader, model, loss_fn
    )

    list_avg_train_loss_incorrecta.append(train_avg_loss_incorrecta)
    list_avg_train_loss.append(train_avg_loss)
    list_avg_valid_loss.append(valid_avg_loss)
    list_train_precision_incorrecta.append(train_precision_incorrecta)
    list_train_precision.append(train_precision)
    list_valid_precision.append(valid_precision)

    print(f"📊 Epoch {epoch+1} Summary:")
    print(f"   Train Loss: {train_avg_loss:.4f} | Train Acc: {train_precision:.4f}")
    print(f"   Valid Loss: {valid_avg_loss:.4f} | Valid Acc: {valid_precision:.4f}\n")

print("✅ FINE-TUNING COMPLETO FINALIZADO!\n")

# ===============================================================
#          🔥 GUARDAR MODELO Y MÉTRICAS (FORMATO EXPERIMENTOS)
# ===============================================================

# 1) Guardar modelo (solo pesos)
model_path = "resultados/modelo.pt"
torch.save(model.state_dict(), model_path)

# 1b) Guardar checkpoint completo (pesos + optimizador + config)
checkpoint_path = "resultados/checkpoint.pt"
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": {
        "num_epochs": num_epochs,
        "learning_rate": learning_rate,
        "batch_size": batch_size,
        "p_dropout_clf": p_dropout_clf
    }
}, checkpoint_path)

# 2) Guardar TODAS las métricas
metrics_path = "resultados/metricas.pt"
torch.save({
    "train_loss_incorrecta": list_avg_train_loss_incorrecta,
    "train_loss": list_avg_train_loss,
    "valid_loss": list_avg_valid_loss,
    "train_precision_incorrecta": list_train_precision_incorrecta,
    "train_precision": list_train_precision,
    "valid_precision": list_valid_precision,
    "num_epochs": num_epochs,
    "learning_rate": learning_rate,
    "batch_size": batch_size,
    "p_dropout_clf": p_dropout_clf
}, metrics_path)

# 3) Guardar JSON con resumen
resumen = {
    "final_train_precision": list_train_precision[-1],
    "final_valid_precision": list_valid_precision[-1],
    "final_valid_loss": list_avg_valid_loss[-1],
    "model_path": model_path,
    "checkpoint_path": checkpoint_path,
    "metrics_path": metrics_path
}

json_path = "resultados/resumen.json"
with open(json_path, "w") as f:
    json.dump(resumen, f, indent=4)

print("✔ Modelo guardado en:", model_path)
print("✔ Checkpoint guardado en:", checkpoint_path)
print("✔ Métricas guardadas en:", metrics_path)
print("✔ Resumen guardado en:", json_path)
# Out:
# Epoch 1
# -------------------------------
# @train_loop batch=    0 avrg_loss=2.317122 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.201565 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.966495 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.837186 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.759859 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.708018 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.665281 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.631023 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.603609 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.581157 processed samples= 90.2%
# @eval_loop avg_loss=0.324687 precision=88.6%
# @eval_loop avg_loss=0.357244 precision=87.3%
# 📊 Epoch 1 Summary:
#    Train Loss: 0.3247 | Train Acc: 0.8857
#    Valid Loss: 0.3572 | Valid Acc: 0.8729
#
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.234688 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.370812 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.357101 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.355368 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.352205 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.348196 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.345304 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.341246 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.336537 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.335845 processed samples= 90.2%
# @eval_loop avg_loss=0.232640 precision=91.6%
# @eval_loop avg_loss=0.278440 precision=90.1%
# 📊 Epoch 2 Summary:
#    Train Loss: 0.2326 | Train Acc: 0.9156
#    Valid Loss: 0.2784 | Valid Acc: 0.9014
#
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.304280 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.278113 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.276857 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.282373 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.277505 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.278634 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.278557 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.277241 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.276999 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.276772 processed samples= 90.2%
# @eval_loop avg_loss=0.199193 precision=92.6%
# @eval_loop avg_loss=0.264232 precision=90.6%
# 📊 Epoch 3 Summary:
#    Train Loss: 0.1992 | Train Acc: 0.9265
#    Valid Loss: 0.2642 | Valid Acc: 0.9061
#
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.150202 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.242230 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.251987 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.248892 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.248234 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.248451 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.247834 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.246325 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.244961 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.244111 processed samples= 90.2%
# @eval_loop avg_loss=0.174129 precision=93.7%
# @eval_loop avg_loss=0.244637 precision=91.3%
# 📊 Epoch 4 Summary:
#    Train Loss: 0.1741 | Train Acc: 0.9367
#    Valid Loss: 0.2446 | Valid Acc: 0.9126
#
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.157197 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.203399 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.208686 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.208583 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.214717 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.215419 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.215739 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.215990 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.217328 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.216149 processed samples= 90.2%
# @eval_loop avg_loss=0.164896 precision=94.0%
# @eval_loop avg_loss=0.245966 precision=91.2%
# 📊 Epoch 5 Summary:
#    Train Loss: 0.1649 | Train Acc: 0.9400
#    Valid Loss: 0.2460 | Valid Acc: 0.9123
#
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.198804 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.193293 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.186432 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.191730 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.196220 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.196445 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.196694 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.196401 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.194785 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.194523 processed samples= 90.2%
# @eval_loop avg_loss=0.135019 precision=95.1%
# @eval_loop avg_loss=0.232168 precision=91.7%
# 📊 Epoch 6 Summary:
#    Train Loss: 0.1350 | Train Acc: 0.9512
#    Valid Loss: 0.2322 | Valid Acc: 0.9174
#
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.199705 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.161217 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.171827 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.177392 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.178124 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.179419 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.177539 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.177848 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.179865 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.180187 processed samples= 90.2%
# @eval_loop avg_loss=0.115329 precision=95.8%
# @eval_loop avg_loss=0.230385 precision=92.1%
# 📊 Epoch 7 Summary:
#    Train Loss: 0.1153 | Train Acc: 0.9580
#    Valid Loss: 0.2304 | Valid Acc: 0.9206
#
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.114881 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.151586 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.155022 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.158355 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.159466 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.160608 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.160742 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.162771 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.164559 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.165200 processed samples= 90.2%
# @eval_loop avg_loss=0.110701 precision=95.9%
# @eval_loop avg_loss=0.244713 precision=91.9%
# 📊 Epoch 8 Summary:
#    Train Loss: 0.1107 | Train Acc: 0.9586
#    Valid Loss: 0.2447 | Valid Acc: 0.9187
#
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.094974 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.144302 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.149603 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.151300 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.151642 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.149703 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.150711 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.150188 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.151198 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.152343 processed samples= 90.2%
# @eval_loop avg_loss=0.098864 precision=96.4%
# @eval_loop avg_loss=0.250783 precision=92.2%
# 📊 Epoch 9 Summary:
#    Train Loss: 0.0989 | Train Acc: 0.9637
#    Valid Loss: 0.2508 | Valid Acc: 0.9217
#
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.139871 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.140314 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.142579 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.141979 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.144739 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.143558 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.144980 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.144570 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.144466 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.144703 processed samples= 90.2%
# @eval_loop avg_loss=0.087667 precision=96.7%
# @eval_loop avg_loss=0.263151 precision=91.9%
# 📊 Epoch 10 Summary:
#    Train Loss: 0.0877 | Train Acc: 0.9668
#    Valid Loss: 0.2632 | Valid Acc: 0.9187
#
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.211424 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.122388 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.123759 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.128294 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.130636 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.129280 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.128365 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.128798 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.129962 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.130700 processed samples= 90.2%
# @eval_loop avg_loss=0.088812 precision=96.6%
# @eval_loop avg_loss=0.263185 precision=91.8%
# 📊 Epoch 11 Summary:
#    Train Loss: 0.0888 | Train Acc: 0.9663
#    Valid Loss: 0.2632 | Valid Acc: 0.9182
#
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.136622 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.121687 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.116126 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.119098 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.119058 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.118513 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.120044 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.120549 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.120969 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.121889 processed samples= 90.2%
# @eval_loop avg_loss=0.068852 precision=97.6%
# @eval_loop avg_loss=0.255153 precision=92.0%
# 📊 Epoch 12 Summary:
#    Train Loss: 0.0689 | Train Acc: 0.9765
#    Valid Loss: 0.2552 | Valid Acc: 0.9205
#
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.067211 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.109404 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.105296 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.106261 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.105241 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.108243 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.109907 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.111332 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.111596 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.112051 processed samples= 90.2%
# @eval_loop avg_loss=0.064894 precision=97.7%
# @eval_loop avg_loss=0.267849 precision=91.9%
# 📊 Epoch 13 Summary:
#    Train Loss: 0.0649 | Train Acc: 0.9766
#    Valid Loss: 0.2678 | Valid Acc: 0.9187
#
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.046214 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.112086 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.108789 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.107616 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.106694 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.108124 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.108678 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.109301 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.110035 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.109404 processed samples= 90.2%
# @eval_loop avg_loss=0.051035 precision=98.3%
# @eval_loop avg_loss=0.284953 precision=92.0%
# 📊 Epoch 14 Summary:
#    Train Loss: 0.0510 | Train Acc: 0.9826
#    Valid Loss: 0.2850 | Valid Acc: 0.9205
#
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.078783 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.097423 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.102803 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.102282 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.102193 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.099829 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.101346 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.102262 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.101960 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.102578 processed samples= 90.2%
# @eval_loop avg_loss=0.052145 precision=98.1%
# @eval_loop avg_loss=0.291231 precision=92.0%
# 📊 Epoch 15 Summary:
#    Train Loss: 0.0521 | Train Acc: 0.9810
#    Valid Loss: 0.2912 | Valid Acc: 0.9201
#
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.099671 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.089729 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.093351 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.094057 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.095626 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.093955 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.093787 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.094337 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.094959 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.096192 processed samples= 90.2%
# @eval_loop avg_loss=0.051541 precision=98.1%
# @eval_loop avg_loss=0.298554 precision=92.1%
# 📊 Epoch 16 Summary:
#    Train Loss: 0.0515 | Train Acc: 0.9810
#    Valid Loss: 0.2986 | Valid Acc: 0.9213
#
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.092842 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.084724 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.082921 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.083642 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.085599 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.087630 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.089544 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.089526 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.091312 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.092503 processed samples= 90.2%
# @eval_loop avg_loss=0.041933 precision=98.6%
# @eval_loop avg_loss=0.284508 precision=92.3%
# 📊 Epoch 17 Summary:
#    Train Loss: 0.0419 | Train Acc: 0.9860
#    Valid Loss: 0.2845 | Valid Acc: 0.9231
#
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.063899 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.082516 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.079468 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.081137 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.082371 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.082879 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.083371 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.083772 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.085687 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.086746 processed samples= 90.2%
# @eval_loop avg_loss=0.039546 precision=98.8%
# @eval_loop avg_loss=0.282019 precision=92.5%
# 📊 Epoch 18 Summary:
#    Train Loss: 0.0395 | Train Acc: 0.9883
#    Valid Loss: 0.2820 | Valid Acc: 0.9250
#
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.071280 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.071958 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.075710 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.077597 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.076661 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.077526 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.078033 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.079840 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.080170 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.080435 processed samples= 90.2%
# @eval_loop avg_loss=0.037345 precision=98.8%
# @eval_loop avg_loss=0.300946 precision=92.3%
# 📊 Epoch 19 Summary:
#    Train Loss: 0.0373 | Train Acc: 0.9882
#    Valid Loss: 0.3009 | Valid Acc: 0.9226
#
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.071172 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.073807 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.074869 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.075177 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.078332 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.078859 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.078698 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.077846 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.078216 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.079996 processed samples= 90.2%
# @eval_loop avg_loss=0.031318 precision=99.0%
# @eval_loop avg_loss=0.316833 precision=92.3%
# 📊 Epoch 20 Summary:
#    Train Loss: 0.0313 | Train Acc: 0.9897
#    Valid Loss: 0.3168 | Valid Acc: 0.9235
#
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.060542 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.067717 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.066874 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.072649 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.073606 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.075095 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.075346 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.075443 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.076479 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.075970 processed samples= 90.2%
# @eval_loop avg_loss=0.033625 precision=98.9%
# @eval_loop avg_loss=0.311633 precision=92.3%
# 📊 Epoch 21 Summary:
#    Train Loss: 0.0336 | Train Acc: 0.9892
#    Valid Loss: 0.3116 | Valid Acc: 0.9229
#
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.124604 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.057048 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.062490 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.068182 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.069062 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.067872 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.069244 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.069491 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.070729 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.072673 processed samples= 90.2%
# @eval_loop avg_loss=0.029604 precision=99.0%
# @eval_loop avg_loss=0.318082 precision=92.1%
# 📊 Epoch 22 Summary:
#    Train Loss: 0.0296 | Train Acc: 0.9899
#    Valid Loss: 0.3181 | Valid Acc: 0.9210
#
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.052155 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.069209 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.066013 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.065069 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.066079 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.067755 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.068339 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.068108 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.069044 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.069947 processed samples= 90.2%
# @eval_loop avg_loss=0.023193 precision=99.3%
# @eval_loop avg_loss=0.317475 precision=92.4%
# 📊 Epoch 23 Summary:
#    Train Loss: 0.0232 | Train Acc: 0.9929
#    Valid Loss: 0.3175 | Valid Acc: 0.9238
#
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.014502 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.060264 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.065538 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.066188 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.064175 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.067914 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.067826 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.067851 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.067784 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.068696 processed samples= 90.2%
# @eval_loop avg_loss=0.023693 precision=99.2%
# @eval_loop avg_loss=0.337909 precision=92.2%
# 📊 Epoch 24 Summary:
#    Train Loss: 0.0237 | Train Acc: 0.9921
#    Valid Loss: 0.3379 | Valid Acc: 0.9221
#
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.043387 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.070853 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.063579 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.061953 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.060234 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.059889 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.060969 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.062952 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.062937 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.062140 processed samples= 90.2%
# @eval_loop avg_loss=0.021832 precision=99.4%
# @eval_loop avg_loss=0.335582 precision=92.1%
# 📊 Epoch 25 Summary:
#    Train Loss: 0.0218 | Train Acc: 0.9939
#    Valid Loss: 0.3356 | Valid Acc: 0.9212
#
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.080630 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.065207 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.062030 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.060723 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.062567 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.062403 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.061915 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.062876 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.063089 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.062840 processed samples= 90.2%
# @eval_loop avg_loss=0.017377 precision=99.5%
# @eval_loop avg_loss=0.365023 precision=92.3%
# 📊 Epoch 26 Summary:
#    Train Loss: 0.0174 | Train Acc: 0.9947
#    Valid Loss: 0.3650 | Valid Acc: 0.9229
#
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.072726 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.055063 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.057413 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.059009 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.058776 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.063421 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.063510 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.063449 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.064224 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.063390 processed samples= 90.2%
# @eval_loop avg_loss=0.018104 precision=99.4%
# @eval_loop avg_loss=0.364845 precision=92.2%
# 📊 Epoch 27 Summary:
#    Train Loss: 0.0181 | Train Acc: 0.9943
#    Valid Loss: 0.3648 | Valid Acc: 0.9222
#
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.052621 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.059486 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.060076 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.058069 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.058892 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.059560 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.060968 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.061035 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.060938 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.061179 processed samples= 90.2%
# @eval_loop avg_loss=0.015224 precision=99.6%
# @eval_loop avg_loss=0.339706 precision=92.3%
# 📊 Epoch 28 Summary:
#    Train Loss: 0.0152 | Train Acc: 0.9962
#    Valid Loss: 0.3397 | Valid Acc: 0.9232
#
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.044873 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.049376 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.053329 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.054986 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.055452 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.054889 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.055616 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.055976 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.056598 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.056484 processed samples= 90.2%
# @eval_loop avg_loss=0.014936 precision=99.6%
# @eval_loop avg_loss=0.360499 precision=92.0%
# 📊 Epoch 29 Summary:
#    Train Loss: 0.0149 | Train Acc: 0.9957
#    Valid Loss: 0.3605 | Valid Acc: 0.9200
#
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.054135 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.056634 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.053837 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.056424 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.054410 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.054031 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.054568 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.054911 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.055648 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.056818 processed samples= 90.2%
# @eval_loop avg_loss=0.016923 precision=99.5%
# @eval_loop avg_loss=0.349202 precision=92.5%
# 📊 Epoch 30 Summary:
#    Train Loss: 0.0169 | Train Acc: 0.9955
#    Valid Loss: 0.3492 | Valid Acc: 0.9251
#
# Epoch 31
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.030122 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.046020 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.044232 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044297 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.049910 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.052436 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.054039 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.054946 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.055758 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.055878 processed samples= 90.2%
# @eval_loop avg_loss=0.017854 precision=99.4%
# @eval_loop avg_loss=0.382607 precision=91.8%
# 📊 Epoch 31 Summary:
#    Train Loss: 0.0179 | Train Acc: 0.9937
#    Valid Loss: 0.3826 | Valid Acc: 0.9180
#
# Epoch 32
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.101492 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.054664 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.055618 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.054825 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.051712 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.052407 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.052192 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.051926 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.051987 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.053023 processed samples= 90.2%
# @eval_loop avg_loss=0.013220 precision=99.6%
# @eval_loop avg_loss=0.378452 precision=92.3%
# 📊 Epoch 32 Summary:
#    Train Loss: 0.0132 | Train Acc: 0.9959
#    Valid Loss: 0.3785 | Valid Acc: 0.9229
#
# Epoch 33
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.014240 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.044039 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.048807 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.051015 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.051728 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.051492 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.051335 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.052686 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.052783 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.051797 processed samples= 90.2%
# @eval_loop avg_loss=0.011899 precision=99.6%
# @eval_loop avg_loss=0.389719 precision=92.4%
# 📊 Epoch 33 Summary:
#    Train Loss: 0.0119 | Train Acc: 0.9964
#    Valid Loss: 0.3897 | Valid Acc: 0.9238
#
# Epoch 34
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.049222 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.050289 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.047463 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046385 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.048545 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.048007 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.050101 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.051204 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.052301 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.052604 processed samples= 90.2%
# @eval_loop avg_loss=0.010597 precision=99.7%
# @eval_loop avg_loss=0.392064 precision=92.3%
# 📊 Epoch 34 Summary:
#    Train Loss: 0.0106 | Train Acc: 0.9970
#    Valid Loss: 0.3921 | Valid Acc: 0.9230
#
# Epoch 35
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.007064 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.047630 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.049638 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.048380 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046013 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.044872 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.047025 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.047110 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.047867 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.048086 processed samples= 90.2%
# @eval_loop avg_loss=0.022525 precision=99.2%
# @eval_loop avg_loss=0.387957 precision=92.1%
# 📊 Epoch 35 Summary:
#    Train Loss: 0.0225 | Train Acc: 0.9919
#    Valid Loss: 0.3880 | Valid Acc: 0.9206
#
# Epoch 36
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.028640 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.047467 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.051925 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.050733 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.050211 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.050228 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.049040 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.049504 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.050811 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.050844 processed samples= 90.2%
# @eval_loop avg_loss=0.008690 precision=99.8%
# @eval_loop avg_loss=0.366077 precision=92.4%
# 📊 Epoch 36 Summary:
#    Train Loss: 0.0087 | Train Acc: 0.9984
#    Valid Loss: 0.3661 | Valid Acc: 0.9241
#
# Epoch 37
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.058000 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.049576 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.046042 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046333 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.047101 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.047792 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.046771 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.046434 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.046044 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.046440 processed samples= 90.2%
# @eval_loop avg_loss=0.009582 precision=99.7%
# @eval_loop avg_loss=0.418654 precision=92.1%
# 📊 Epoch 37 Summary:
#    Train Loss: 0.0096 | Train Acc: 0.9972
#    Valid Loss: 0.4187 | Valid Acc: 0.9209
#
# Epoch 38
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.048225 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.050890 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.047593 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046971 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.047755 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.047891 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.047546 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.047137 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.047573 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.048589 processed samples= 90.2%
# @eval_loop avg_loss=0.009609 precision=99.8%
# @eval_loop avg_loss=0.383517 precision=92.5%
# 📊 Epoch 38 Summary:
#    Train Loss: 0.0096 | Train Acc: 0.9978
#    Valid Loss: 0.3835 | Valid Acc: 0.9247
#
# Epoch 39
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.030207 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.046729 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043701 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046503 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.045578 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.044970 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045547 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.045970 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.046855 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.047021 processed samples= 90.2%
# @eval_loop avg_loss=0.011127 precision=99.7%
# @eval_loop avg_loss=0.399443 precision=92.2%
# 📊 Epoch 39 Summary:
#    Train Loss: 0.0111 | Train Acc: 0.9969
#    Valid Loss: 0.3994 | Valid Acc: 0.9223
#
# Epoch 40
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.034053 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.048637 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.045963 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046735 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046324 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.046499 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045628 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.047118 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.046713 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.046676 processed samples= 90.2%
# @eval_loop avg_loss=0.009685 precision=99.7%
# @eval_loop avg_loss=0.413507 precision=92.1%
# 📊 Epoch 40 Summary:
#    Train Loss: 0.0097 | Train Acc: 0.9970
#    Valid Loss: 0.4135 | Valid Acc: 0.9208
#
# Epoch 41
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.027372 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.042033 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.038424 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.037208 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.041272 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.042297 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.042861 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.043761 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.044667 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.044246 processed samples= 90.2%
# @eval_loop avg_loss=0.010953 precision=99.7%
# @eval_loop avg_loss=0.447065 precision=92.0%
# 📊 Epoch 41 Summary:
#    Train Loss: 0.0110 | Train Acc: 0.9966
#    Valid Loss: 0.4471 | Valid Acc: 0.9204
#
# Epoch 42
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.071565 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.041590 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043007 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.042792 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046381 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.045527 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045334 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.044341 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.044614 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.044002 processed samples= 90.2%
# @eval_loop avg_loss=0.009065 precision=99.8%
# @eval_loop avg_loss=0.400831 precision=92.1%
# 📊 Epoch 42 Summary:
#    Train Loss: 0.0091 | Train Acc: 0.9979
#    Valid Loss: 0.4008 | Valid Acc: 0.9210
#
# Epoch 43
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.048066 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.038737 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043865 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.040915 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.040660 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.041010 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.041452 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.041357 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.041541 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.041915 processed samples= 90.2%
# @eval_loop avg_loss=0.010577 precision=99.7%
# @eval_loop avg_loss=0.409054 precision=92.0%
# 📊 Epoch 43 Summary:
#    Train Loss: 0.0106 | Train Acc: 0.9967
#    Valid Loss: 0.4091 | Valid Acc: 0.9196
#
# Epoch 44
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.034448 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.043904 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043627 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044022 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.042506 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.042547 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.042895 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.043656 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.042594 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.042635 processed samples= 90.2%
# @eval_loop avg_loss=0.007946 precision=99.8%
# @eval_loop avg_loss=0.401318 precision=92.2%
# 📊 Epoch 44 Summary:
#    Train Loss: 0.0079 | Train Acc: 0.9980
#    Valid Loss: 0.4013 | Valid Acc: 0.9220
#
# Epoch 45
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.034537 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.039493 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.039495 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.039553 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.040257 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039554 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.039394 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.039669 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.039453 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.039733 processed samples= 90.2%
# @eval_loop avg_loss=0.008951 precision=99.7%
# @eval_loop avg_loss=0.415440 precision=92.3%
# 📊 Epoch 45 Summary:
#    Train Loss: 0.0090 | Train Acc: 0.9974
#    Valid Loss: 0.4154 | Valid Acc: 0.9229
#
# Epoch 46
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.019953 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.038713 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.040630 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044153 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.042528 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.042739 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.043247 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.043385 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.042870 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.043284 processed samples= 90.2%
# @eval_loop avg_loss=0.008346 precision=99.8%
# @eval_loop avg_loss=0.409730 precision=92.1%
# 📊 Epoch 46 Summary:
#    Train Loss: 0.0083 | Train Acc: 0.9978
#    Valid Loss: 0.4097 | Valid Acc: 0.9211
#
# Epoch 47
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.011201 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.035344 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.037028 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.036258 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.038279 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.038888 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.040622 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.039895 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.040351 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.041601 processed samples= 90.2%
# @eval_loop avg_loss=0.006378 precision=99.9%
# @eval_loop avg_loss=0.408681 precision=92.4%
# 📊 Epoch 47 Summary:
#    Train Loss: 0.0064 | Train Acc: 0.9988
#    Valid Loss: 0.4087 | Valid Acc: 0.9242
#
# Epoch 48
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.006052 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.038103 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.038848 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.037156 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.038252 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.037526 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.037226 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.038653 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.038268 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.040007 processed samples= 90.2%
# @eval_loop avg_loss=0.007117 precision=99.8%
# @eval_loop avg_loss=0.396402 precision=92.4%
# 📊 Epoch 48 Summary:
#    Train Loss: 0.0071 | Train Acc: 0.9981
#    Valid Loss: 0.3964 | Valid Acc: 0.9236
#
# Epoch 49
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.054691 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.038891 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.040144 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.039900 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.039034 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039172 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.039806 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.040165 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.040729 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.040691 processed samples= 90.2%
# @eval_loop avg_loss=0.007520 precision=99.8%
# @eval_loop avg_loss=0.465078 precision=91.7%
# 📊 Epoch 49 Summary:
#    Train Loss: 0.0075 | Train Acc: 0.9977
#    Valid Loss: 0.4651 | Valid Acc: 0.9167
#
# Epoch 50
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.035328 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.046277 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.047491 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.043795 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.043355 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.042557 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.041316 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.041478 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.040828 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.041562 processed samples= 90.2%
# @eval_loop avg_loss=0.006471 precision=99.9%
# @eval_loop avg_loss=0.414963 precision=91.9%
# 📊 Epoch 50 Summary:
#    Train Loss: 0.0065 | Train Acc: 0.9987
#    Valid Loss: 0.4150 | Valid Acc: 0.9189
#
# Epoch 51
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.015337 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.032177 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.035224 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.033179 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.038066 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.038439 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.037034 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.036416 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.037898 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.037998 processed samples= 90.2%
# @eval_loop avg_loss=0.004966 precision=99.9%
# @eval_loop avg_loss=0.435101 precision=92.2%
# 📊 Epoch 51 Summary:
#    Train Loss: 0.0050 | Train Acc: 0.9991
#    Valid Loss: 0.4351 | Valid Acc: 0.9218
#
# Epoch 52
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.004357 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.035937 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.037389 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.039405 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.038889 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.037544 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.038171 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.038557 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.038690 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.038971 processed samples= 90.2%
# @eval_loop avg_loss=0.004949 precision=99.9%
# @eval_loop avg_loss=0.427507 precision=92.4%
# 📊 Epoch 52 Summary:
#    Train Loss: 0.0049 | Train Acc: 0.9987
#    Valid Loss: 0.4275 | Valid Acc: 0.9241
#
# Epoch 53
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.050885 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.030265 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.032099 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.034954 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.033596 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.034699 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.036795 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.037027 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.036413 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.036932 processed samples= 90.2%
# @eval_loop avg_loss=0.005042 precision=99.9%
# @eval_loop avg_loss=0.429264 precision=92.1%
# 📊 Epoch 53 Summary:
#    Train Loss: 0.0050 | Train Acc: 0.9988
#    Valid Loss: 0.4293 | Valid Acc: 0.9210
#
# Epoch 54
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.019699 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.031181 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.031729 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.033045 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.035374 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.036268 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.035729 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.036779 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.037201 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.038428 processed samples= 90.2%
# @eval_loop avg_loss=0.006269 precision=99.9%
# @eval_loop avg_loss=0.423194 precision=92.4%
# 📊 Epoch 54 Summary:
#    Train Loss: 0.0063 | Train Acc: 0.9986
#    Valid Loss: 0.4232 | Valid Acc: 0.9242
#
# Epoch 55
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.067907 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.041576 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.040878 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.038173 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.037363 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.037450 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.037060 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.036840 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.036458 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.037266 processed samples= 90.2%
# @eval_loop avg_loss=0.005217 precision=99.9%
# @eval_loop avg_loss=0.442782 precision=92.2%
# 📊 Epoch 55 Summary:
#    Train Loss: 0.0052 | Train Acc: 0.9987
#    Valid Loss: 0.4428 | Valid Acc: 0.9215
#
# Epoch 56
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.005127 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.031231 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.029458 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.030621 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.031902 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.031929 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.032079 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.033743 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.034168 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.035257 processed samples= 90.2%
# @eval_loop avg_loss=0.003590 precision=99.9%
# @eval_loop avg_loss=0.442851 precision=92.4%
# 📊 Epoch 56 Summary:
#    Train Loss: 0.0036 | Train Acc: 0.9991
#    Valid Loss: 0.4429 | Valid Acc: 0.9244
#
# Epoch 57
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.025860 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.029791 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.033538 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.031873 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.031580 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.031594 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.032132 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.032514 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.033014 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.033473 processed samples= 90.2%
# @eval_loop avg_loss=0.004525 precision=99.9%
# @eval_loop avg_loss=0.459446 precision=92.1%
# 📊 Epoch 57 Summary:
#    Train Loss: 0.0045 | Train Acc: 0.9990
#    Valid Loss: 0.4594 | Valid Acc: 0.9213
#
# Epoch 58
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.028696 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.034811 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.031730 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.034145 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.034595 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.034662 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.034297 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.034880 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.035193 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.035673 processed samples= 90.2%
# @eval_loop avg_loss=0.007645 precision=99.8%
# @eval_loop avg_loss=0.440946 precision=92.0%
# 📊 Epoch 58 Summary:
#    Train Loss: 0.0076 | Train Acc: 0.9980
#    Valid Loss: 0.4409 | Valid Acc: 0.9198
#
# Epoch 59
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.025267 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.032372 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.029968 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.029895 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.031260 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.032294 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.033557 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.032913 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.032802 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.033888 processed samples= 90.2%
# @eval_loop avg_loss=0.004385 precision=99.9%
# @eval_loop avg_loss=0.436341 precision=92.2%
# 📊 Epoch 59 Summary:
#    Train Loss: 0.0044 | Train Acc: 0.9992
#    Valid Loss: 0.4363 | Valid Acc: 0.9221
#
# Epoch 60
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.001488 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.030298 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.032402 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.030245 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.031971 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.032851 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.034657 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.035891 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.035117 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.035097 processed samples= 90.2%
# @eval_loop avg_loss=0.004194 precision=99.9%
# @eval_loop avg_loss=0.481490 precision=92.5%
# 📊 Epoch 60 Summary:
#    Train Loss: 0.0042 | Train Acc: 0.9988
#    Valid Loss: 0.4815 | Valid Acc: 0.9246
#
# ✅ FINE-TUNING COMPLETO FINALIZADO!
#
# ✔ Modelo guardado en: resultados/modelo.pt
# ✔ Checkpoint guardado en: resultados/checkpoint.pt
# ✔ Métricas guardadas en: resultados/metricas.pt
# ✔ Resumen guardado en: resultados/resumen.json

# %%
# ...existing code...
import torch
import matplotlib.pyplot as plt
import os

# Cargar métricas guardadas
metrics_path = "resultados/metricas.pt"
metrics = torch.load(metrics_path, map_location="cpu")

list_avg_train_loss = metrics["train_loss"]
list_avg_valid_loss = metrics["valid_loss"]

os.makedirs("resultados", exist_ok=True)
plt.figure(figsize=(10, 6))

plt.plot(
    range(1, len(list_avg_train_loss) + 1),
    list_avg_train_loss,
    linestyle="--",
    color="tab:green",
    label="Train loss"
)

plt.plot(
    range(1, len(list_avg_valid_loss) + 1),
    list_avg_valid_loss,
    linestyle="-",
    color="tab:blue",
    label="Valid loss"
)

plt.title("Evolución del Loss – Fine tuning con codificador pre-entrenado")
plt.xlabel("Epoch")
plt.ylabel("Loss (Cross Entropy)")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("resultados/loss_from_file.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en resultados/loss_from_file.png")
# Out:
# ✔ Gráfico guardado en resultados/loss.png

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("resultados", exist_ok=True)

plt.figure(figsize=(10, 6))

# Línea objetivo
plt.axhline(y=0.9, color="grey", linestyle="--")

# Colores tabulados (consistentes)
plt.plot(
    range(1, len(list_train_precision_incorrecta) + 1),
    list_train_precision_incorrecta,
    linestyle=":",
    color="tab:red",
    label="Train accuracy incorrecta"
)

plt.plot(
    range(1, len(list_train_precision) + 1),
    list_train_precision,
    linestyle="--",
    color="tab:green",
    label="Train accuracy"
)

plt.plot(
    range(1, len(list_valid_precision) + 1),
    list_valid_precision,
    linestyle="-",
    color="tab:blue",
    label="Valid accuracy"
)

plt.title("Evolución de Accuracy – Fine tunning con codificador pre-entrenado")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim(-0.1, len(list_valid_precision) + 0.1)
plt.ylim(0.7, 1.0)

plt.legend()
plt.grid(True)
plt.tight_layout()

save_path = "resultados/accuracy.png"
plt.savefig(save_path, dpi=300)
plt.show()

print("✔ Gráfico de accuracy guardado en:", save_path)
# Out:
# ✔ Gráfico de accuracy guardado en: resultados/accuracy.png

# %%
import torch
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------------------------------------
#   1) Cargar el modelo entrenado
# ---------------------------------------------------------
model_path = "resultados/modelo.pt"

clasificador = model.to(device)
clasificador.load_state_dict(torch.load(model_path, map_location=device))
clasificador.eval()

print("✔ Modelo cargado desde:", model_path)

# ---------------------------------------------------------
#   2) Obtener predicciones sobre conjunto VALID
# ---------------------------------------------------------
y_true = []
y_pred = []

with torch.no_grad():
    for x, labels in valid_loader:
        x, labels = x.to(device), labels.to(device)

        outputs = clasificador(x)
        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ---------------------------------------------------------
#   3) Matriz de confusión
# ---------------------------------------------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")

plt.title("Matriz de Confusión – Fine tunning con codificador pre-entrenado")
plt.tight_layout()

out_png = "resultados/matriz_confusion_5_11.png"
plt.savefig(out_png, dpi=300)
plt.show()

print("✔ Matriz de confusión guardada en:", out_png)
# Out:
# ✔ Modelo cargado desde: resultados/modelo.pt
# ✔ Matriz de confusión guardada en: resultados/matriz_confusion_5_11.png
