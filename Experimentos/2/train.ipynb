# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# /bin/bash: línea 1: /home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/.venv/bin/pip3: no se puede ejecutar: no se ha encontrado el fichero requerido

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                #,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=19885
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
# Cargar únicamente los pesos del Autoencoder preentrenado
import torch
from torch import nn
# Debes tener la misma definición de Autoencoder que se usó al entrenar
from autoencoder import Autoencoder  # o copia la clase Autoencoder a tu notebook

checkpoint_path = "/home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/Autoencoder/3_final/resultados/loss_results.pt"
checkpoint = torch.load(checkpoint_path, map_location="cpu")

# Fijamos manualmente el hiperparámetro de dropout (por ejemplo 0.15)
dropout_autoencoder = 0.20
autoencoder = Autoencoder(dropout=dropout_autoencoder)
autoencoder.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
class Clasificadora(nn.Module):
    def __init__(self, encoder=None):
        super().__init__()
        
        self.encoder = encoder
        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),
            
            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            
            # Capa 2
            nn.Linear(in_features = 512, out_features = 256),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Capa 3
            nn.Linear(in_features = 256, out_features = 10)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

num_train_batches = len(train_loader)
num_valid_batches = len(valid_loader)
print(f'num_train_batches={num_train_batches}')
print(f'num_valid_batches={num_valid_batches}')
# Out:
# num_train_batches=600
# num_valid_batches=100

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
# Ejemplo: pasar encoder a tu modelo Clasificadora con dropout fijo en la clasificadora
# p_dropout_clf = 0.2
# clasificador = Clasificadora(p=p_dropout_clf, n1=128, n2=64, encoder=autoencoder.encoder)

# %%
# 5.6)
# learning_rate = 1e-4
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.Adam(clasificador.classifier.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#clasificador = clasificador.to(device)

# %%
# 5.8) y 5.9)
import torch
import json
import os

# Crear carpeta de resultados si no existe
os.makedirs("resultados", exist_ok=True)

# Inicializar el modelo Clasificadora con el encoder del Autoencoder preentrenado
p_dropout_clf = 0.2
learning_rate = 1e-3
model = Clasificadora(encoder=autoencoder.encoder)
model = model.to(device)

# 2) IMPORTANTE: Permitir que el encoder también se entrene (fine-tuning completo)
# Por defecto, todos los parámetros están habilitados para entrenamiento
# Si quisieras congelar el encoder, harías: 
# for param in model.encoder.parameters():
#     param.requires_grad = False

# 3) Configurar optimizador para TODOS los parámetros (encoder + clasificador)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=1e-08, weight_decay=0, amsgrad=False)

num_epochs = 40

list_avg_train_loss_incorrecta = []
list_avg_train_loss = []
list_avg_valid_loss = []
list_train_precision_incorrecta = []
list_train_precision = []
list_valid_precision = []

for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}\n-------------------------------')

    train_avg_loss_incorrecta, train_precision_incorrecta = train_loop(
        train_loader, model, loss_fn, optimizer
    )

    train_avg_loss, train_precision = eval_loop(
        train_loader, model, loss_fn
    )

    valid_avg_loss, valid_precision = eval_loop(
        valid_loader, model, loss_fn
    )

    list_avg_train_loss_incorrecta.append(train_avg_loss_incorrecta)
    list_avg_train_loss.append(train_avg_loss)
    list_avg_valid_loss.append(valid_avg_loss)
    list_train_precision_incorrecta.append(train_precision_incorrecta)
    list_train_precision.append(train_precision)
    list_valid_precision.append(valid_precision)

    print(f"📊 Epoch {epoch+1} Summary:")
    print(f"   Train Loss: {train_avg_loss:.4f} | Train Acc: {train_precision:.4f}")
    print(f"   Valid Loss: {valid_avg_loss:.4f} | Valid Acc: {valid_precision:.4f}\n")

print("✅ FINE-TUNING COMPLETO FINALIZADO!\n")

# ===============================================================
#          🔥 GUARDAR MODELO Y MÉTRICAS (FORMATO EXPERIMENTOS)
# ===============================================================

# 1) Guardar modelo (solo pesos)
model_path = "resultados/modelo.pt"
torch.save(model.state_dict(), model_path)

# 1b) Guardar checkpoint completo (pesos + optimizador + config)
checkpoint_path = "resultados/checkpoint.pt"
torch.save({
    "model_state_dict": model.state_dict(),
    "optimizer_state_dict": optimizer.state_dict(),
    "config": {
        "num_epochs": num_epochs,
        "learning_rate": learning_rate,
        "batch_size": batch_size,
        "p_dropout_clf": p_dropout_clf
    }
}, checkpoint_path)

# 2) Guardar TODAS las métricas
metrics_path = "resultados/metricas.pt"
torch.save({
    "train_loss_incorrecta": list_avg_train_loss_incorrecta,
    "train_loss": list_avg_train_loss,
    "valid_loss": list_avg_valid_loss,
    "train_precision_incorrecta": list_train_precision_incorrecta,
    "train_precision": list_train_precision,
    "valid_precision": list_valid_precision,
    "num_epochs": num_epochs,
    "learning_rate": learning_rate,
    "batch_size": batch_size,
    "p_dropout_clf": p_dropout_clf
}, metrics_path)

# 3) Guardar JSON con resumen
resumen = {
    "final_train_precision": list_train_precision[-1],
    "final_valid_precision": list_valid_precision[-1],
    "final_valid_loss": list_avg_valid_loss[-1],
    "model_path": model_path,
    "checkpoint_path": checkpoint_path,
    "metrics_path": metrics_path
}

json_path = "resultados/resumen.json"
with open(json_path, "w") as f:
    json.dump(resumen, f, indent=4)

print("✔ Modelo guardado en:", model_path)
print("✔ Checkpoint guardado en:", checkpoint_path)
print("✔ Métricas guardadas en:", metrics_path)
print("✔ Resumen guardado en:", json_path)
# Out:
# Epoch 1
# -------------------------------
# @train_loop batch=    0 avrg_loss=2.325263 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.927779 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.738517 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.640257 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.585939 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.543512 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.511930 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.491545 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.470730 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.454551 processed samples= 90.2%
# @eval_loop avg_loss=0.306327 precision=88.5%
# @eval_loop avg_loss=0.340498 precision=87.1%
# 📊 Epoch 1 Summary:
#    Train Loss: 0.3063 | Train Acc: 0.8847
#    Valid Loss: 0.3405 | Valid Acc: 0.8705
#
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.341374 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.306115 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.299868 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.293481 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.293795 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.293932 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.293243 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.292423 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.290008 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.285808 processed samples= 90.2%
# @eval_loop avg_loss=0.213180 precision=92.2%
# @eval_loop avg_loss=0.258448 precision=90.8%
# 📊 Epoch 2 Summary:
#    Train Loss: 0.2132 | Train Acc: 0.9221
#    Valid Loss: 0.2584 | Valid Acc: 0.9082
#
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.214215 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.244529 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.246965 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.247524 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.246019 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.245704 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.243192 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.241644 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.241464 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.239887 processed samples= 90.2%
# @eval_loop avg_loss=0.181339 precision=93.5%
# @eval_loop avg_loss=0.236677 precision=91.4%
# 📊 Epoch 3 Summary:
#    Train Loss: 0.1813 | Train Acc: 0.9352
#    Valid Loss: 0.2367 | Valid Acc: 0.9144
#
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.249618 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.201657 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.206497 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.204736 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.207219 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.208445 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.208314 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.209795 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.209133 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.210048 processed samples= 90.2%
# @eval_loop avg_loss=0.157216 precision=94.1%
# @eval_loop avg_loss=0.231463 precision=91.8%
# 📊 Epoch 4 Summary:
#    Train Loss: 0.1572 | Train Acc: 0.9414
#    Valid Loss: 0.2315 | Valid Acc: 0.9176
#
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.152550 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.189027 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.193069 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.194706 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.194207 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.194755 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.194657 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.193440 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.192020 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.191622 processed samples= 90.2%
# @eval_loop avg_loss=0.142509 precision=94.8%
# @eval_loop avg_loss=0.221812 precision=92.3%
# 📊 Epoch 5 Summary:
#    Train Loss: 0.1425 | Train Acc: 0.9483
#    Valid Loss: 0.2218 | Valid Acc: 0.9226
#
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.161848 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.168202 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.171232 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.168259 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.166712 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.169266 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.169476 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.171369 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.170235 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.169739 processed samples= 90.2%
# @eval_loop avg_loss=0.122722 precision=95.6%
# @eval_loop avg_loss=0.217495 precision=92.4%
# 📊 Epoch 6 Summary:
#    Train Loss: 0.1227 | Train Acc: 0.9560
#    Valid Loss: 0.2175 | Valid Acc: 0.9241
#
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.117320 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.146147 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.149390 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.151138 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.150173 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.150325 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.152625 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.153786 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.153894 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.153664 processed samples= 90.2%
# @eval_loop avg_loss=0.111967 precision=95.8%
# @eval_loop avg_loss=0.229894 precision=92.0%
# 📊 Epoch 7 Summary:
#    Train Loss: 0.1120 | Train Acc: 0.9583
#    Valid Loss: 0.2299 | Valid Acc: 0.9203
#
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.122580 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.133547 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.137659 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.137355 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.137204 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.139217 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.140997 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.142689 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.142430 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.143281 processed samples= 90.2%
# @eval_loop avg_loss=0.093275 precision=96.7%
# @eval_loop avg_loss=0.224121 precision=92.6%
# 📊 Epoch 8 Summary:
#    Train Loss: 0.0933 | Train Acc: 0.9672
#    Valid Loss: 0.2241 | Valid Acc: 0.9256
#
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.081180 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.126211 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.120390 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.121281 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.126160 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.126344 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.128226 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.128702 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.129377 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.130275 processed samples= 90.2%
# @eval_loop avg_loss=0.080504 precision=97.1%
# @eval_loop avg_loss=0.232530 precision=92.4%
# 📊 Epoch 9 Summary:
#    Train Loss: 0.0805 | Train Acc: 0.9709
#    Valid Loss: 0.2325 | Valid Acc: 0.9238
#
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.130699 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.113805 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.117987 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.116116 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.114125 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.117032 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.116261 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.118447 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.119368 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.119625 processed samples= 90.2%
# @eval_loop avg_loss=0.067795 precision=97.6%
# @eval_loop avg_loss=0.233846 precision=92.8%
# 📊 Epoch 10 Summary:
#    Train Loss: 0.0678 | Train Acc: 0.9758
#    Valid Loss: 0.2338 | Valid Acc: 0.9279
#
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.059671 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.094784 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.098570 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.101383 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.100510 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.102195 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.103836 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.105355 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.105282 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.106010 processed samples= 90.2%
# @eval_loop avg_loss=0.058964 precision=98.0%
# @eval_loop avg_loss=0.239604 precision=92.9%
# 📊 Epoch 11 Summary:
#    Train Loss: 0.0590 | Train Acc: 0.9796
#    Valid Loss: 0.2396 | Valid Acc: 0.9288
#
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.141571 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.085735 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.085851 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.085521 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.087471 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.090555 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.092585 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.094282 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.095240 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.095657 processed samples= 90.2%
# @eval_loop avg_loss=0.055495 precision=98.1%
# @eval_loop avg_loss=0.243345 precision=92.7%
# 📊 Epoch 12 Summary:
#    Train Loss: 0.0555 | Train Acc: 0.9812
#    Valid Loss: 0.2433 | Valid Acc: 0.9274
#
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.048482 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.088603 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.088286 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.089446 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.090946 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.090317 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.091207 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.092212 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.092350 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.091701 processed samples= 90.2%
# @eval_loop avg_loss=0.044531 precision=98.4%
# @eval_loop avg_loss=0.267264 precision=92.8%
# 📊 Epoch 13 Summary:
#    Train Loss: 0.0445 | Train Acc: 0.9836
#    Valid Loss: 0.2673 | Valid Acc: 0.9275
#
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.023480 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.085437 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.081997 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.081755 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.084411 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.085686 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.085428 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.085606 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.086940 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.087744 processed samples= 90.2%
# @eval_loop avg_loss=0.040007 precision=98.7%
# @eval_loop avg_loss=0.265782 precision=92.5%
# 📊 Epoch 14 Summary:
#    Train Loss: 0.0400 | Train Acc: 0.9869
#    Valid Loss: 0.2658 | Valid Acc: 0.9249
#
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.066302 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.066765 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.072268 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.072703 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.074182 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.075801 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.075879 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.078032 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.079021 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.079766 processed samples= 90.2%
# @eval_loop avg_loss=0.041307 precision=98.6%
# @eval_loop avg_loss=0.274892 precision=92.5%
# 📊 Epoch 15 Summary:
#    Train Loss: 0.0413 | Train Acc: 0.9861
#    Valid Loss: 0.2749 | Valid Acc: 0.9250
#
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.059680 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.076759 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.070601 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.071548 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.071300 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.072181 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.072232 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.072375 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.073725 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.074851 processed samples= 90.2%
# @eval_loop avg_loss=0.031184 precision=99.0%
# @eval_loop avg_loss=0.292914 precision=92.7%
# 📊 Epoch 16 Summary:
#    Train Loss: 0.0312 | Train Acc: 0.9896
#    Valid Loss: 0.2929 | Valid Acc: 0.9268
#
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.047899 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.073523 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.070010 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.067415 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.069650 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.070199 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.071965 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.072005 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.073017 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.072510 processed samples= 90.2%
# @eval_loop avg_loss=0.030919 precision=99.0%
# @eval_loop avg_loss=0.288021 precision=92.6%
# 📊 Epoch 17 Summary:
#    Train Loss: 0.0309 | Train Acc: 0.9898
#    Valid Loss: 0.2880 | Valid Acc: 0.9264
#
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.183100 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.065531 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.060251 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.057607 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.060728 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.061657 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.062048 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.063852 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.064738 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.065595 processed samples= 90.2%
# @eval_loop avg_loss=0.032735 precision=98.9%
# @eval_loop avg_loss=0.297179 precision=92.3%
# 📊 Epoch 18 Summary:
#    Train Loss: 0.0327 | Train Acc: 0.9889
#    Valid Loss: 0.2972 | Valid Acc: 0.9228
#
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.099711 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.053404 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.053975 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.054752 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.056940 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.059791 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.060019 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.061499 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.062299 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.063547 processed samples= 90.2%
# @eval_loop avg_loss=0.027230 precision=99.1%
# @eval_loop avg_loss=0.279411 precision=92.6%
# 📊 Epoch 19 Summary:
#    Train Loss: 0.0272 | Train Acc: 0.9914
#    Valid Loss: 0.2794 | Valid Acc: 0.9262
#
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.071625 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.056745 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.057246 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.056069 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.056229 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.059254 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.058965 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.058716 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.058833 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.059049 processed samples= 90.2%
# @eval_loop avg_loss=0.019706 precision=99.4%
# @eval_loop avg_loss=0.316563 precision=92.9%
# 📊 Epoch 20 Summary:
#    Train Loss: 0.0197 | Train Acc: 0.9942
#    Valid Loss: 0.3166 | Valid Acc: 0.9286
#
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.039528 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.045072 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.047861 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.051299 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.054853 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.055056 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.054876 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.055551 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.056708 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.057017 processed samples= 90.2%
# @eval_loop avg_loss=0.020504 precision=99.4%
# @eval_loop avg_loss=0.318448 precision=92.6%
# 📊 Epoch 21 Summary:
#    Train Loss: 0.0205 | Train Acc: 0.9937
#    Valid Loss: 0.3184 | Valid Acc: 0.9256
#
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.017121 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.043983 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.047057 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.047610 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.047097 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.049169 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.050070 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.049656 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.050692 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.052551 processed samples= 90.2%
# @eval_loop avg_loss=0.020081 precision=99.4%
# @eval_loop avg_loss=0.302273 precision=92.7%
# 📊 Epoch 22 Summary:
#    Train Loss: 0.0201 | Train Acc: 0.9942
#    Valid Loss: 0.3023 | Valid Acc: 0.9273
#
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.062285 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.048744 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.045129 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.046714 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046197 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.047832 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.048737 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.049330 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.050244 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.049655 processed samples= 90.2%
# @eval_loop avg_loss=0.015780 precision=99.5%
# @eval_loop avg_loss=0.327299 precision=92.9%
# 📊 Epoch 23 Summary:
#    Train Loss: 0.0158 | Train Acc: 0.9951
#    Valid Loss: 0.3273 | Valid Acc: 0.9289
#
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.036554 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.048549 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.049565 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.047238 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.048266 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.049069 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.049136 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.048613 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.049268 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.049471 processed samples= 90.2%
# @eval_loop avg_loss=0.021471 precision=99.2%
# @eval_loop avg_loss=0.337091 precision=92.5%
# 📊 Epoch 24 Summary:
#    Train Loss: 0.0215 | Train Acc: 0.9924
#    Valid Loss: 0.3371 | Valid Acc: 0.9248
#
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.038842 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.049183 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.044679 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.045361 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046484 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.048380 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.048538 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.048905 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.050070 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.050500 processed samples= 90.2%
# @eval_loop avg_loss=0.019083 precision=99.4%
# @eval_loop avg_loss=0.318214 precision=92.6%
# 📊 Epoch 25 Summary:
#    Train Loss: 0.0191 | Train Acc: 0.9941
#    Valid Loss: 0.3182 | Valid Acc: 0.9264
#
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.063813 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.041622 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.043677 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.043168 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.043498 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.044614 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045579 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.045652 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.045774 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.045795 processed samples= 90.2%
# @eval_loop avg_loss=0.012385 precision=99.7%
# @eval_loop avg_loss=0.323159 precision=92.8%
# 📊 Epoch 26 Summary:
#    Train Loss: 0.0124 | Train Acc: 0.9966
#    Valid Loss: 0.3232 | Valid Acc: 0.9278
#
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.057392 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.036187 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.038562 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.044556 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.042580 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.041350 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.040633 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.040450 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.041075 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.042595 processed samples= 90.2%
# @eval_loop avg_loss=0.011052 precision=99.6%
# @eval_loop avg_loss=0.360540 precision=92.9%
# 📊 Epoch 27 Summary:
#    Train Loss: 0.0111 | Train Acc: 0.9964
#    Valid Loss: 0.3605 | Valid Acc: 0.9288
#
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.054370 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.049108 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.044304 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.043506 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.046688 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.045807 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.045158 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.044454 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.045381 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.045200 processed samples= 90.2%
# @eval_loop avg_loss=0.013367 precision=99.6%
# @eval_loop avg_loss=0.351580 precision=92.6%
# 📊 Epoch 28 Summary:
#    Train Loss: 0.0134 | Train Acc: 0.9955
#    Valid Loss: 0.3516 | Valid Acc: 0.9259
#
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.019454 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.045626 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.040911 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.040331 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.042268 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.042107 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.040684 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.039636 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.039334 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.039695 processed samples= 90.2%
# @eval_loop avg_loss=0.010247 precision=99.7%
# @eval_loop avg_loss=0.379769 precision=92.5%
# 📊 Epoch 29 Summary:
#    Train Loss: 0.0102 | Train Acc: 0.9971
#    Valid Loss: 0.3798 | Valid Acc: 0.9254
#
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.043884 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.038057 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.042850 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.043005 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.040302 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039675 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.040803 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.040426 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.039683 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.039800 processed samples= 90.2%
# @eval_loop avg_loss=0.008579 precision=99.7%
# @eval_loop avg_loss=0.395654 precision=92.5%
# 📊 Epoch 30 Summary:
#    Train Loss: 0.0086 | Train Acc: 0.9973
#    Valid Loss: 0.3957 | Valid Acc: 0.9252
#
# Epoch 31
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.093848 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.044910 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.039907 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.038108 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.039846 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.041117 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.042923 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.042368 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.043003 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.042451 processed samples= 90.2%
# @eval_loop avg_loss=0.010486 precision=99.7%
# @eval_loop avg_loss=0.369135 precision=92.7%
# 📊 Epoch 31 Summary:
#    Train Loss: 0.0105 | Train Acc: 0.9968
#    Valid Loss: 0.3691 | Valid Acc: 0.9265
#
# Epoch 32
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.104036 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.037816 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.035405 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.035408 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.034513 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.035285 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.036224 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.036213 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.036371 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.036600 processed samples= 90.2%
# @eval_loop avg_loss=0.009327 precision=99.7%
# @eval_loop avg_loss=0.373320 precision=92.5%
# 📊 Epoch 32 Summary:
#    Train Loss: 0.0093 | Train Acc: 0.9972
#    Valid Loss: 0.3733 | Valid Acc: 0.9245
#
# Epoch 33
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.042411 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.029450 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.028340 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.029980 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.031906 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.032035 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.033686 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.033826 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.035009 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.036206 processed samples= 90.2%
# @eval_loop avg_loss=0.010164 precision=99.7%
# @eval_loop avg_loss=0.397492 precision=92.4%
# 📊 Epoch 33 Summary:
#    Train Loss: 0.0102 | Train Acc: 0.9967
#    Valid Loss: 0.3975 | Valid Acc: 0.9237
#
# Epoch 34
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.068859 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.037527 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.035974 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.032825 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.033008 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.034998 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.035035 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.034542 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.035070 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.035519 processed samples= 90.2%
# @eval_loop avg_loss=0.006336 precision=99.8%
# @eval_loop avg_loss=0.391795 precision=92.4%
# 📊 Epoch 34 Summary:
#    Train Loss: 0.0063 | Train Acc: 0.9983
#    Valid Loss: 0.3918 | Valid Acc: 0.9240
#
# Epoch 35
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.044634 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.029181 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.032487 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.032246 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.036413 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.039601 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.038658 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.038548 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.038225 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.037864 processed samples= 90.2%
# @eval_loop avg_loss=0.006164 precision=99.8%
# @eval_loop avg_loss=0.380661 precision=92.5%
# 📊 Epoch 35 Summary:
#    Train Loss: 0.0062 | Train Acc: 0.9985
#    Valid Loss: 0.3807 | Valid Acc: 0.9254
#
# Epoch 36
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.069924 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.028521 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.026140 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.030005 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.033583 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.033318 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.033340 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.034259 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.035116 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.035365 processed samples= 90.2%
# @eval_loop avg_loss=0.007147 precision=99.8%
# @eval_loop avg_loss=0.357363 precision=92.5%
# 📊 Epoch 36 Summary:
#    Train Loss: 0.0071 | Train Acc: 0.9983
#    Valid Loss: 0.3574 | Valid Acc: 0.9249
#
# Epoch 37
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.046586 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.025240 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.026613 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.029878 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.031301 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.033349 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.034486 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.033418 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.032572 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.033898 processed samples= 90.2%
# @eval_loop avg_loss=0.006473 precision=99.8%
# @eval_loop avg_loss=0.387520 precision=92.7%
# 📊 Epoch 37 Summary:
#    Train Loss: 0.0065 | Train Acc: 0.9982
#    Valid Loss: 0.3875 | Valid Acc: 0.9272
#
# Epoch 38
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.011905 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.019514 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.022323 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.023440 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.026325 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.028955 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.029648 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.030899 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.031512 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.031783 processed samples= 90.2%
# @eval_loop avg_loss=0.005936 precision=99.9%
# @eval_loop avg_loss=0.381738 precision=92.7%
# 📊 Epoch 38 Summary:
#    Train Loss: 0.0059 | Train Acc: 0.9985
#    Valid Loss: 0.3817 | Valid Acc: 0.9265
#
# Epoch 39
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.029032 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.035945 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.035243 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.034885 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.034116 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.033066 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.032756 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.032474 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.033164 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.033955 processed samples= 90.2%
# @eval_loop avg_loss=0.004071 precision=99.9%
# @eval_loop avg_loss=0.399548 precision=92.7%
# 📊 Epoch 39 Summary:
#    Train Loss: 0.0041 | Train Acc: 0.9991
#    Valid Loss: 0.3995 | Valid Acc: 0.9274
#
# Epoch 40
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.029543 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.029068 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.029122 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.029249 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.030475 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.029764 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.029939 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.031160 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.031146 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.032180 processed samples= 90.2%
# @eval_loop avg_loss=0.004616 precision=99.9%
# @eval_loop avg_loss=0.401844 precision=92.7%
# 📊 Epoch 40 Summary:
#    Train Loss: 0.0046 | Train Acc: 0.9990
#    Valid Loss: 0.4018 | Valid Acc: 0.9270
#
# ✅ FINE-TUNING COMPLETO FINALIZADO!
#
# ✔ Modelo guardado en: resultados/modelo.pt
# ✔ Checkpoint guardado en: resultados/checkpoint.pt
# ✔ Métricas guardadas en: resultados/metricas.pt
# ✔ Resumen guardado en: resultados/resumen.json

# %%
# ...existing code...
import torch
import matplotlib.pyplot as plt
import os

# Cargar métricas guardadas
metrics_path = "resultados/metricas.pt"
metrics = torch.load(metrics_path, map_location="cpu")

list_avg_train_loss = metrics["train_loss"]
list_avg_valid_loss = metrics["valid_loss"]

os.makedirs("resultados", exist_ok=True)
plt.figure(figsize=(10, 6))

plt.plot(
    range(1, len(list_avg_train_loss) + 1),
    list_avg_train_loss,
    linestyle="--",
    color="tab:green",
    label="Train loss"
)

plt.plot(
    range(1, len(list_avg_valid_loss) + 1),
    list_avg_valid_loss,
    linestyle="-",
    color="tab:blue",
    label="Valid loss"
)

plt.title("Evolución del Loss – Fine tuning con codificador pre-entrenado")
plt.xlabel("Epoch")
plt.ylabel("Loss (Cross Entropy)")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("resultados/loss_from_file.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en resultados/loss_from_file.png")
# Out:
# ✔ Gráfico guardado en resultados/loss_from_file.png

# %%
import matplotlib.pyplot as plt
import os

os.makedirs("resultados", exist_ok=True)

plt.figure(figsize=(10, 6))

# Línea objetivo
plt.axhline(y=0.9, color="grey", linestyle="--")

# Colores tabulados (consistentes)
plt.plot(
    range(1, len(list_train_precision_incorrecta) + 1),
    list_train_precision_incorrecta,
    linestyle=":",
    color="tab:red",
    label="Train accuracy incorrecta"
)

plt.plot(
    range(1, len(list_train_precision) + 1),
    list_train_precision,
    linestyle="--",
    color="tab:green",
    label="Train accuracy"
)

plt.plot(
    range(1, len(list_valid_precision) + 1),
    list_valid_precision,
    linestyle="-",
    color="tab:blue",
    label="Valid accuracy"
)

plt.title("Evolución de Accuracy – Fine tunning con codificador pre-entrenado")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.xlim(-0.1, len(list_valid_precision) + 0.1)
plt.ylim(0.7, 1.0)

plt.legend()
plt.grid(True)
plt.tight_layout()

save_path = "resultados/accuracy.png"
plt.savefig(save_path, dpi=300)
plt.show()

print("✔ Gráfico de accuracy guardado en:", save_path)
# Out:
# ✔ Gráfico de accuracy guardado en: resultados/accuracy.png

# %%
import torch
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------------------------------------
#   1) Reconstruir y cargar el modelo entrenado desde carpeta "resultados"
# ---------------------------------------------------------
model_path = "resultados/modelo.pt"

# Se asume que la clase Clasificadora y el autoencoder ya están definidos en celdas anteriores
clasificador = Clasificadora(encoder=autoencoder.encoder).to(device)
clasificador.load_state_dict(torch.load(model_path, map_location=device))
clasificador.eval()

print("✔ Modelo cargado desde:", model_path)

# Nombres de clases para Fashion-MNIST
class_names = [
    "T-shirt", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# ---------------------------------------------------------
#   2) Obtener predicciones sobre conjunto VALID usando valid_loader
# ---------------------------------------------------------
y_true = []
y_pred = []

with torch.no_grad():
    for x, labels in valid_loader:
        x, labels = x.to(device), labels.to(device)

        outputs = clasificador(x)
        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ---------------------------------------------------------
#   3) Matriz de confusión (normalizada, paleta "magma")
# ---------------------------------------------------------
cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)

plt.style.use("seaborn-v0_8")
fig, ax = plt.subplots(figsize=(8, 8))

# Paleta más elegante y con buen contraste
cmap = "viridis"

disp = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=class_names)
disp.plot(cmap=cmap, values_format=".2f", ax=ax, colorbar=True)

# Sin líneas de grid
ax.grid(False)

ax.set_title("Matriz de Confusión\nFine tuning con codificador pre-entrenado\n sobre el conjunto de validación", fontsize=14, pad=20)
ax.set_xlabel("Predicted label", fontsize=12)
ax.set_ylabel("True label", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()

out_png = "resultados/matriz_confusion_5_11_bonita.png"
os.makedirs("resultados", exist_ok=True)
plt.savefig(out_png, dpi=300)
plt.show()

print("✔ Confusion matrix saved to:", out_png)
# Out:
# ✔ Modelo cargado desde: resultados/modelo.pt
# ✔ Confusion matrix saved to: resultados/matriz_confusion_5_11_bonita.png
