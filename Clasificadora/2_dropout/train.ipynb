# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchviz in /usr/local/lib/python3.12/dist-packages (0.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                ,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=11113
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
# Cargar únicamente los pesos del Autoencoder preentrenado
import torch
from torch import nn
# Debes tener la misma definición de Autoencoder que se usó al entrenar
from autoencoder import Autoencoder  # o copia la clase Autoencoder a tu notebook

checkpoint_path = "/content/loss_results.pt"
checkpoint = torch.load(checkpoint_path, map_location="cpu")

dropout_autoencoder = 0.2
autoencoder = Autoencoder(dropout=dropout_autoencoder)
autoencoder.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
class Clasificadora(nn.Module):
    def __init__(self, p, encoder=None):
        super().__init__()
        self._dropout = p

        self.encoder = encoder
        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),

            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = 256),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 2
            nn.Linear(in_features = 256, out_features = 128),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 2
            nn.Linear(in_features = 128, out_features = 64),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 3
            nn.Linear(in_features = 64, out_features = 10)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

num_train_batches = len(train_loader)
num_valid_batches = len(valid_loader)
print(f'num_train_batches={num_train_batches}')
print(f'num_valid_batches={num_valid_batches}')
# Out:
# num_train_batches=600
# num_valid_batches=100

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
# Ejemplo: pasar encoder a tu modelo Clasificadora con dropout fijo en la clasificadora
# p_dropout_clf = 0.2
# clasificador = Clasificadora(p=p_dropout_clf, n1=128, n2=64, encoder=autoencoder.encoder)

# %%
# 5.6)
#learning_rate = 1e-3
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.Adam(clasificador.classifier.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#clasificador = clasificador.to(device)

# %%
import torch
import torch.nn as nn
import json
import os
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# ---------------------------------------------------------
#   PARÁMETROS FIJOS DEL CLASIFICADOR
# ---------------------------------------------------------
learning_rate = 1e-3
num_epochs = 40
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss_fn = nn.CrossEntropyLoss()

# Valores de dropout a testear en la clasificadora
experimentos = {
    "Exp 1": {"p_dropout_clf": 0.2},
    "Exp 2": {"p_dropout_clf": 0.4},
    "Exp 3": {"p_dropout_clf": 0.6},
}


# Carpeta para guardar resultados
os.makedirs("experimentos_resultados", exist_ok=True)

# Diccionario donde se guarda TODO
resultados_globales = {}

# ---------------------------------------------------------
#   LOOP DE EXPERIMENTOS
# ---------------------------------------------------------
for nombre_exp, params in experimentos.items():
    print(f"\n============================")
    print(f"      EJECUTANDO {nombre_exp}")
    print(f"============================")

    p_dropout_clf = params["p_dropout_clf"]

    # Crear clasificador con el dropout actual
    clasificador = Clasificadora(
        p=p_dropout_clf,
        encoder=autoencoder.encoder
    ).to(device)

    optimizer = torch.optim.Adam(
        clasificador.classifier.parameters(),
        lr=learning_rate
    )

    # HISTORIA DE MÉTRICAS
    train_loss_incorrecta_hist = []
    train_precision_incorrecta_hist = []
    train_loss_hist = []
    valid_loss_hist = []
    train_acc_hist = []
    valid_acc_hist = []

    # ---------------------------------------------------------
    #                  ENTRENAMIENTO
    # ---------------------------------------------------------
    for epoch in range(num_epochs):
        print(f"EPOCH {epoch+1}/{num_epochs}")

        # (1) train_loop: devuelve las "incorrectas" (p. ej. loss tras update y acc tras update)
        train_loss_incorrecta, train_prec_incorrecta = train_loop(
            train_loader, clasificador, loss_fn, optimizer
        )

        # (2) eval en train (sin update) -> para medir train "eval"
        train_loss_eval, train_prec_eval = eval_loop(
            train_loader, clasificador, loss_fn
        )

        # (3) eval en valid
        valid_loss, valid_prec = eval_loop(
            valid_loader, clasificador, loss_fn
        )

        # Guardar en historiales
        train_loss_incorrecta_hist.append(train_loss_incorrecta)
        train_precision_incorrecta_hist.append(train_prec_incorrecta)
        train_loss_hist.append(train_loss_eval)
        train_acc_hist.append(train_prec_eval)
        valid_loss_hist.append(valid_loss)
        valid_acc_hist.append(valid_prec)

    # ---------------------------------------------------------
    #      GUARDAR LO NECESARIO PARA POSTERIOR USO
    # ---------------------------------------------------------
    # 1) Guardar modelo
    model_path = f"experimentos_resultados/{nombre_exp.replace(' ', '_').lower()}_model.pt"
    torch.save(clasificador.state_dict(), model_path)

    # 2) Guardar métricas (PyTorch)
    metrics_path = f"experimentos_resultados/{nombre_exp.replace(' ', '_').lower()}_metrics.pt"
    torch.save({
        "train_loss_incorrecta": train_loss_incorrecta_hist,
        "train_precision_incorrecta": train_precision_incorrecta_hist,
        "train_loss": train_loss_hist,
        "valid_loss": valid_loss_hist,
        "train_precision": train_acc_hist,
        "valid_precision": valid_acc_hist,
        "learning_rate": learning_rate,
        "p_dropout_clf": p_dropout_clf,
        "num_epochs": num_epochs
    }, metrics_path)

    # 3) Guardar entrada al JSON global
    resultados_globales[nombre_exp] = {
        "learning_rate": learning_rate,
        "p_dropout_clf": p_dropout_clf,
        "final_valid_precision": valid_acc_hist[-1],
        "final_valid_loss": valid_loss_hist[-1],
        "model_path": model_path,
        "metrics_path": metrics_path
    }

    print(f"✔ Modelo guardado en {model_path}")
    print(f"✔ Métricas guardadas en {metrics_path}")

# ---------------------------------------------------------
#      GUARDAR ARCHIVO JSON GLOBAL DE RESULTADOS
# ---------------------------------------------------------
json_path = "experimentos_resultados/resultados.json"
with open(json_path, "w") as f:
    json.dump(resultados_globales, f, indent=4)

print("\n============================")
print(" TODOS LOS EXPERIMENTOS FINALIZADOS ")
print("============================")
print(f"Resultados guardados en {json_path}")
# Out:
# ============================
#       EJECUTANDO Exp 1
# ============================
# EPOCH 1/40
# @train_loop batch=    0 avrg_loss=2.313757 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.255309 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=1.002685 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.895854 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.834954 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.778288 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.742007 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.713744 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.690500 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.673417 processed samples= 90.2%
# @eval_loop avg_loss=0.438484 precision=84.0%
# @eval_loop avg_loss=0.465127 precision=83.0%
# EPOCH 2/40
# @train_loop batch=    0 avrg_loss=0.533255 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.471640 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.479775 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.481912 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.485283 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.484207 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.483734 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.483043 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.480076 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.476780 processed samples= 90.2%
# @eval_loop avg_loss=0.384912 precision=86.0%
# @eval_loop avg_loss=0.417770 precision=85.0%
# EPOCH 3/40
# @train_loop batch=    0 avrg_loss=0.310647 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.450336 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.450895 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.440306 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.437932 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.441346 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.438184 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.436141 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.436693 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.435657 processed samples= 90.2%
# @eval_loop avg_loss=0.354095 precision=87.1%
# @eval_loop avg_loss=0.391655 precision=86.2%
# EPOCH 4/40
# @train_loop batch=    0 avrg_loss=0.353002 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.425928 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.418343 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.411312 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.412266 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.415131 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.414731 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.412991 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.411788 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.412059 processed samples= 90.2%
# @eval_loop avg_loss=0.322117 precision=88.2%
# @eval_loop avg_loss=0.360184 precision=87.0%
# EPOCH 5/40
# @train_loop batch=    0 avrg_loss=0.306807 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.384014 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.385065 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.388368 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.387192 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.388521 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.391103 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.392576 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.391353 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.392347 processed samples= 90.2%
# @eval_loop avg_loss=0.305406 precision=88.5%
# @eval_loop avg_loss=0.348966 precision=86.7%
# EPOCH 6/40
# @train_loop batch=    0 avrg_loss=0.428499 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.380973 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.382316 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.385526 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.388258 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.390292 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.386888 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.386512 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.384267 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.382763 processed samples= 90.2%
# @eval_loop avg_loss=0.308864 precision=88.5%
# @eval_loop avg_loss=0.358927 precision=87.3%
# EPOCH 7/40
# @train_loop batch=    0 avrg_loss=0.286176 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.366878 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.361588 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.362533 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.365060 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.366378 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.369784 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.370000 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.371347 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.370144 processed samples= 90.2%
# @eval_loop avg_loss=0.289900 precision=89.3%
# @eval_loop avg_loss=0.344538 precision=87.6%
# EPOCH 8/40
# @train_loop batch=    0 avrg_loss=0.411566 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.354263 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.345927 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.354744 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.359714 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.357929 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.361705 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.361621 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.362162 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.361887 processed samples= 90.2%
# @eval_loop avg_loss=0.298834 precision=88.6%
# @eval_loop avg_loss=0.351175 precision=86.7%
# EPOCH 9/40
# @train_loop batch=    0 avrg_loss=0.326351 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.345499 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.356555 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.355419 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.352728 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.352631 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.350193 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.350919 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.349815 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.349230 processed samples= 90.2%
# @eval_loop avg_loss=0.276882 precision=89.7%
# @eval_loop avg_loss=0.342091 precision=87.8%
# EPOCH 10/40
# @train_loop batch=    0 avrg_loss=0.265568 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.332147 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.351848 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.353510 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.359222 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.355489 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.355222 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.354599 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.353241 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.355019 processed samples= 90.2%
# @eval_loop avg_loss=0.270107 precision=90.0%
# @eval_loop avg_loss=0.330621 precision=88.0%
# EPOCH 11/40
# @train_loop batch=    0 avrg_loss=0.368937 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.323876 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.335274 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.339011 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.344097 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.345143 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.345840 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.344182 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.344380 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.343222 processed samples= 90.2%
# @eval_loop avg_loss=0.269470 precision=89.7%
# @eval_loop avg_loss=0.326994 precision=87.7%
# EPOCH 12/40
# @train_loop batch=    0 avrg_loss=0.319251 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.340428 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.335514 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.335477 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.335962 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.338491 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.335232 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.337196 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.338942 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.339598 processed samples= 90.2%
# @eval_loop avg_loss=0.267418 precision=89.9%
# @eval_loop avg_loss=0.339970 precision=87.8%
# EPOCH 13/40
# @train_loop batch=    0 avrg_loss=0.479635 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.330422 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.325046 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.327748 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.326426 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.330956 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.331979 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.331867 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.331339 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.331798 processed samples= 90.2%
# @eval_loop avg_loss=0.257035 precision=90.4%
# @eval_loop avg_loss=0.324660 precision=88.0%
# EPOCH 14/40
# @train_loop batch=    0 avrg_loss=0.320830 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.339705 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.323047 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.323126 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.326856 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.326101 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.327967 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.327355 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.326955 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.326600 processed samples= 90.2%
# @eval_loop avg_loss=0.260042 precision=90.1%
# @eval_loop avg_loss=0.333510 precision=88.1%
# EPOCH 15/40
# @train_loop batch=    0 avrg_loss=0.475874 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.325019 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.323621 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.317443 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.317527 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.318511 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.318977 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.319431 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.319211 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.320800 processed samples= 90.2%
# @eval_loop avg_loss=0.245840 precision=90.6%
# @eval_loop avg_loss=0.319923 precision=88.5%
# EPOCH 16/40
# @train_loop batch=    0 avrg_loss=0.432655 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.320436 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.314145 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.311932 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.314370 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.315279 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.314663 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.317365 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.315642 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.315854 processed samples= 90.2%
# @eval_loop avg_loss=0.240764 precision=91.0%
# @eval_loop avg_loss=0.317329 precision=88.7%
# EPOCH 17/40
# @train_loop batch=    0 avrg_loss=0.416337 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.320126 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.316159 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.311082 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.309443 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.308380 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.309733 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.312414 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.313946 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.315254 processed samples= 90.2%
# @eval_loop avg_loss=0.242058 precision=90.9%
# @eval_loop avg_loss=0.316397 precision=88.5%
# EPOCH 18/40
# @train_loop batch=    0 avrg_loss=0.420850 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.310398 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.313230 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.310427 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.316340 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.317242 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.317620 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.318337 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.315773 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.315874 processed samples= 90.2%
# @eval_loop avg_loss=0.233154 precision=91.3%
# @eval_loop avg_loss=0.316215 precision=88.4%
# EPOCH 19/40
# @train_loop batch=    0 avrg_loss=0.239925 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.298478 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.306195 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.308864 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.311629 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.315409 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.315573 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.314072 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.314097 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.310673 processed samples= 90.2%
# @eval_loop avg_loss=0.241002 precision=91.0%
# @eval_loop avg_loss=0.331802 precision=88.3%
# EPOCH 20/40
# @train_loop batch=    0 avrg_loss=0.418785 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.317701 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.308957 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.302338 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.302467 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.303479 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.300668 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.300683 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.303675 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.304326 processed samples= 90.2%
# @eval_loop avg_loss=0.240456 precision=90.6%
# @eval_loop avg_loss=0.314072 precision=88.3%
# EPOCH 21/40
# @train_loop batch=    0 avrg_loss=0.374738 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.296341 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.290805 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.296823 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.292992 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.297250 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.298388 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.298712 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.299120 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.299947 processed samples= 90.2%
# @eval_loop avg_loss=0.236961 precision=90.8%
# @eval_loop avg_loss=0.324856 precision=88.1%
# EPOCH 22/40
# @train_loop batch=    0 avrg_loss=0.226859 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.277067 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.294961 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.295747 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.296399 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.295152 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.295159 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.298241 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.298869 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.300268 processed samples= 90.2%
# @eval_loop avg_loss=0.225374 precision=91.3%
# @eval_loop avg_loss=0.312288 precision=88.7%
# EPOCH 23/40
# @train_loop batch=    0 avrg_loss=0.378859 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.301418 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.286716 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.289783 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.292191 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.292243 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.293499 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.294979 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.296119 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.297375 processed samples= 90.2%
# @eval_loop avg_loss=0.219511 precision=91.6%
# @eval_loop avg_loss=0.313518 precision=88.9%
# EPOCH 24/40
# @train_loop batch=    0 avrg_loss=0.290184 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.293022 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.298006 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.294219 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.287538 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.291810 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.297217 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.297573 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.297066 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.297300 processed samples= 90.2%
# @eval_loop avg_loss=0.248705 precision=90.5%
# @eval_loop avg_loss=0.345275 precision=87.7%
# EPOCH 25/40
# @train_loop batch=    0 avrg_loss=0.315332 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.292936 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.292918 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.297951 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.300611 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.302594 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.302701 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.301652 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.299838 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.297611 processed samples= 90.2%
# @eval_loop avg_loss=0.218852 precision=91.8%
# @eval_loop avg_loss=0.312311 precision=88.9%
# EPOCH 26/40
# @train_loop batch=    0 avrg_loss=0.321936 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.296780 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.300440 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.295264 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.292522 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.295724 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.297281 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.295852 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.296597 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.294786 processed samples= 90.2%
# @eval_loop avg_loss=0.224652 precision=91.6%
# @eval_loop avg_loss=0.321359 precision=88.9%
# EPOCH 27/40
# @train_loop batch=    0 avrg_loss=0.288507 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.301109 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.298080 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.293002 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.289237 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.287865 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.290207 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.290311 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.293627 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.294439 processed samples= 90.2%
# @eval_loop avg_loss=0.214935 precision=91.8%
# @eval_loop avg_loss=0.311535 precision=88.9%
# EPOCH 28/40
# @train_loop batch=    0 avrg_loss=0.292336 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.283360 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.284409 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.280027 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.284489 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.284499 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.285613 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.288239 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.288394 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.287285 processed samples= 90.2%
# @eval_loop avg_loss=0.229694 precision=91.4%
# @eval_loop avg_loss=0.328707 precision=88.7%
# EPOCH 29/40
# @train_loop batch=    0 avrg_loss=0.303242 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.297988 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.286491 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.281925 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.284317 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.285638 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.285486 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.285812 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.283171 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.283047 processed samples= 90.2%
# @eval_loop avg_loss=0.216975 precision=91.8%
# @eval_loop avg_loss=0.309906 precision=88.9%
# EPOCH 30/40
# @train_loop batch=    0 avrg_loss=0.284040 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.274036 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.282136 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.287071 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.283889 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.282816 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.283631 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.286025 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.285825 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.284986 processed samples= 90.2%
# @eval_loop avg_loss=0.218827 precision=91.7%
# @eval_loop avg_loss=0.312857 precision=88.8%
# EPOCH 31/40
# @train_loop batch=    0 avrg_loss=0.373331 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.266140 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.272242 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.276798 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.278924 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.278464 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.280564 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.280374 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.281292 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.282858 processed samples= 90.2%
# @eval_loop avg_loss=0.216967 precision=91.6%
# @eval_loop avg_loss=0.320845 precision=89.0%
# EPOCH 32/40
# @train_loop batch=    0 avrg_loss=0.172645 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.274110 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.265406 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.271450 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.276559 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.276262 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.278091 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.278188 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.279946 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.279526 processed samples= 90.2%
# @eval_loop avg_loss=0.215743 precision=91.9%
# @eval_loop avg_loss=0.316140 precision=89.0%
# EPOCH 33/40
# @train_loop batch=    0 avrg_loss=0.190819 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.271341 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.278654 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.278106 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.280894 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.277807 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.276989 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.278677 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.280235 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.280800 processed samples= 90.2%
# @eval_loop avg_loss=0.208747 precision=92.0%
# @eval_loop avg_loss=0.316034 precision=89.1%
# EPOCH 34/40
# @train_loop batch=    0 avrg_loss=0.245369 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.264964 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.266514 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.266487 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.264352 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.268266 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.269647 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.275182 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.274415 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.273790 processed samples= 90.2%
# @eval_loop avg_loss=0.210579 precision=91.9%
# @eval_loop avg_loss=0.310615 precision=88.9%
# EPOCH 35/40
# @train_loop batch=    0 avrg_loss=0.291497 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.273821 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.279197 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.280706 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.280457 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.280716 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.278314 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.274085 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.273729 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.275300 processed samples= 90.2%
# @eval_loop avg_loss=0.204142 precision=92.2%
# @eval_loop avg_loss=0.313022 precision=89.4%
# EPOCH 36/40
# @train_loop batch=    0 avrg_loss=0.247527 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.278191 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.264692 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.265272 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.271491 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.272456 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.275644 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.271726 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.271991 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.273512 processed samples= 90.2%
# @eval_loop avg_loss=0.195631 precision=92.7%
# @eval_loop avg_loss=0.300900 precision=89.6%
# EPOCH 37/40
# @train_loop batch=    0 avrg_loss=0.193075 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.254251 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.254972 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.260191 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.263534 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.266528 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.269935 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.271862 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.271933 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.271595 processed samples= 90.2%
# @eval_loop avg_loss=0.200496 precision=92.5%
# @eval_loop avg_loss=0.305566 precision=89.7%
# EPOCH 38/40
# @train_loop batch=    0 avrg_loss=0.250948 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.281748 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.281579 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.278634 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.274213 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.275555 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.273824 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.274290 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.272086 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.272938 processed samples= 90.2%
# @eval_loop avg_loss=0.218675 precision=91.7%
# @eval_loop avg_loss=0.333493 precision=89.0%
# EPOCH 39/40
# @train_loop batch=    0 avrg_loss=0.187326 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.269900 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.281332 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.281683 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.277758 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.272158 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.272387 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.272338 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.270678 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.269031 processed samples= 90.2%
# @eval_loop avg_loss=0.194180 precision=92.6%
# @eval_loop avg_loss=0.307453 precision=89.3%
# EPOCH 40/40
# @train_loop batch=    0 avrg_loss=0.312064 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.258724 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.258805 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.259766 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.266710 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.267193 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.267054 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.267855 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.266673 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.265592 processed samples= 90.2%
# @eval_loop avg_loss=0.188975 precision=92.7%
# @eval_loop avg_loss=0.305831 precision=89.3%
# ✔ Modelo guardado en experimentos_resultados/exp_1_model.pt
# ✔ Métricas guardadas en experimentos_resultados/exp_1_metrics.pt
#
# ============================
#       EJECUTANDO Exp 2
# ============================
# EPOCH 1/40
# @train_loop batch=    0 avrg_loss=2.280803 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.572078 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=1.257842 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=1.109261 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=1.026059 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.965208 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.919281 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.883686 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.857451 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.835177 processed samples= 90.2%
# @eval_loop avg_loss=0.490008 precision=81.7%
# @eval_loop avg_loss=0.507502 precision=81.3%
# EPOCH 2/40
# @train_loop batch=    0 avrg_loss=0.801276 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.639140 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.623194 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.614012 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.614169 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.612685 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.610699 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.611434 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.606545 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.604564 processed samples= 90.2%
# @eval_loop avg_loss=0.431243 precision=84.7%
# @eval_loop avg_loss=0.458654 precision=83.7%
# EPOCH 3/40
# @train_loop batch=    0 avrg_loss=0.436859 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.570154 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.564863 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.562126 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.558580 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.556304 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.552978 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.547144 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.551507 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.553481 processed samples= 90.2%
# @eval_loop avg_loss=0.395990 precision=85.6%
# @eval_loop avg_loss=0.420844 precision=84.5%
# EPOCH 4/40
# @train_loop batch=    0 avrg_loss=0.544330 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.546073 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.543565 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.530835 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.530982 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.532865 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.530735 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.529866 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.527450 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.524520 processed samples= 90.2%
# @eval_loop avg_loss=0.368418 precision=86.5%
# @eval_loop avg_loss=0.398254 precision=85.4%
# EPOCH 5/40
# @train_loop batch=    0 avrg_loss=0.478309 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.509836 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.519485 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.511884 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.516343 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.514715 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.515150 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.511499 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.508094 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.508656 processed samples= 90.2%
# @eval_loop avg_loss=0.358990 precision=87.0%
# @eval_loop avg_loss=0.391118 precision=86.0%
# EPOCH 6/40
# @train_loop batch=    0 avrg_loss=0.569282 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.537583 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.512773 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.501610 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.502143 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.497808 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.496870 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.497147 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.495453 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.494019 processed samples= 90.2%
# @eval_loop avg_loss=0.344848 precision=87.6%
# @eval_loop avg_loss=0.377996 precision=86.5%
# EPOCH 7/40
# @train_loop batch=    0 avrg_loss=0.434936 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.476564 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.481855 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.487792 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.490921 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.484962 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.482493 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.480843 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.480545 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.479151 processed samples= 90.2%
# @eval_loop avg_loss=0.350865 precision=87.2%
# @eval_loop avg_loss=0.388884 precision=85.8%
# EPOCH 8/40
# @train_loop batch=    0 avrg_loss=0.484631 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.489978 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.486348 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.481602 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.477978 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.480395 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.480607 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.477865 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.474026 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.475556 processed samples= 90.2%
# @eval_loop avg_loss=0.343837 precision=87.5%
# @eval_loop avg_loss=0.386050 precision=86.0%
# EPOCH 9/40
# @train_loop batch=    0 avrg_loss=0.304972 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.443810 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.462828 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.473979 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.471346 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.468850 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.468170 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.466884 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.467226 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.465030 processed samples= 90.2%
# @eval_loop avg_loss=0.334337 precision=88.2%
# @eval_loop avg_loss=0.384789 precision=86.6%
# EPOCH 10/40
# @train_loop batch=    0 avrg_loss=0.299722 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.442803 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.449051 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.454424 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.447322 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.451955 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.453199 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.454242 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.456114 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.456133 processed samples= 90.2%
# @eval_loop avg_loss=0.333736 precision=87.6%
# @eval_loop avg_loss=0.376024 precision=86.3%
# EPOCH 11/40
# @train_loop batch=    0 avrg_loss=0.357434 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.457236 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.442800 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.448441 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.443519 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.443580 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.443388 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.447883 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.447672 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.451820 processed samples= 90.2%
# @eval_loop avg_loss=0.316285 precision=88.5%
# @eval_loop avg_loss=0.363545 precision=87.0%
# EPOCH 12/40
# @train_loop batch=    0 avrg_loss=0.423806 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.452915 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.441071 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.439490 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.438381 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.437098 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.436231 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.439197 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.439899 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.443187 processed samples= 90.2%
# @eval_loop avg_loss=0.323861 precision=88.1%
# @eval_loop avg_loss=0.372625 precision=86.6%
# EPOCH 13/40
# @train_loop batch=    0 avrg_loss=0.439306 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.434110 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.439906 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.436552 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.440935 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.442754 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.443672 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.443216 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.441316 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.439060 processed samples= 90.2%
# @eval_loop avg_loss=0.318510 precision=88.4%
# @eval_loop avg_loss=0.365481 precision=87.1%
# EPOCH 14/40
# @train_loop batch=    0 avrg_loss=0.677493 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.445003 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.452447 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.446737 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.446760 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.440235 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.443574 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.441091 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.440534 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.438772 processed samples= 90.2%
# @eval_loop avg_loss=0.325848 precision=88.0%
# @eval_loop avg_loss=0.378848 precision=86.6%
# EPOCH 15/40
# @train_loop batch=    0 avrg_loss=0.548207 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.420209 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.418786 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.422420 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.424648 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.426334 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.429747 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.429223 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.431787 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.432488 processed samples= 90.2%
# @eval_loop avg_loss=0.319104 precision=88.8%
# @eval_loop avg_loss=0.365511 precision=87.3%
# EPOCH 16/40
# @train_loop batch=    0 avrg_loss=0.426311 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.418107 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.430710 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.433286 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.432395 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.427600 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.426175 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.426129 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.423614 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.423812 processed samples= 90.2%
# @eval_loop avg_loss=0.315883 precision=88.2%
# @eval_loop avg_loss=0.365844 precision=86.5%
# EPOCH 17/40
# @train_loop batch=    0 avrg_loss=0.368808 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.437435 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.422533 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.418701 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.421784 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.417966 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.419047 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.419977 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.419169 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.419539 processed samples= 90.2%
# @eval_loop avg_loss=0.313451 precision=88.8%
# @eval_loop avg_loss=0.367582 precision=87.5%
# EPOCH 18/40
# @train_loop batch=    0 avrg_loss=0.498836 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.410758 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.411184 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.416554 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.413006 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.411144 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.415291 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.415200 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.415535 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.417308 processed samples= 90.2%
# @eval_loop avg_loss=0.300483 precision=89.1%
# @eval_loop avg_loss=0.351810 precision=87.6%
# EPOCH 19/40
# @train_loop batch=    0 avrg_loss=0.437957 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.421881 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.413299 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.416433 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.414638 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.417458 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.417530 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.419560 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.418381 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.420223 processed samples= 90.2%
# @eval_loop avg_loss=0.296270 precision=89.2%
# @eval_loop avg_loss=0.351713 precision=87.6%
# EPOCH 20/40
# @train_loop batch=    0 avrg_loss=0.397138 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.407767 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.419836 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.414531 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.414299 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.415020 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.415489 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.419378 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.419040 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.420652 processed samples= 90.2%
# @eval_loop avg_loss=0.311892 precision=88.9%
# @eval_loop avg_loss=0.369380 precision=87.3%
# EPOCH 21/40
# @train_loop batch=    0 avrg_loss=0.296655 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.412332 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.417134 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.415374 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.411485 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.416128 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.417249 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.415299 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.410901 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.413412 processed samples= 90.2%
# @eval_loop avg_loss=0.300006 precision=89.3%
# @eval_loop avg_loss=0.354688 precision=87.6%
# EPOCH 22/40
# ...
# @eval_loop avg_loss=0.458371 precision=82.3%
# EPOCH 21/40
# @train_loop batch=    0 avrg_loss=0.762987 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.698943 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.701462 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.697611 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.695102 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.691602 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.694386 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.695928 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.697735 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.698820 processed samples= 90.2%
# @eval_loop avg_loss=0.464675 precision=81.6%
# @eval_loop avg_loss=0.491788 precision=80.8%
# EPOCH 22/40
# @train_loop batch=    0 avrg_loss=0.648673 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.725555 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.724751 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.724519 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.719645 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.711849 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.707292 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.708603 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.704923 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.705965 processed samples= 90.2%
# @eval_loop avg_loss=0.456144 precision=83.9%
# @eval_loop avg_loss=0.486125 precision=82.8%
# EPOCH 23/40
# @train_loop batch=    0 avrg_loss=0.671910 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.725205 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.705931 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.709943 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.707979 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.703732 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.702366 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.704867 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.704082 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.701258 processed samples= 90.2%
# @eval_loop avg_loss=0.430544 precision=84.3%
# @eval_loop avg_loss=0.458113 precision=83.3%
# EPOCH 24/40
# @train_loop batch=    0 avrg_loss=0.641599 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.676573 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.676455 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.677195 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.675253 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.680726 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.679513 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.689281 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.690520 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.687478 processed samples= 90.2%
# @eval_loop avg_loss=0.467976 precision=83.8%
# @eval_loop avg_loss=0.502276 precision=82.7%
# EPOCH 25/40
# @train_loop batch=    0 avrg_loss=0.659121 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.670133 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.669012 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.680861 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.684266 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.681728 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.686244 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.686079 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.684750 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.685386 processed samples= 90.2%
# @eval_loop avg_loss=0.428378 precision=84.9%
# @eval_loop avg_loss=0.457007 precision=83.9%
# EPOCH 26/40
# @train_loop batch=    0 avrg_loss=0.735195 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.689663 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.692780 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.692348 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.686845 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.688116 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.696508 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.696916 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.698647 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.696655 processed samples= 90.2%
# @eval_loop avg_loss=0.442981 precision=84.0%
# @eval_loop avg_loss=0.474243 precision=83.3%
# EPOCH 27/40
# @train_loop batch=    0 avrg_loss=0.723777 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.702033 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.707816 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.711231 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.708609 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.709147 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.713689 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.709592 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.707665 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.704991 processed samples= 90.2%
# @eval_loop avg_loss=0.427810 precision=84.1%
# @eval_loop avg_loss=0.456230 precision=83.0%
# EPOCH 28/40
# @train_loop batch=    0 avrg_loss=0.604941 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.660270 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.691054 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.699755 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.693323 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.690819 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.692358 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.696192 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.696960 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.696592 processed samples= 90.2%
# @eval_loop avg_loss=0.444693 precision=83.7%
# @eval_loop avg_loss=0.475572 precision=82.7%
# EPOCH 29/40
# @train_loop batch=    0 avrg_loss=0.695103 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.692993 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.686124 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.684182 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.687145 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.688037 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.689316 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.688249 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.689206 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.689382 processed samples= 90.2%
# @eval_loop avg_loss=0.430768 precision=83.6%
# @eval_loop avg_loss=0.458196 precision=82.9%
# EPOCH 30/40
# @train_loop batch=    0 avrg_loss=0.714396 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.686162 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.679698 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.676298 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.677163 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.683026 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.678476 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.680031 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.679475 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.682803 processed samples= 90.2%
# @eval_loop avg_loss=0.426560 precision=85.2%
# @eval_loop avg_loss=0.457040 precision=84.3%
# EPOCH 31/40
# @train_loop batch=    0 avrg_loss=0.533711 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.707066 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.705202 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.711592 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.711619 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.707347 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.707631 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.707262 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.712421 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.709082 processed samples= 90.2%
# @eval_loop avg_loss=0.433609 precision=84.8%
# @eval_loop avg_loss=0.464425 precision=83.9%
# EPOCH 32/40
# @train_loop batch=    0 avrg_loss=0.599720 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.716553 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.695281 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.690113 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.707502 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.712309 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.717654 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.718206 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.718792 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.718702 processed samples= 90.2%
# @eval_loop avg_loss=0.443325 precision=83.9%
# @eval_loop avg_loss=0.468037 precision=83.4%
# EPOCH 33/40
# @train_loop batch=    0 avrg_loss=0.788482 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.719921 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.726542 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.718066 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.718848 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.716435 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.712905 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.709208 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.710498 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.710914 processed samples= 90.2%
# @eval_loop avg_loss=0.438016 precision=85.1%
# @eval_loop avg_loss=0.470264 precision=84.3%
# EPOCH 34/40
# @train_loop batch=    0 avrg_loss=0.758037 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.673468 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.688069 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.685279 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.690351 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.694775 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.694419 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.695148 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.694549 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.696052 processed samples= 90.2%
# @eval_loop avg_loss=0.435632 precision=83.8%
# @eval_loop avg_loss=0.461955 precision=82.9%
# EPOCH 35/40
# @train_loop batch=    0 avrg_loss=0.945774 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.693265 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.694297 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.698328 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.698439 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.700972 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.703289 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.704077 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.710866 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.713348 processed samples= 90.2%
# @eval_loop avg_loss=0.435611 precision=84.3%
# @eval_loop avg_loss=0.462170 precision=83.2%
# EPOCH 36/40
# @train_loop batch=    0 avrg_loss=0.570000 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.678341 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.693686 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.706046 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.708246 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.703068 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.697578 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.700952 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.697475 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.695589 processed samples= 90.2%
# @eval_loop avg_loss=0.420061 precision=85.2%
# @eval_loop avg_loss=0.455377 precision=84.0%
# EPOCH 37/40
# @train_loop batch=    0 avrg_loss=0.628843 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.678935 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.677731 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.682889 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.686338 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.681667 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.679661 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.681060 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.683154 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.685849 processed samples= 90.2%
# @eval_loop avg_loss=0.457953 precision=84.7%
# @eval_loop avg_loss=0.484241 precision=83.9%
# EPOCH 38/40
# @train_loop batch=    0 avrg_loss=0.678846 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.704156 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.693286 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.686950 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.688481 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.691663 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.697944 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.698095 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.698740 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.697642 processed samples= 90.2%
# @eval_loop avg_loss=0.422990 precision=84.4%
# @eval_loop avg_loss=0.464607 precision=83.7%
# EPOCH 39/40
# @train_loop batch=    0 avrg_loss=0.603473 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.672957 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.688854 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.692511 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.692983 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.692229 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.690457 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.688579 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.684963 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.686277 processed samples= 90.2%
# @eval_loop avg_loss=0.436559 precision=85.3%
# @eval_loop avg_loss=0.470780 precision=84.2%
# EPOCH 40/40
# @train_loop batch=    0 avrg_loss=0.645083 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.680899 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.713832 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.702872 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.707908 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.704922 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.703482 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.703284 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.703471 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.704272 processed samples= 90.2%
# @eval_loop avg_loss=0.407214 precision=85.7%
# @eval_loop avg_loss=0.442256 precision=84.8%
# ✔ Modelo guardado en experimentos_resultados/exp_3_model.pt
# ✔ Métricas guardadas en experimentos_resultados/exp_3_metrics.pt
#
# ============================
#  TODOS LOS EXPERIMENTOS FINALIZADOS
# ============================
# Resultados guardados en experimentos_resultados/resultados.json

# %%
import torch
import matplotlib.pyplot as plt
import os

# ---------------------------------------------------------
#    ARCHIVOS DE MÉTRICAS GUARDADOS PARA LOS DROPOUTS
# ---------------------------------------------------------
ruta = "experimentos_resultados"

experimentos = {
    "Dropout = 0.2": os.path.join(ruta, "exp_1_metrics.pt"),
    "Dropout = 0.4": os.path.join(ruta, "exp_2_metrics.pt"),
    "Dropout = 0.6": os.path.join(ruta, "exp_3_metrics.pt")
}

# ---------------------------------------------------------
#    CARGA DE MÉTRICAS
# ---------------------------------------------------------
metricas = {}

for nombre, archivo in experimentos.items():
    if not os.path.exists(archivo):
        print(f"ERROR: No se encuentra {archivo}")
        continue

    data = torch.load(archivo)
    metricas[nombre] = {
        "train_loss": data["train_loss"],
        "valid_loss": data["valid_loss"]
    }

print("✔ Métricas cargadas correctamente\n")

# ---------------------------------------------------------
#     GRAFICAR LOSS vs EPOCH PARA LOS 3 EXPERIMENTOS
# ---------------------------------------------------------
plt.figure(figsize=(10, 6))

# Paleta fija: un color por experimento
colores = ["tab:blue", "tab:orange", "tab:green"]

for (nombre, datos), color in zip(metricas.items(), colores):
    plt.plot(datos["train_loss"], linestyle=":", color=color,
             label=f"{nombre} – Train loss")
    plt.plot(datos["valid_loss"], linestyle="-", color=color,
             label=f"{nombre} – Valid loss")

plt.title("Comparación de Loss (Train y Valid) entre Experimentos con Distinto Dropout")
plt.xlabel("Epoch")
plt.ylabel("Loss (Cross Entropy)")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("experimentos_resultados/loss_vs_epoch_dropout.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en: experimentos_resultados/loss_vs_epoch_dropout.png")
# Out:
# ✔ Métricas cargadas correctamente
# ✔ Gráfico guardado en: experimentos_resultados/loss_vs_epoch_dropout.png

# %%
import torch
import matplotlib.pyplot as plt
import os

# ---------------------------------------------------------
#    ARCHIVOS DE MÉTRICAS GUARDADOS DE CADA EXPERIMENTO
# ---------------------------------------------------------
ruta = "experimentos_resultados"

experimentos = {
    "Dropout = 0.2": os.path.join(ruta, "exp_1_metrics.pt"),
    "Dropout = 0.4": os.path.join(ruta, "exp_2_metrics.pt"),
    "Dropout = 0.6": os.path.join(ruta, "exp_3_metrics.pt")
}

# ---------------------------------------------------------
#    CARGA DE MÉTRICAS
# ---------------------------------------------------------
metricas = {}

for nombre, archivo in experimentos.items():
    if not os.path.exists(archivo):
        print(f"ERROR: No se encuentra {archivo}")
        continue

    data = torch.load(archivo)
    metricas[nombre] = {
        "train_prec": data["train_precision"],
        "valid_prec": data["valid_precision"]
    }

print("✔ Métricas de precisión cargadas correctamente\n")

# ---------------------------------------------------------
#     GRAFICAR PRECISIÓN vs EPOCH (Train y Valid)
# ---------------------------------------------------------
plt.figure(figsize=(10, 6))

# Paleta fija: un color por experimento
colores = ["tab:blue", "tab:orange", "tab:green"]

for (nombre, datos), color in zip(metricas.items(), colores):
    # Train en puntos
    plt.plot(datos["train_prec"], "o", color=color,
             label=f"{nombre} – Train accuracy")
    # Valid en línea sólida
    plt.plot(datos["valid_prec"], "-", color=color,
             label=f"{nombre} – Valid accuracy")

plt.title("Comparación de Precisión (Train y Valid) entre Experimentos de Dropout")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("experimentos_resultados/precision_vs_epoch_dropout.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en: experimentos_resultados/precision_vs_epoch_dropout.png")
# Out:
# ✔ Métricas de precisión cargadas correctamente
# ✔ Gráfico guardado en: experimentos_resultados/precision_vs_epoch_dropout.png

# %%
import torch
import json
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------------------------------------
#   1) Cargar JSON global con los resultados
# ---------------------------------------------------------
json_path = "experimentos_resultados/resultados.json"

with open(json_path, "r") as f:
    resultados = json.load(f)

# ---------------------------------------------------------
#   2) Seleccionar el mejor experimento por valid_precision
# ---------------------------------------------------------
mejor_exp = max(
    resultados.items(),
    key=lambda x: x[1]["final_valid_precision"]
)

nombre_exp, datos_exp = mejor_exp

print(f"\n✔ Mejor experimento: {nombre_exp}")
print(f"  - Dropout = {datos_exp['p_dropout_clf']}")
print(f"  - Accuracy valid final = {datos_exp['final_valid_precision']:.4f}")
print(f"  - Model path: {datos_exp['model_path']}")

# ---------------------------------------------------------
#   3) Cargar el modelo del mejor experimento
# ---------------------------------------------------------
# IMPORTANTE → Clasificadora NO usa n1/n2 ahora (está fija en tu código)
clasificador = Clasificadora(
    p=datos_exp["p_dropout_clf"],      # dropout correcto del JSON
    encoder=autoencoder.encoder        # reutilizamos el encoder del autoencoder
).to(device)

clasificador.load_state_dict(torch.load(datos_exp["model_path"], map_location=device))
clasificador.eval()

# ---------------------------------------------------------
#   4) Obtener predicciones sobre VALID para matriz de confusión
# ---------------------------------------------------------
y_true = []
y_pred = []

with torch.no_grad():
    for x, labels in valid_loader:
        x, labels = x.to(device), labels.to(device)
        outputs = clasificador(x)
        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ---------------------------------------------------------
#   5) Crear matriz de confusión
# ---------------------------------------------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")
plt.title(f"Matriz de Confusión – {nombre_exp} (Dropout={datos_exp['p_dropout_clf']})")
plt.tight_layout()

output_png = (
    "experimentos_resultados/"
    f"matriz_confusion_{nombre_exp.replace(' ', '_')}.png"
)
plt.savefig(output_png, dpi=300)
plt.show()

print(f"\n✔ Matriz de confusión guardada en: {output_png}")
# Out:
# ✔ Mejor experimento: Exp 1
#   - Dropout = 0.2
#   - Accuracy valid final = 0.8934
#   - Model path: experimentos_resultados/exp_1_model.pt
# ✔ Matriz de confusión guardada en: experimentos_resultados/matriz_confusion_Exp_1.png
