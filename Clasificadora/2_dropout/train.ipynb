# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# /bin/bash: línea 1: /home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/.venv/bin/pip3: no se puede ejecutar: no se ha encontrado el fichero requerido

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                #,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=8898
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
# Cargar únicamente los pesos del Autoencoder preentrenado
import torch
from torch import nn
# Debes tener la misma definición de Autoencoder que se usó al entrenar
from autoencoder import Autoencoder  # o copia la clase Autoencoder a tu notebook

checkpoint_path = "/home/usuario/Documentos/RedesNeuronales/RN-FinalProyect/Autoencoder/3_final/resultados/loss_results.pt"
checkpoint = torch.load(checkpoint_path, map_location="cpu")

dropout_autoencoder = 0.2
autoencoder = Autoencoder(dropout=dropout_autoencoder)
autoencoder.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
class Clasificadora(nn.Module):
    def __init__(self, p, encoder=None):
        super().__init__()
        self._dropout = p

        self.encoder = encoder
        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),
            
            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = 512),
            nn.ReLU(),
            nn.Dropout(p),
            
            # Capa 2
            nn.Linear(in_features = 512, out_features = 256),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 3
            nn.Linear(in_features = 256, out_features = 10)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

num_train_batches = len(train_loader)
num_valid_batches = len(valid_loader)
print(f'num_train_batches={num_train_batches}')
print(f'num_valid_batches={num_valid_batches}')
# Out:
# num_train_batches=600
# num_valid_batches=100

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
# Ejemplo: pasar encoder a tu modelo Clasificadora con dropout fijo en la clasificadora
# p_dropout_clf = 0.2
# clasificador = Clasificadora(p=p_dropout_clf, n1=128, n2=64, encoder=autoencoder.encoder)

# %%
# 5.6)
#learning_rate = 1e-3
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.Adam(clasificador.classifier.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#clasificador = clasificador.to(device)

# %%
import torch
import torch.nn as nn
import json
import os
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# ---------------------------------------------------------
#   PARÁMETROS FIJOS DEL CLASIFICADOR
# ---------------------------------------------------------
learning_rate = 1e-3
num_epochs = 40
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss_fn = nn.CrossEntropyLoss()

# Valores de dropout a testear en la clasificadora
experimentos = {
    "Exp 1": {"p_dropout_clf": 0.2},
    "Exp 2": {"p_dropout_clf": 0.4},
    "Exp 3": {"p_dropout_clf": 0.6},
}


# Carpeta para guardar resultados
os.makedirs("experimentos_resultados", exist_ok=True)

# Diccionario donde se guarda TODO
resultados_globales = {}

# ---------------------------------------------------------
#   LOOP DE EXPERIMENTOS
# ---------------------------------------------------------
for nombre_exp, params in experimentos.items():
    print(f"\n============================")
    print(f"      EJECUTANDO {nombre_exp}")
    print(f"============================")

    p_dropout_clf = params["p_dropout_clf"]

    # Crear clasificador con el dropout actual
    clasificador = Clasificadora(
        p=p_dropout_clf,
        encoder=autoencoder.encoder
    ).to(device)

    optimizer = torch.optim.Adam(
        clasificador.classifier.parameters(),
        lr=learning_rate
    )

    # HISTORIA DE MÉTRICAS
    train_loss_incorrecta_hist = []
    train_precision_incorrecta_hist = []
    train_loss_hist = []
    valid_loss_hist = []
    train_acc_hist = []
    valid_acc_hist = []

    # ---------------------------------------------------------
    #                  ENTRENAMIENTO
    # ---------------------------------------------------------
    for epoch in range(num_epochs):
        print(f"EPOCH {epoch+1}/{num_epochs}")

        # (1) train_loop: devuelve las "incorrectas" (p. ej. loss tras update y acc tras update)
        train_loss_incorrecta, train_prec_incorrecta = train_loop(
            train_loader, clasificador, loss_fn, optimizer
        )

        # (2) eval en train (sin update) -> para medir train "eval"
        train_loss_eval, train_prec_eval = eval_loop(
            train_loader, clasificador, loss_fn
        )

        # (3) eval en valid
        valid_loss, valid_prec = eval_loop(
            valid_loader, clasificador, loss_fn
        )

        # Guardar en historiales
        train_loss_incorrecta_hist.append(train_loss_incorrecta)
        train_precision_incorrecta_hist.append(train_prec_incorrecta)
        train_loss_hist.append(train_loss_eval)
        train_acc_hist.append(train_prec_eval)
        valid_loss_hist.append(valid_loss)
        valid_acc_hist.append(valid_prec)

    # ---------------------------------------------------------
    #      GUARDAR LO NECESARIO PARA POSTERIOR USO
    # ---------------------------------------------------------
    # 1) Guardar modelo
    model_path = f"experimentos_resultados/{nombre_exp.replace(' ', '_').lower()}_model.pt"
    torch.save(clasificador.state_dict(), model_path)

    # 2) Guardar métricas (PyTorch)
    metrics_path = f"experimentos_resultados/{nombre_exp.replace(' ', '_').lower()}_metrics.pt"
    torch.save({
        "train_loss_incorrecta": train_loss_incorrecta_hist,
        "train_precision_incorrecta": train_precision_incorrecta_hist,
        "train_loss": train_loss_hist,
        "valid_loss": valid_loss_hist,
        "train_precision": train_acc_hist,
        "valid_precision": valid_acc_hist,
        "learning_rate": learning_rate,
        "p_dropout_clf": p_dropout_clf,
        "num_epochs": num_epochs
    }, metrics_path)

    # 3) Guardar entrada al JSON global
    resultados_globales[nombre_exp] = {
        "learning_rate": learning_rate,
        "p_dropout_clf": p_dropout_clf,
        "final_valid_precision": valid_acc_hist[-1],
        "final_valid_loss": valid_loss_hist[-1],
        "model_path": model_path,
        "metrics_path": metrics_path
    }

    print(f"✔ Modelo guardado en {model_path}")
    print(f"✔ Métricas guardadas en {metrics_path}")

# ---------------------------------------------------------
#      GUARDAR ARCHIVO JSON GLOBAL DE RESULTADOS
# ---------------------------------------------------------
json_path = "experimentos_resultados/resultados.json"
with open(json_path, "w") as f:
    json.dump(resultados_globales, f, indent=4)

print("\n============================")
print(" TODOS LOS EXPERIMENTOS FINALIZADOS ")
print("============================")
print(f"Resultados guardados en {json_path}")
# Out:
# ============================
#       EJECUTANDO Exp 1
# ============================
# EPOCH 1/40
# @train_loop batch=    0 avrg_loss=2.302322 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.965935 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.772365 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.686960 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.641751 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.602577 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.579360 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.562409 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.546760 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.533287 processed samples= 90.2%
# @eval_loop avg_loss=0.380778 precision=86.2%
# @eval_loop avg_loss=0.405285 precision=85.4%
# EPOCH 2/40
# @train_loop batch=    0 avrg_loss=0.597749 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.424840 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.414447 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.406012 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.403100 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.399062 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.394798 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.394771 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.394884 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.396858 processed samples= 90.2%
# @eval_loop avg_loss=0.322804 precision=88.0%
# @eval_loop avg_loss=0.355152 precision=87.1%
# EPOCH 3/40
# @train_loop batch=    0 avrg_loss=0.235169 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.366651 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.362578 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.369671 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.373556 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.373183 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.371400 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.373182 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.368998 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.366625 processed samples= 90.2%
# @eval_loop avg_loss=0.307917 precision=88.5%
# @eval_loop avg_loss=0.344253 precision=87.5%
# EPOCH 4/40
# @train_loop batch=    0 avrg_loss=0.240604 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.338113 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.351303 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.353287 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.357594 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.360715 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.362109 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.359743 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.359594 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.360140 processed samples= 90.2%
# @eval_loop avg_loss=0.288744 precision=89.2%
# @eval_loop avg_loss=0.323739 precision=88.5%
# EPOCH 5/40
# @train_loop batch=    0 avrg_loss=0.396778 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.346831 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.345617 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.341660 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.341069 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.345877 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.346793 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.344216 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.343230 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.343973 processed samples= 90.2%
# @eval_loop avg_loss=0.276465 precision=89.6%
# @eval_loop avg_loss=0.319444 precision=88.3%
# EPOCH 6/40
# @train_loop batch=    0 avrg_loss=0.388507 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.326674 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.327249 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.327739 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.325816 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.324984 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.321516 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.321279 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.323416 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.323827 processed samples= 90.2%
# @eval_loop avg_loss=0.273594 precision=89.8%
# @eval_loop avg_loss=0.309629 precision=88.7%
# EPOCH 7/40
# @train_loop batch=    0 avrg_loss=0.183270 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.341398 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.327757 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.322867 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.324304 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.328206 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.329925 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.330306 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.327945 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.328067 processed samples= 90.2%
# @eval_loop avg_loss=0.264297 precision=90.0%
# @eval_loop avg_loss=0.310031 precision=89.0%
# EPOCH 8/40
# @train_loop batch=    0 avrg_loss=0.395388 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.323373 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.324626 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.321175 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.316903 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.315825 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.316068 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.316198 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.315158 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.317580 processed samples= 90.2%
# @eval_loop avg_loss=0.254781 precision=90.2%
# @eval_loop avg_loss=0.299469 precision=88.7%
# EPOCH 9/40
# @train_loop batch=    0 avrg_loss=0.225243 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.307911 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.317505 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.308022 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.305045 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.305311 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.307999 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.310385 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.309640 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.309047 processed samples= 90.2%
# @eval_loop avg_loss=0.253685 precision=90.5%
# @eval_loop avg_loss=0.302090 precision=88.8%
# EPOCH 10/40
# @train_loop batch=    0 avrg_loss=0.448589 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.299508 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.303867 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.306709 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.306735 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.308635 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.309059 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.306025 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.305680 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.306488 processed samples= 90.2%
# @eval_loop avg_loss=0.263805 precision=90.2%
# @eval_loop avg_loss=0.317771 precision=88.8%
# EPOCH 11/40
# @train_loop batch=    0 avrg_loss=0.211866 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.311126 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.295954 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.297752 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.300198 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.300463 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.306833 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.305620 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.305601 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.304775 processed samples= 90.2%
# @eval_loop avg_loss=0.259082 precision=90.3%
# @eval_loop avg_loss=0.310350 precision=88.6%
# EPOCH 12/40
# @train_loop batch=    0 avrg_loss=0.209183 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.299594 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.298600 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.298557 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.296138 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.296246 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.297962 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.297619 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.299089 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.298617 processed samples= 90.2%
# @eval_loop avg_loss=0.248058 precision=90.6%
# @eval_loop avg_loss=0.296996 precision=89.3%
# EPOCH 13/40
# @train_loop batch=    0 avrg_loss=0.247735 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.294869 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.291199 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.298247 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.294276 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.294223 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.292098 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.292199 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.293603 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.294499 processed samples= 90.2%
# @eval_loop avg_loss=0.263720 precision=89.9%
# @eval_loop avg_loss=0.314647 precision=88.5%
# EPOCH 14/40
# @train_loop batch=    0 avrg_loss=0.235430 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.296207 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.289970 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.288373 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.290549 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.290634 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.286002 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.288064 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.287722 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.289137 processed samples= 90.2%
# @eval_loop avg_loss=0.240513 precision=90.9%
# @eval_loop avg_loss=0.292776 precision=89.3%
# EPOCH 15/40
# @train_loop batch=    0 avrg_loss=0.337506 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.301784 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.295389 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.293637 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.291613 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.290866 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.292261 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.291327 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.289436 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.290087 processed samples= 90.2%
# @eval_loop avg_loss=0.240285 precision=91.0%
# @eval_loop avg_loss=0.290468 precision=89.0%
# EPOCH 16/40
# @train_loop batch=    0 avrg_loss=0.176218 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.291894 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.286943 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.286395 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.283400 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.281928 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.281907 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.281421 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.281691 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.282785 processed samples= 90.2%
# @eval_loop avg_loss=0.234400 precision=91.2%
# @eval_loop avg_loss=0.286467 precision=89.6%
# EPOCH 17/40
# @train_loop batch=    0 avrg_loss=0.334135 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.279585 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.272968 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.270497 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.272835 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.276617 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.278322 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.279630 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.275903 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.279329 processed samples= 90.2%
# @eval_loop avg_loss=0.230101 precision=91.3%
# @eval_loop avg_loss=0.289896 precision=89.4%
# EPOCH 18/40
# @train_loop batch=    0 avrg_loss=0.269139 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.279844 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.272448 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.270626 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.276355 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.279328 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.279817 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.278785 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.280327 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.279468 processed samples= 90.2%
# @eval_loop avg_loss=0.234983 precision=91.1%
# @eval_loop avg_loss=0.291222 precision=89.4%
# EPOCH 19/40
# @train_loop batch=    0 avrg_loss=0.300330 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.271775 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.277744 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.281579 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.280368 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.283991 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.284595 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.286360 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.286433 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.284811 processed samples= 90.2%
# @eval_loop avg_loss=0.225878 precision=91.4%
# @eval_loop avg_loss=0.291357 precision=89.7%
# EPOCH 20/40
# @train_loop batch=    0 avrg_loss=0.180481 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.258353 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.268003 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.266188 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.267985 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.268439 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.273928 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.273035 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.274773 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.275912 processed samples= 90.2%
# @eval_loop avg_loss=0.230536 precision=91.3%
# @eval_loop avg_loss=0.292058 precision=89.4%
# EPOCH 21/40
# @train_loop batch=    0 avrg_loss=0.309909 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.273270 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.270649 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.272054 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.273979 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.276474 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.276103 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.275557 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.276962 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.276312 processed samples= 90.2%
# @eval_loop avg_loss=0.226087 precision=91.5%
# @eval_loop avg_loss=0.286350 precision=89.6%
# EPOCH 22/40
# @train_loop batch=    0 avrg_loss=0.352321 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.273252 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.278666 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.275944 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.272477 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.269952 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.273799 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.275140 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.273953 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.275509 processed samples= 90.2%
# @eval_loop avg_loss=0.210581 precision=92.0%
# @eval_loop avg_loss=0.276402 precision=90.0%
# EPOCH 23/40
# @train_loop batch=    0 avrg_loss=0.196946 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.270372 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.275821 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.277084 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.275570 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.274973 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.271015 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.268591 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.268253 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.268211 processed samples= 90.2%
# @eval_loop avg_loss=0.212978 precision=91.9%
# @eval_loop avg_loss=0.277685 precision=89.9%
# EPOCH 24/40
# @train_loop batch=    0 avrg_loss=0.274658 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.261742 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.248903 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.258012 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.259469 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.263549 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.263760 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.265848 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.267008 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.266122 processed samples= 90.2%
# @eval_loop avg_loss=0.210132 precision=91.8%
# @eval_loop avg_loss=0.275529 precision=90.1%
# EPOCH 25/40
# @train_loop batch=    0 avrg_loss=0.211539 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.267366 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.259880 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.257350 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.256320 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.261621 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.263927 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.265146 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.264050 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.264331 processed samples= 90.2%
# @eval_loop avg_loss=0.225521 precision=91.4%
# @eval_loop avg_loss=0.292806 precision=89.4%
# EPOCH 26/40
# @train_loop batch=    0 avrg_loss=0.277930 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.252549 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.272825 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.270643 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.268826 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.264490 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.266036 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.267244 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.265666 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.265355 processed samples= 90.2%
# @eval_loop avg_loss=0.222098 precision=91.6%
# @eval_loop avg_loss=0.287576 precision=89.6%
# EPOCH 27/40
# @train_loop batch=    0 avrg_loss=0.173876 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.259990 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.261180 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.260577 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.259602 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.255229 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.256400 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.259763 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.262548 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.263676 processed samples= 90.2%
# @eval_loop avg_loss=0.221442 precision=91.6%
# @eval_loop avg_loss=0.282613 precision=89.9%
# EPOCH 28/40
# @train_loop batch=    0 avrg_loss=0.317985 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.264287 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.258348 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.258687 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.259346 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.259117 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.258632 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.259344 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.258775 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.259033 processed samples= 90.2%
# @eval_loop avg_loss=0.205735 precision=92.3%
# @eval_loop avg_loss=0.277015 precision=90.1%
# EPOCH 29/40
# @train_loop batch=    0 avrg_loss=0.197676 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.276087 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.262865 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.261557 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.264549 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.263710 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.262851 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.261702 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.259568 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.258721 processed samples= 90.2%
# @eval_loop avg_loss=0.211659 precision=91.9%
# @eval_loop avg_loss=0.280097 precision=89.8%
# EPOCH 30/40
# @train_loop batch=    0 avrg_loss=0.251885 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.255392 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.260601 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.264649 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.261344 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.261011 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.258233 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.256621 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.258187 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.260828 processed samples= 90.2%
# @eval_loop avg_loss=0.210568 precision=91.9%
# @eval_loop avg_loss=0.278944 precision=90.0%
# EPOCH 31/40
# @train_loop batch=    0 avrg_loss=0.181111 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.253284 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.255574 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.252483 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.249168 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.250716 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.255369 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.257776 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.256268 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.256257 processed samples= 90.2%
# @eval_loop avg_loss=0.202516 precision=92.7%
# @eval_loop avg_loss=0.267776 precision=90.4%
# EPOCH 32/40
# @train_loop batch=    0 avrg_loss=0.117303 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.258677 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.262537 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.257493 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.260648 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.261383 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.262626 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.262932 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.262302 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.260685 processed samples= 90.2%
# @eval_loop avg_loss=0.221868 precision=91.6%
# @eval_loop avg_loss=0.287030 precision=89.6%
# EPOCH 33/40
# @train_loop batch=    0 avrg_loss=0.215031 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.237700 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.240798 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.251102 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.253596 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.252122 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.252609 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.252792 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.251056 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.252502 processed samples= 90.2%
# @eval_loop avg_loss=0.198538 precision=92.4%
# @eval_loop avg_loss=0.270098 precision=90.1%
# EPOCH 34/40
# @train_loop batch=    0 avrg_loss=0.329341 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.245595 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.241329 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.236391 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.242618 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.245764 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.247179 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.251204 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.253427 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.251596 processed samples= 90.2%
# @eval_loop avg_loss=0.224321 precision=91.4%
# @eval_loop avg_loss=0.292820 precision=89.6%
# EPOCH 35/40
# @train_loop batch=    0 avrg_loss=0.352655 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.261342 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.253740 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.256911 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.256179 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.256073 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.256277 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.254739 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.255503 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.256164 processed samples= 90.2%
# @eval_loop avg_loss=0.199660 precision=92.5%
# @eval_loop avg_loss=0.275791 precision=90.0%
# EPOCH 36/40
# @train_loop batch=    0 avrg_loss=0.278635 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.238202 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.241068 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.244366 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.247120 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.251900 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.254721 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.253964 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.253022 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.253414 processed samples= 90.2%
# @eval_loop avg_loss=0.197876 precision=92.7%
# @eval_loop avg_loss=0.270614 precision=90.2%
# EPOCH 37/40
# @train_loop batch=    0 avrg_loss=0.190158 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.238900 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.254811 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.249581 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.255874 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.253341 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.249315 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.247163 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.248126 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.248320 processed samples= 90.2%
# @eval_loop avg_loss=0.199588 precision=92.7%
# @eval_loop avg_loss=0.269589 precision=90.3%
# EPOCH 38/40
# @train_loop batch=    0 avrg_loss=0.240583 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.228527 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.237883 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.241313 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.241174 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.243497 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.245481 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.246295 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.244047 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.244707 processed samples= 90.2%
# @eval_loop avg_loss=0.200197 precision=92.7%
# @eval_loop avg_loss=0.271973 precision=90.4%
# EPOCH 39/40
# @train_loop batch=    0 avrg_loss=0.370801 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.240554 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.234038 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.240759 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.246228 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.244943 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.243657 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.242545 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.243997 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.246031 processed samples= 90.2%
# @eval_loop avg_loss=0.193177 precision=92.6%
# @eval_loop avg_loss=0.273192 precision=90.1%
# EPOCH 40/40
# @train_loop batch=    0 avrg_loss=0.333474 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.230974 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.238152 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.239743 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.247377 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.243599 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.246120 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.246478 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.247545 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.247674 processed samples= 90.2%
# @eval_loop avg_loss=0.199553 precision=92.4%
# @eval_loop avg_loss=0.278620 precision=90.2%
# ✔ Modelo guardado en experimentos_resultados/exp_1_model.pt
# ✔ Métricas guardadas en experimentos_resultados/exp_1_metrics.pt
#
# ============================
#       EJECUTANDO Exp 2
# ============================
# EPOCH 1/40
# @train_loop batch=    0 avrg_loss=2.280577 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.150323 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.925655 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.817429 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.753931 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.713552 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.681842 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.658730 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.641422 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.624996 processed samples= 90.2%
# @eval_loop avg_loss=0.398988 precision=85.3%
# @eval_loop avg_loss=0.416488 precision=84.5%
# EPOCH 2/40
# @train_loop batch=    0 avrg_loss=0.447744 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.498691 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.491770 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.478621 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.473302 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.468856 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.468252 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.463919 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.463424 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.461117 processed samples= 90.2%
# @eval_loop avg_loss=0.339572 precision=87.8%
# @eval_loop avg_loss=0.361234 precision=87.3%
# EPOCH 3/40
# @train_loop batch=    0 avrg_loss=0.517581 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.439198 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.441426 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.442735 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.441049 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.443424 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.445990 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.444765 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.441298 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.439153 processed samples= 90.2%
# @eval_loop avg_loss=0.349681 precision=87.7%
# @eval_loop avg_loss=0.371436 precision=87.2%
# EPOCH 4/40
# @train_loop batch=    0 avrg_loss=0.502470 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.430099 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.422973 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.425947 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.430491 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.430244 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.425244 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.425017 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.423931 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.424457 processed samples= 90.2%
# @eval_loop avg_loss=0.324002 precision=88.1%
# @eval_loop avg_loss=0.351759 precision=87.2%
# EPOCH 5/40
# @train_loop batch=    0 avrg_loss=0.263310 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.424834 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.417516 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.412195 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.412933 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.413437 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.415540 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.415155 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.411756 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.410853 processed samples= 90.2%
# @eval_loop avg_loss=0.311355 precision=88.6%
# @eval_loop avg_loss=0.338411 precision=87.8%
# EPOCH 6/40
# @train_loop batch=    0 avrg_loss=0.462422 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.428968 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.409056 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.406499 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.401995 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.401451 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.399420 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.401361 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.403407 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.402356 processed samples= 90.2%
# @eval_loop avg_loss=0.308221 precision=88.3%
# @eval_loop avg_loss=0.340226 precision=87.3%
# EPOCH 7/40
# @train_loop batch=    0 avrg_loss=0.339654 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.399585 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.391638 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.386240 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.388438 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.388717 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.389620 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.392660 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.390878 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.389577 processed samples= 90.2%
# @eval_loop avg_loss=0.296364 precision=89.4%
# @eval_loop avg_loss=0.328033 precision=88.2%
# EPOCH 8/40
# @train_loop batch=    0 avrg_loss=0.368742 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.383990 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.388823 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.395079 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.392768 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.387298 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.386537 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.388161 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.390852 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.391541 processed samples= 90.2%
# @eval_loop avg_loss=0.290794 precision=89.0%
# @eval_loop avg_loss=0.323345 precision=88.2%
# EPOCH 9/40
# @train_loop batch=    0 avrg_loss=0.394329 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.386535 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.397807 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.399710 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.396565 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.394570 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.394898 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.393500 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.392399 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.391874 processed samples= 90.2%
# @eval_loop avg_loss=0.297369 precision=89.6%
# @eval_loop avg_loss=0.326948 precision=88.9%
# EPOCH 10/40
# @train_loop batch=    0 avrg_loss=0.404285 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.380941 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.379585 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.389536 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.386343 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.382707 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.380414 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.378513 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.379236 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.380490 processed samples= 90.2%
# @eval_loop avg_loss=0.302307 precision=89.3%
# @eval_loop avg_loss=0.337612 precision=88.2%
# EPOCH 11/40
# @train_loop batch=    0 avrg_loss=0.436191 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.381900 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.371530 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.375330 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.373011 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.370463 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.375013 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.380778 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.380814 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.378440 processed samples= 90.2%
# @eval_loop avg_loss=0.287478 precision=90.0%
# @eval_loop avg_loss=0.321987 precision=88.8%
# EPOCH 12/40
# @train_loop batch=    0 avrg_loss=0.430440 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.365601 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.370573 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.372552 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.373573 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.376215 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.375587 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.372777 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.372971 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.372794 processed samples= 90.2%
# @eval_loop avg_loss=0.271938 precision=89.8%
# @eval_loop avg_loss=0.310940 precision=88.6%
# EPOCH 13/40
# @train_loop batch=    0 avrg_loss=0.255511 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.346292 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.352225 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.352771 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.353576 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.356401 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.358101 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.356892 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.359481 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.361185 processed samples= 90.2%
# @eval_loop avg_loss=0.302298 precision=89.0%
# @eval_loop avg_loss=0.339603 precision=87.6%
# EPOCH 14/40
# @train_loop batch=    0 avrg_loss=0.332708 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.358347 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.351432 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.351292 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.351497 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.356600 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.360334 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.360608 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.358644 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.361993 processed samples= 90.2%
# @eval_loop avg_loss=0.280071 precision=90.0%
# @eval_loop avg_loss=0.317087 precision=88.6%
# EPOCH 15/40
# @train_loop batch=    0 avrg_loss=0.327699 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.360344 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.366700 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.360655 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.357877 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.357021 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.357963 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.359352 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.359704 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.357538 processed samples= 90.2%
# @eval_loop avg_loss=0.280793 precision=90.1%
# @eval_loop avg_loss=0.314764 precision=89.0%
# EPOCH 16/40
# @train_loop batch=    0 avrg_loss=0.504007 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.358181 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.352613 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.355787 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.354519 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.355778 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.356975 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.359818 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.357827 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.358117 processed samples= 90.2%
# @eval_loop avg_loss=0.276908 precision=90.2%
# @eval_loop avg_loss=0.317478 precision=88.9%
# EPOCH 17/40
# @train_loop batch=    0 avrg_loss=0.529672 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.348999 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.342478 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.346769 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.345044 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.343331 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.345366 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.343387 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.343576 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.344937 processed samples= 90.2%
# @eval_loop avg_loss=0.274870 precision=90.1%
# @eval_loop avg_loss=0.315580 precision=88.7%
# EPOCH 18/40
# @train_loop batch=    0 avrg_loss=0.465727 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.357370 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.345719 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.346591 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.345184 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.344038 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.346101 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.345926 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.346577 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.346167 processed samples= 90.2%
# @eval_loop avg_loss=0.269610 precision=90.3%
# @eval_loop avg_loss=0.307741 precision=89.1%
# EPOCH 19/40
# @train_loop batch=    0 avrg_loss=0.366999 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.348095 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.346172 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.351402 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.353336 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.353481 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.352519 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.350990 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.350175 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.348813 processed samples= 90.2%
# @eval_loop avg_loss=0.274486 precision=90.2%
# @eval_loop avg_loss=0.314553 precision=88.8%
# EPOCH 20/40
# @train_loop batch=    0 avrg_loss=0.436402 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.353518 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.356386 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.349661 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.344175 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.346165 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.346174 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.342689 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.342789 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.341243 processed samples= 90.2%
# @eval_loop avg_loss=0.270398 precision=90.4%
# @eval_loop avg_loss=0.311855 precision=89.0%
# EPOCH 21/40
# @train_loop batch=    0 avrg_loss=0.277595 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.317256 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.332333 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.332401 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.335244 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.334218 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.337003 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.340595 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.342237 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.342626 processed samples= 90.2%
# @eval_loop avg_loss=0.277118 precision=90.2%
# @eval_loop avg_loss=0.316129 precision=88.7%
# EPOCH 22/40
# ...
# @eval_loop avg_loss=0.362578 precision=87.9%
# EPOCH 21/40
# @train_loop batch=    0 avrg_loss=0.428412 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.438365 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.438576 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.443298 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.449723 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.453123 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.448076 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.449236 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.447378 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.449463 processed samples= 90.2%
# @eval_loop avg_loss=0.338965 precision=89.0%
# @eval_loop avg_loss=0.367168 precision=87.9%
# EPOCH 22/40
# @train_loop batch=    0 avrg_loss=0.517979 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.420315 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.439406 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.446217 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.455017 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.456226 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.456274 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.458380 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.458979 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.459033 processed samples= 90.2%
# @eval_loop avg_loss=0.342257 precision=88.9%
# @eval_loop avg_loss=0.369244 precision=87.5%
# EPOCH 23/40
# @train_loop batch=    0 avrg_loss=0.486245 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.447129 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.448235 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.447580 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.450302 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.450575 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.448169 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.448349 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.447081 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.445851 processed samples= 90.2%
# @eval_loop avg_loss=0.331643 precision=89.2%
# @eval_loop avg_loss=0.360449 precision=87.7%
# EPOCH 24/40
# @train_loop batch=    0 avrg_loss=0.427213 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.452389 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.445939 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.440968 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.439841 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.440418 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.439682 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.442850 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.442864 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.441496 processed samples= 90.2%
# @eval_loop avg_loss=0.334267 precision=88.9%
# @eval_loop avg_loss=0.363852 precision=87.8%
# EPOCH 25/40
# @train_loop batch=    0 avrg_loss=0.342704 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.442381 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.430673 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.427980 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.434402 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.438903 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.437924 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.436920 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.439438 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.439553 processed samples= 90.2%
# @eval_loop avg_loss=0.357786 precision=88.3%
# @eval_loop avg_loss=0.385749 precision=87.3%
# EPOCH 26/40
# @train_loop batch=    0 avrg_loss=0.609191 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.454382 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.452534 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.443434 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.440616 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.441733 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.443478 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.441061 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.438628 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.437144 processed samples= 90.2%
# @eval_loop avg_loss=0.304824 precision=89.5%
# @eval_loop avg_loss=0.339003 precision=88.3%
# EPOCH 27/40
# @train_loop batch=    0 avrg_loss=0.556743 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.414736 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.428156 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.430772 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.438598 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.435529 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.436402 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.438603 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.438480 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.439613 processed samples= 90.2%
# @eval_loop avg_loss=0.350529 precision=88.7%
# @eval_loop avg_loss=0.381832 precision=87.5%
# EPOCH 28/40
# @train_loop batch=    0 avrg_loss=0.442573 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.425417 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.431188 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.449456 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.450235 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.447937 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.445057 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.442376 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.442728 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.443251 processed samples= 90.2%
# @eval_loop avg_loss=0.330643 precision=89.7%
# @eval_loop avg_loss=0.362680 precision=88.7%
# EPOCH 29/40
# @train_loop batch=    0 avrg_loss=0.583831 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.423010 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.437681 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.434312 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.433771 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.434566 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.437318 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.435195 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.433910 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.435456 processed samples= 90.2%
# @eval_loop avg_loss=0.349666 precision=88.1%
# @eval_loop avg_loss=0.381024 precision=87.1%
# EPOCH 30/40
# @train_loop batch=    0 avrg_loss=0.559182 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.459960 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.452606 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.447808 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.444790 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.437035 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.436257 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.436550 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.435703 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.438242 processed samples= 90.2%
# @eval_loop avg_loss=0.351249 precision=87.9%
# @eval_loop avg_loss=0.380889 precision=87.0%
# EPOCH 31/40
# @train_loop batch=    0 avrg_loss=0.345243 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.430875 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.436966 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.434666 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.436121 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.433115 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.431272 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.431640 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.433014 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.433093 processed samples= 90.2%
# @eval_loop avg_loss=0.321012 precision=89.5%
# @eval_loop avg_loss=0.353816 precision=88.2%
# EPOCH 32/40
# @train_loop batch=    0 avrg_loss=0.279407 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.447485 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.454638 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.444071 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.440495 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.439167 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.435542 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.433035 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.434637 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.436314 processed samples= 90.2%
# @eval_loop avg_loss=0.316992 precision=90.1%
# @eval_loop avg_loss=0.348734 precision=89.0%
# EPOCH 33/40
# @train_loop batch=    0 avrg_loss=0.381405 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.440649 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.430161 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.433940 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.431657 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.428126 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.424368 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.421241 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.426725 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.428334 processed samples= 90.2%
# @eval_loop avg_loss=0.354192 precision=88.6%
# @eval_loop avg_loss=0.384143 precision=87.2%
# EPOCH 34/40
# @train_loop batch=    0 avrg_loss=0.305265 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.437224 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.449378 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.443087 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.430777 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.430595 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.429449 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.427588 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.434204 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.434813 processed samples= 90.2%
# @eval_loop avg_loss=0.329761 precision=89.5%
# @eval_loop avg_loss=0.363816 precision=88.1%
# EPOCH 35/40
# @train_loop batch=    0 avrg_loss=0.466762 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.416685 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.423091 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.423627 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.426251 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.426426 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.424864 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.425041 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.424770 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.425653 processed samples= 90.2%
# @eval_loop avg_loss=0.320206 precision=89.7%
# @eval_loop avg_loss=0.355241 precision=88.5%
# EPOCH 36/40
# @train_loop batch=    0 avrg_loss=0.452193 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.409351 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.418230 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.421250 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.430263 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.427109 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.426111 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.426303 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.424787 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.426595 processed samples= 90.2%
# @eval_loop avg_loss=0.350878 precision=87.9%
# @eval_loop avg_loss=0.383781 precision=86.3%
# EPOCH 37/40
# @train_loop batch=    0 avrg_loss=0.441229 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.438876 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.426387 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.421005 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.419086 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.417542 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.420912 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.424085 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.423792 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.423090 processed samples= 90.2%
# @eval_loop avg_loss=0.321650 precision=89.6%
# @eval_loop avg_loss=0.356298 precision=88.3%
# EPOCH 38/40
# @train_loop batch=    0 avrg_loss=0.371627 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.433978 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.426376 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.428854 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.433182 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.433763 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.430584 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.431213 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.429016 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.426057 processed samples= 90.2%
# @eval_loop avg_loss=0.332089 precision=88.2%
# @eval_loop avg_loss=0.364096 precision=87.1%
# EPOCH 39/40
# @train_loop batch=    0 avrg_loss=0.500221 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.412228 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.414514 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.421843 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.418736 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.418260 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.418459 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.419446 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.419823 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.420578 processed samples= 90.2%
# @eval_loop avg_loss=0.324479 precision=89.4%
# @eval_loop avg_loss=0.357280 precision=88.1%
# EPOCH 40/40
# @train_loop batch=    0 avrg_loss=0.483018 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.418231 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.421179 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.413819 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.411856 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.417682 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.420668 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.419740 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.419537 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.418605 processed samples= 90.2%
# @eval_loop avg_loss=0.312867 precision=90.1%
# @eval_loop avg_loss=0.348395 precision=88.7%
# ✔ Modelo guardado en experimentos_resultados/exp_3_model.pt
# ✔ Métricas guardadas en experimentos_resultados/exp_3_metrics.pt
#
# ============================
#  TODOS LOS EXPERIMENTOS FINALIZADOS
# ============================
# Resultados guardados en experimentos_resultados/resultados.json

# %%
import torch
import matplotlib.pyplot as plt
import os

# ---------------------------------------------------------
#    ARCHIVOS DE MÉTRICAS GUARDADOS PARA LOS DROPOUTS
# ---------------------------------------------------------
ruta = "experimentos_resultados"

experimentos = {
    "Dropout = 0.2": os.path.join(ruta, "exp_1_metrics.pt"),
    "Dropout = 0.4": os.path.join(ruta, "exp_2_metrics.pt"),
    "Dropout = 0.6": os.path.join(ruta, "exp_3_metrics.pt")
}

# ---------------------------------------------------------
#    CARGA DE MÉTRICAS
# ---------------------------------------------------------
metricas = {}

for nombre, archivo in experimentos.items():
    if not os.path.exists(archivo):
        print(f"ERROR: No se encuentra {archivo}")
        continue

    data = torch.load(archivo)
    metricas[nombre] = {
        "train_loss": data["train_loss"],
        "valid_loss": data["valid_loss"]
    }

print("✔ Métricas cargadas correctamente\n")

# ---------------------------------------------------------
#     GRAFICAR LOSS vs EPOCH PARA LOS 3 EXPERIMENTOS
# ---------------------------------------------------------
plt.figure(figsize=(10, 6))

# Paleta fija: un color por experimento
colores = ["tab:blue", "tab:orange", "tab:green"]

for (nombre, datos), color in zip(metricas.items(), colores):
    plt.plot(datos["train_loss"], linestyle=":", color=color,
             label=f"{nombre} – Train loss")
    plt.plot(datos["valid_loss"], linestyle="-", color=color,
             label=f"{nombre} – Valid loss")

plt.title("Comparación de Loss (Train y Valid) entre Experimentos con Distinto Dropout")
plt.xlabel("Epoch")
plt.ylabel("Loss (Cross Entropy)")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("experimentos_resultados/loss_vs_epoch_dropout.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en: experimentos_resultados/loss_vs_epoch_dropout.png")
# Out:
# ✔ Métricas cargadas correctamente
# ✔ Gráfico guardado en: experimentos_resultados/loss_vs_epoch_dropout.png

# %%
import torch
import matplotlib.pyplot as plt
import os

# ---------------------------------------------------------
#    ARCHIVOS DE MÉTRICAS GUARDADOS DE CADA EXPERIMENTO
# ---------------------------------------------------------
ruta = "experimentos_resultados"

experimentos = {
    "Dropout = 0.2": os.path.join(ruta, "exp_1_metrics.pt"),
    "Dropout = 0.4": os.path.join(ruta, "exp_2_metrics.pt"),
    "Dropout = 0.6": os.path.join(ruta, "exp_3_metrics.pt")
}

# ---------------------------------------------------------
#    CARGA DE MÉTRICAS
# ---------------------------------------------------------
metricas = {}

for nombre, archivo in experimentos.items():
    if not os.path.exists(archivo):
        print(f"ERROR: No se encuentra {archivo}")
        continue

    data = torch.load(archivo)
    metricas[nombre] = {
        "train_prec": data["train_precision"],
        "valid_prec": data["valid_precision"]
    }

print("✔ Métricas de precisión cargadas correctamente\n")

# ---------------------------------------------------------
#     GRAFICAR PRECISIÓN vs EPOCH (Train y Valid)
# ---------------------------------------------------------
plt.figure(figsize=(10, 6))

# Paleta fija: un color por experimento
colores = ["tab:blue", "tab:orange", "tab:green"]

for (nombre, datos), color in zip(metricas.items(), colores):
    # Train en puntos
    #plt.plot(datos["train_prec"], ":", color=color,
             #label=f"{nombre} – Train accuracy")
    # Valid en línea sólida
    plt.plot(datos["valid_prec"], "-", color=color,
             label=f"{nombre} – Valid accuracy")

plt.title("Comparación de Precisión (Train y Valid) entre Experimentos de Dropout")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("experimentos_resultados/precision_vs_epoch_dropout.png", dpi=300)
plt.show()

print("✔ Gráfico guardado en: experimentos_resultados/precision_vs_epoch_dropout.png")
# Out:
# ✔ Métricas de precisión cargadas correctamente
# ✔ Gráfico guardado en: experimentos_resultados/precision_vs_epoch_dropout.png

# %%
import torch
import json
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------------------------------------------------------
#   1) Cargar JSON global con los resultados
# ---------------------------------------------------------
json_path = "experimentos_resultados/resultados.json"

with open(json_path, "r") as f:
    resultados = json.load(f)

# ---------------------------------------------------------
#   2) Seleccionar el mejor experimento por valid_precision
# ---------------------------------------------------------
mejor_exp = max(
    resultados.items(),
    key=lambda x: x[1]["final_valid_precision"]
)

nombre_exp, datos_exp = mejor_exp

print(f"\n✔ Mejor experimento: {nombre_exp}")
print(f"  - Dropout = {datos_exp['p_dropout_clf']}")
print(f"  - Accuracy valid final = {datos_exp['final_valid_precision']:.4f}")
print(f"  - Model path: {datos_exp['model_path']}")

# ---------------------------------------------------------
#   3) Cargar el modelo del mejor experimento
# ---------------------------------------------------------
# IMPORTANTE → Clasificadora NO usa n1/n2 ahora (está fija en tu código)
clasificador = Clasificadora(
    p=datos_exp["p_dropout_clf"],      # dropout correcto del JSON
    encoder=autoencoder.encoder        # reutilizamos el encoder del autoencoder
).to(device)

clasificador.load_state_dict(torch.load(datos_exp["model_path"], map_location=device))
clasificador.eval()

# ---------------------------------------------------------
#   4) Obtener predicciones sobre VALID para matriz de confusión
# ---------------------------------------------------------
y_true = []
y_pred = []

with torch.no_grad():
    for x, labels in valid_loader:
        x, labels = x.to(device), labels.to(device)
        outputs = clasificador(x)
        preds = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

# ---------------------------------------------------------
#   5) Crear matriz de confusión
# ---------------------------------------------------------
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", values_format="d")
plt.title(f"Matriz de Confusión – {nombre_exp} (Dropout={datos_exp['p_dropout_clf']})")
plt.tight_layout()

output_png = (
    "experimentos_resultados/"
    f"matriz_confusion_{nombre_exp.replace(' ', '_')}.png"
)
plt.savefig(output_png, dpi=300)
plt.show()

print(f"\n✔ Matriz de confusión guardada en: {output_png}")
# Out:
# ✔ Mejor experimento: Exp 1
#   - Dropout = 0.2
#   - Accuracy valid final = 0.9020
#   - Model path: experimentos_resultados/exp_1_model.pt
# ✔ Matriz de confusión guardada en: experimentos_resultados/matriz_confusion_Exp_1.png
