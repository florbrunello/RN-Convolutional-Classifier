# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchviz in /usr/local/lib/python3.12/dist-packages (0.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                #,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=11282
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
# Cargar únicamente los pesos del Autoencoder preentrenado
import torch
from torch import nn
# Debes tener la misma definición de Autoencoder que se usó al entrenar
from autoencoder import Autoencoder

checkpoint_path = "/content/loss_results.pt"
checkpoint = torch.load(checkpoint_path, map_location="cpu")

dropout_autoencoder = 0.2
autoencoder = Autoencoder(dropout=dropout_autoencoder)
autoencoder.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
class Clasificadora1(nn.Module):
    def __init__(self, p, n1, n2, encoder=None):
        super().__init__()
        self._dropout = p

        self.encoder = encoder
        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),

            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = n1),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 2
            nn.Linear(in_features = n1, out_features = n2),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 3
            nn.Linear(in_features = n2, out_features = 10)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x


class Clasificadora2(nn.Module):
    def __init__(self, p, n1, n2, n3, encoder=None):
        super().__init__()
        self._dropout = p

        self.encoder = encoder
        self.classifier = nn.Sequential(
            # Capa 0
            nn.Flatten(),

            # Capa 1
            nn.Linear(in_features = 64*7*7, out_features = n1),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 2
            nn.Linear(in_features = n1, out_features = n2),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 2
            nn.Linear(in_features = n2, out_features = n3),
            nn.ReLU(),
            nn.Dropout(p),

            # Capa 3
            nn.Linear(in_features = n3, out_features = 10)
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

num_train_batches = len(train_loader)
num_valid_batches = len(valid_loader)
print(f'num_train_batches={num_train_batches}')
print(f'num_valid_batches={num_valid_batches}')
# Out:
# num_train_batches=600
# num_valid_batches=100

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
# Ejemplo: pasar encoder a tu modelo Clasificadora con dropout fijo en la clasificadora
# p_dropout_clf = 0.2
# clasificador = Clasificadora(p=p_dropout_clf, n1=128, n2=64, encoder=autoencoder.encoder)

# %%
# 5.6)
#learning_rate = 1e-3
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.Adam(clasificador.classifier.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#clasificador = clasificador.to(device)

# %%
# -------------------------
# Configuración común
# -------------------------

p_dropout_clf = 0.2
learning_rate = 1e-3
num_epochs = 100
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
loss_fn = torch.nn.CrossEntropyLoss()  # Ejemplo, usar el que tengas
results_base_path = "results"

# Crear carpeta base si no existe
os.makedirs(results_base_path, exist_ok=True)

# -------------------------
# BLOQUE 1: Clasificadora 2 capas
# -------------------------
experimentos_2capas = {
    "Exp1": {"n1": 64,  "n2": 32},
    "Exp2": {"n1": 128, "n2": 64},
    "Exp3": {"n1": 512, "n2": 256}
}

results_2capas = {}
path_2capas = os.path.join(results_base_path, "2capas")
os.makedirs(path_2capas, exist_ok=True)

for nombre_exp, params in experimentos_2capas.items():
    print(f"\n============================")
    print(f"      EJECUTANDO 2CAPAS {nombre_exp}")
    print(f"============================")

    clf = Clasificadora1(
        p=p_dropout_clf,
        n1=params["n1"],
        n2=params["n2"],
        encoder=autoencoder.encoder
    ).to(device)

    optimizer = torch.optim.Adam(clf.classifier.parameters(), lr=learning_rate)

    # Inicializar listas de métricas
    list_avg_train_loss_incorrecta = []
    list_avg_train_loss = []
    list_avg_valid_loss = []
    list_train_precision_incorrecta = []
    list_train_precision = []
    list_valid_precision = []

    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch+1}/{num_epochs}")
        # TRAIN LOOP con métricas incorrectas
        train_avg_loss_incorrecta, train_precision_incorrecta = train_loop(train_loader, clf, loss_fn, optimizer)
        # TRAIN LOOP normal (solo para monitoreo)
        train_avg_loss, train_precision = eval_loop(train_loader, clf, loss_fn)
        # VALID LOOP
        valid_avg_loss, valid_precision = eval_loop(valid_loader, clf, loss_fn)

        # Guardar métricas
        list_avg_train_loss_incorrecta.append(train_avg_loss_incorrecta)
        list_avg_train_loss.append(train_avg_loss)
        list_avg_valid_loss.append(valid_avg_loss)
        list_train_precision_incorrecta.append(train_precision_incorrecta)
        list_train_precision.append(train_precision)
        list_valid_precision.append(valid_precision)

    # --------------------
    # Guardar resultados por experimento (métricas + config)
    # --------------------
    results_2capas[nombre_exp] = {
        "config": {
            "tipo_modelo": "Clasificadora1",
            "p_dropout_clf": p_dropout_clf,
            "learning_rate": learning_rate,
            "num_epochs": num_epochs,
            "n1": params["n1"],
            "n2": params["n2"]
        },
        "train_loss_incorrecta": list_avg_train_loss_incorrecta,
        "train_loss": list_avg_train_loss,
        "valid_loss": list_avg_valid_loss,
        "train_precision_incorrecta": list_train_precision_incorrecta,
        "train_precision": list_train_precision,
        "valid_precision": list_valid_precision
    }

    # Guardar métricas en archivo .pkl
    with open(os.path.join(path_2capas, f"{nombre_exp}_results.pkl"), "wb") as f:
        pickle.dump(results_2capas[nombre_exp], f)

    # Guardar pesos del modelo y estado del optimizador en .pt
    torch.save(
        {
            "config": results_2capas[nombre_exp]["config"],
            "model_state_dict": clf.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        },
        os.path.join(path_2capas, f"{nombre_exp}_model.pt"),
    )

    # Guardar resumen corto en JSON con últimos valores
    resumen = {
        "config": results_2capas[nombre_exp]["config"],
        "final_train_loss": list_avg_train_loss[-1],
        "final_valid_loss": list_avg_valid_loss[-1],
        "final_train_precision": list_train_precision[-1],
        "final_valid_precision": list_valid_precision[-1],
    }
    with open(os.path.join(path_2capas, f"{nombre_exp}_summary.json"), "w") as fjson:
        json.dump(resumen, fjson, indent=4)

print("✅ BLOQUE 2 CAPAS FINALIZADO")
# Out:
# ============================
#       EJECUTANDO 2CAPAS Exp1
# ============================
#
# Epoch 1/100
# @train_loop batch=    0 avrg_loss=2.302031 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.530972 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=1.229877 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=1.062632 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.964073 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.893937 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.843778 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.803371 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.772283 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.744048 processed samples= 90.2%
# @eval_loop avg_loss=0.401432 precision=85.7%
# @eval_loop avg_loss=0.420532 precision=85.2%
#
# Epoch 2/100
# @train_loop batch=    0 avrg_loss=0.492342 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.495118 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.486567 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.495834 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.490535 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.483532 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.479462 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.481087 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.479034 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.477774 processed samples= 90.2%
# @eval_loop avg_loss=0.370876 precision=87.0%
# @eval_loop avg_loss=0.394597 precision=86.1%
#
# Epoch 3/100
# @train_loop batch=    0 avrg_loss=0.523959 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.437546 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.433728 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.428026 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.432158 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.430444 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.430752 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.433022 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.431790 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.431911 processed samples= 90.2%
# @eval_loop avg_loss=0.318917 precision=88.4%
# @eval_loop avg_loss=0.350296 precision=87.5%
#
# Epoch 4/100
# @train_loop batch=    0 avrg_loss=0.323708 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.422892 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.418692 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.421454 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.418129 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.411002 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.410746 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.410834 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.411619 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.410812 processed samples= 90.2%
# @eval_loop avg_loss=0.326884 precision=88.1%
# @eval_loop avg_loss=0.359952 precision=87.3%
#
# Epoch 5/100
# @train_loop batch=    0 avrg_loss=0.374673 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.380615 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.385888 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.395021 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.393145 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.394942 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.395362 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.397262 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.397648 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.396548 processed samples= 90.2%
# @eval_loop avg_loss=0.303431 precision=88.6%
# @eval_loop avg_loss=0.342984 precision=87.5%
#
# Epoch 6/100
# @train_loop batch=    0 avrg_loss=0.309849 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.380014 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.387425 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.382494 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.385006 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.384283 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.382705 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.381880 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.381505 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.382579 processed samples= 90.2%
# @eval_loop avg_loss=0.309244 precision=88.5%
# @eval_loop avg_loss=0.344369 precision=87.2%
#
# Epoch 7/100
# @train_loop batch=    0 avrg_loss=0.388515 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.373778 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.381645 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.373160 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.372958 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.369781 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.369047 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.370583 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.369310 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.370475 processed samples= 90.2%
# @eval_loop avg_loss=0.273365 precision=89.8%
# @eval_loop avg_loss=0.317314 precision=88.7%
#
# Epoch 8/100
# @train_loop batch=    0 avrg_loss=0.274790 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.358662 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.362073 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.363855 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.364729 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.363781 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.363373 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.365690 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.366694 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.364954 processed samples= 90.2%
# @eval_loop avg_loss=0.276963 precision=89.7%
# @eval_loop avg_loss=0.321757 precision=88.4%
#
# Epoch 9/100
# @train_loop batch=    0 avrg_loss=0.254907 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.358996 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.347830 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.357038 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.361102 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.361158 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.359647 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.357893 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.357361 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.356486 processed samples= 90.2%
# @eval_loop avg_loss=0.279049 precision=89.7%
# @eval_loop avg_loss=0.323004 precision=88.3%
#
# Epoch 10/100
# @train_loop batch=    0 avrg_loss=0.477324 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.357430 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.361274 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.356929 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.353616 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.355207 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.354871 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.352665 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.352607 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.352263 processed samples= 90.2%
# @eval_loop avg_loss=0.261324 precision=90.2%
# @eval_loop avg_loss=0.307248 precision=88.9%
#
# Epoch 11/100
# @train_loop batch=    0 avrg_loss=0.380892 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.341740 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.338342 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.338268 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.341030 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.341574 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.344447 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.345665 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.346588 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.348064 processed samples= 90.2%
# @eval_loop avg_loss=0.267845 precision=90.0%
# @eval_loop avg_loss=0.316761 precision=88.6%
#
# Epoch 12/100
# @train_loop batch=    0 avrg_loss=0.237082 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.342875 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.341330 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.342933 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.341991 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.342525 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.342846 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.345457 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.345229 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.345997 processed samples= 90.2%
# @eval_loop avg_loss=0.258501 precision=90.3%
# @eval_loop avg_loss=0.310052 precision=88.8%
#
# Epoch 13/100
# @train_loop batch=    0 avrg_loss=0.372608 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.335870 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.337197 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.340756 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.337182 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.341545 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.342857 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.344918 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.342488 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.343333 processed samples= 90.2%
# @eval_loop avg_loss=0.259318 precision=90.3%
# @eval_loop avg_loss=0.310628 precision=88.8%
#
# Epoch 14/100
# @train_loop batch=    0 avrg_loss=0.291817 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.354942 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.344358 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.345483 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.343251 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.343682 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.342244 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.341542 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.338382 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.338666 processed samples= 90.2%
# @eval_loop avg_loss=0.252838 precision=90.7%
# @eval_loop avg_loss=0.303725 precision=89.2%
#
# Epoch 15/100
# @train_loop batch=    0 avrg_loss=0.511377 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.334163 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.333197 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.325237 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.328845 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.331490 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.330410 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.331850 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.332016 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.331817 processed samples= 90.2%
# @eval_loop avg_loss=0.246256 precision=90.9%
# @eval_loop avg_loss=0.298437 precision=89.3%
#
# Epoch 16/100
# @train_loop batch=    0 avrg_loss=0.395144 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.322542 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.324345 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.328289 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.329241 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.330910 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.331252 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.329742 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.332164 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.331280 processed samples= 90.2%
# @eval_loop avg_loss=0.244474 precision=90.8%
# @eval_loop avg_loss=0.298528 precision=89.5%
#
# Epoch 17/100
# @train_loop batch=    0 avrg_loss=0.341104 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.322456 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.326184 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.323215 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.329611 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.331193 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.330851 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.331883 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.330995 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.331453 processed samples= 90.2%
# @eval_loop avg_loss=0.271228 precision=89.5%
# @eval_loop avg_loss=0.327875 precision=87.8%
#
# Epoch 18/100
# @train_loop batch=    0 avrg_loss=0.399921 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.311202 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.318299 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.320158 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.320658 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.318833 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.323232 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.322173 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.322043 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.323978 processed samples= 90.2%
# @eval_loop avg_loss=0.230898 precision=91.3%
# @eval_loop avg_loss=0.289271 precision=89.5%
#
# Epoch 19/100
# @train_loop batch=    0 avrg_loss=0.429294 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.315540 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.318596 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.320975 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.324120 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.322330 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.321504 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.319718 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.319586 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.320614 processed samples= 90.2%
# @eval_loop avg_loss=0.247154 precision=90.8%
# @eval_loop avg_loss=0.302592 precision=89.4%
#
# Epoch 20/100
# @train_loop batch=    0 avrg_loss=0.407066 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.327851 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.328331 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.326464 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.320749 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.323944 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.324856 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.324092 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.322489 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.323477 processed samples= 90.2%
# @eval_loop avg_loss=0.254850 precision=90.6%
# @eval_loop avg_loss=0.317154 precision=88.7%
#
# Epoch 21/100
# @train_loop batch=    0 avrg_loss=0.320327 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.318004 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.317871 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.311440 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.309274 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.310015 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.313812 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.312453 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.312816 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.314906 processed samples= 90.2%
# @eval_loop avg_loss=0.238924 precision=90.9%
# @eval_loop avg_loss=0.296167 precision=89.3%
#
# Epoch 22/100
# @train_loop batch=    0 avrg_loss=0.218491 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.299728 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.310864 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.310039 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.309204 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.310352 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.315121 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.312846 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.314311 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.316166 processed samples= 90.2%
# @eval_loop avg_loss=0.234382 precision=91.3%
# @eval_loop avg_loss=0.288882 precision=89.7%
#
# Epoch 23/100
# @train_loop batch=    0 avrg_loss=0.342286 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.325233 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.315603 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.311612 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.314136 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.311392 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.312083 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.310957 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.311169 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.309045 processed samples= 90.2%
# @eval_loop avg_loss=0.242119 precision=90.9%
# @eval_loop avg_loss=0.302505 precision=89.3%
#
# Epoch 24/100
# @train_loop batch=    0 avrg_loss=0.306178 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.300510 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.306636 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.308709 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.308933 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.307357 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.307122 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.306325 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.308147 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.307809 processed samples= 90.2%
# @eval_loop avg_loss=0.226755 precision=91.7%
# @eval_loop avg_loss=0.282390 precision=89.9%
#
# Epoch 25/100
# @train_loop batch=    0 avrg_loss=0.292757 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.305447 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.303050 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.311696 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.314139 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.315340 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.311586 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.311068 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.311814 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.315044 processed samples= 90.2%
# @eval_loop avg_loss=0.239360 precision=91.0%
# @eval_loop avg_loss=0.305367 precision=89.3%
#
# Epoch 26/100
# @train_loop batch=    0 avrg_loss=0.377559 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.295388 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.300642 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.302027 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.303676 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.303558 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.307750 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.308664 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.307697 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.307398 processed samples= 90.2%
# @eval_loop avg_loss=0.229291 precision=91.4%
# @eval_loop avg_loss=0.291312 precision=89.8%
#
# Epoch 27/100
# @train_loop batch=    0 avrg_loss=0.274196 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.303492 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.310014 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.311067 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.311743 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.309635 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.309602 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.309995 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.307341 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.309569 processed samples= 90.2%
# @eval_loop avg_loss=0.243228 precision=90.8%
# @eval_loop avg_loss=0.300077 precision=89.0%
#
# Epoch 28/100
# @train_loop batch=    0 avrg_loss=0.337271 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.307603 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.310045 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.300138 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.301346 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.301863 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.303464 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.303546 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.304540 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.304925 processed samples= 90.2%
# @eval_loop avg_loss=0.218199 precision=91.7%
# @eval_loop avg_loss=0.285235 precision=89.8%
#
# Epoch 29/100
# @train_loop batch=    0 avrg_loss=0.264042 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.315887 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.306421 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.305097 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.304347 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.302409 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.304549 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.303808 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.305919 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.305718 processed samples= 90.2%
# @eval_loop avg_loss=0.239945 precision=91.0%
# @eval_loop avg_loss=0.301291 precision=89.4%
#
# Epoch 30/100
# @train_loop batch=    0 avrg_loss=0.330846 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.298244 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.295024 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.303520 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.300189 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.302814 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.302868 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.306270 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.306669 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.304349 processed samples= 90.2%
# @eval_loop avg_loss=0.230767 precision=91.2%
# @eval_loop avg_loss=0.296590 precision=89.3%
#
# Epoch 31/100
# @train_loop batch=    0 avrg_loss=0.211899 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.320777 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.302488 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.298773 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.299087 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.299291 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.298082 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.299590 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.299049 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.299630 processed samples= 90.2%
# @eval_loop avg_loss=0.239590 precision=90.8%
# @eval_loop avg_loss=0.304892 precision=89.2%
#
# Epoch 32/100
# @train_loop batch=    0 avrg_loss=0.264499 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.294936 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.291795 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.290148 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.294729 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.294965 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.294524 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.293882 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.294419 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.295735 processed samples= 90.2%
# @eval_loop avg_loss=0.226328 precision=91.5%
# @eval_loop avg_loss=0.288784 precision=89.5%
#
# Epoch 33/100
# @train_loop batch=    0 avrg_loss=0.412452 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.304303 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.289997 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.289439 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.293318 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.295098 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.296212 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.296743 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.296005 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.297542 processed samples= 90.2%
# @eval_loop avg_loss=0.230880 precision=91.2%
# @eval_loop avg_loss=0.304070 precision=89.4%
#
# Epoch 34/100
# @train_loop batch=    0 avrg_loss=0.212468 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.281419 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.288149 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.282275 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.284380 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.283309 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.284251 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.284806 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.288610 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.290834 processed samples= 90.2%
# @eval_loop avg_loss=0.220580 precision=91.7%
# @eval_loop avg_loss=0.295103 precision=89.7%
#
# Epoch 35/100
# @train_loop batch=    0 avrg_loss=0.375034 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.298632 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.303043 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.299092 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.297321 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.297962 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.297929 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.299080 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.297854 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.298124 processed samples= 90.2%
# @eval_loop avg_loss=0.214132 precision=92.0%
# @eval_loop avg_loss=0.282653 precision=89.9%
#
# Epoch 36/100
# @train_loop batch=    0 avrg_loss=0.200033 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.288291 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.288109 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.290673 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.293020 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.293959 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.296970 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.296277 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.297721 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.297185 processed samples= 90.2%
# @eval_loop avg_loss=0.214935 precision=91.8%
# @eval_loop avg_loss=0.287395 precision=89.6%
#
# Epoch 37/100
# @train_loop batch=    0 avrg_loss=0.355439 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.288500 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.288774 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.289427 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.287364 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.287849 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.290291 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.290051 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.288933 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.289372 processed samples= 90.2%
# @eval_loop avg_loss=0.208657 precision=92.2%
# @eval_loop avg_loss=0.281669 precision=90.0%
#
# Epoch 38/100
# @train_loop batch=    0 avrg_loss=0.332375 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.290578 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.288102 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.285009 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.287784 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.287796 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.287295 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.286405 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.288287 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.289352 processed samples= 90.2%
# @eval_loop avg_loss=0.228856 precision=91.6%
# @eval_loop avg_loss=0.293913 precision=89.8%
#
# Epoch 39/100
# @train_loop batch=    0 avrg_loss=0.341536 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.311555 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.294467 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.287466 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.286558 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.285922 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.288372 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.289636 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.291131 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.291844 processed samples= 90.2%
# @eval_loop avg_loss=0.205111 precision=92.3%
# @eval_loop avg_loss=0.281120 precision=90.0%
#
# Epoch 40/100
# @train_loop batch=    0 avrg_loss=0.279133 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.269280 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.276533 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.282029 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.284258 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.287048 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.289231 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.288244 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.289001 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.287827 processed samples= 90.2%
# @eval_loop avg_loss=0.213486 precision=92.0%
# @eval_loop avg_loss=0.283585 precision=89.8%
#
# Epoch 41/100
# @train_loop batch=    0 avrg_loss=0.382157 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.296851 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.280441 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.284350 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.287769 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.288674 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.285671 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.285458 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.287353 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.287137 processed samples= 90.2%
# @eval_loop avg_loss=0.208209 precision=92.2%
# @eval_loop avg_loss=0.282893 precision=89.9%
#
# Epoch 42/100
# @train_loop batch=    0 avrg_loss=0.257197 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.287178 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.291909 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.290283 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.289436 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.290091 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.290795 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.289449 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.289104 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.287814 processed samples= 90.2%
# @eval_loop avg_loss=0.205142 precision=92.2%
# @eval_loop avg_loss=0.280721 precision=90.0%
#
# Epoch 43/100
# @train_loop batch=    0 avrg_loss=0.321380 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.292494 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.298521 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.293521 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.295397 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.293394 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.291569 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.293071 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.293255 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.291304 processed samples= 90.2%
# @eval_loop avg_loss=0.200476 precision=92.4%
# @eval_loop avg_loss=0.278626 precision=90.2%
#
# Epoch 44/100
# @train_loop batch=    0 avrg_loss=0.292544 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.281867 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.277751 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.278627 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.282482 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.283855 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.282082 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.282553 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.282543 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.283478 processed samples= 90.2%
# @eval_loop avg_loss=0.209765 precision=92.2%
# @eval_loop avg_loss=0.281585 precision=90.2%
#
# Epoch 45/100
# @train_loop batch=    0 avrg_loss=0.304991 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.295990 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.283543 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.280599 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.280560 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.283611 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.284310 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.284154 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.282677 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.285352 processed samples= 90.2%
# @eval_loop avg_loss=0.205685 precision=92.1%
# @eval_loop avg_loss=0.285266 precision=90.0%
#
# Epoch 46/100
# @train_loop batch=    0 avrg_loss=0.372829 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.291049 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.291167 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.288483 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.287742 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.287411 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.287081 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.287754 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.287157 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.287785 processed samples= 90.2%
# @eval_loop avg_loss=0.207066 precision=92.1%
# @eval_loop avg_loss=0.283212 precision=89.9%
#
# Epoch 47/100
# @train_loop batch=    0 avrg_loss=0.216381 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.266414 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.272897 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.278024 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.280946 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.278677 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.281454 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.282195 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.283590 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.284609 processed samples= 90.2%
# @eval_loop avg_loss=0.232503 precision=90.6%
# @eval_loop avg_loss=0.308066 precision=88.5%
#
# Epoch 48/100
# @train_loop batch=    0 avrg_loss=0.213279 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.274801 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.268647 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.277433 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.278750 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.283624 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.282680 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.282211 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.281650 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.281649 processed samples= 90.2%
# @eval_loop avg_loss=0.206622 precision=92.2%
# @eval_loop avg_loss=0.284850 precision=89.9%
#
# Epoch 49/100
# @train_loop batch=    0 avrg_loss=0.183147 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.290717 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.281690 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.275689 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.276957 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.279883 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.281989 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.283180 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.283458 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.282053 processed samples= 90.2%
# @eval_loop avg_loss=0.209348 precision=92.3%
# @eval_loop avg_loss=0.291425 precision=89.8%
#
# Epoch 50/100
# @train_loop batch=    0 avrg_loss=0.284701 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.284433 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.275253 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.272620 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.276033 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.275916 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.278923 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.278847 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.276161 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.278433 processed samples= 90.2%
# @eval_loop avg_loss=0.203225 precision=92.3%
# @eval_loop avg_loss=0.281220 precision=89.9%
#
# Epoch 51/100
# @train_loop batch=    0 avrg_loss=0.230305 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.278359 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.281830 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.275666 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.274694 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.275360 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.281610 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.282351 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.283019 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.282942 processed samples= 90.2%
# @eval_loop avg_loss=0.195739 precision=92.7%
# @eval_loop avg_loss=0.280547 precision=90.0%
#
# Epoch 52/100
# @train_loop batch=    0 avrg_loss=0.251873 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.267117 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.273713 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.279054 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.280447 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.279533 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.276866 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.279878 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.280636 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.278674 processed samples= 90.2%
# @eval_loop avg_loss=0.212665 precision=91.8%
# @eval_loop avg_loss=0.293833 precision=89.6%
#
# Epoch 53/100
# @train_loop batch=    0 avrg_loss=0.245765 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.286722 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.282322 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.282667 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.279095 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.281178 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.279533 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.280447 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.281330 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.280721 processed samples= 90.2%
# @eval_loop avg_loss=0.217767 precision=91.7%
# @eval_loop avg_loss=0.306525 precision=89.4%
#
# Epoch 54/100
# @train_loop batch=    0 avrg_loss=0.282249 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.282663 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.288360 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.288053 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.284883 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.282930 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.277763 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.277739 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.276517 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.276336 processed samples= 90.2%
# @eval_loop avg_loss=0.202755 precision=92.3%
# @eval_loop avg_loss=0.291562 precision=89.7%
#
# Epoch 55/100
# @train_loop batch=    0 avrg_loss=0.526494 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.292996 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.276346 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.277016 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.277275 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.277840 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.275605 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.277039 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.274434 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.275198 processed samples= 90.2%
# @eval_loop avg_loss=0.200868 precision=92.4%
# @eval_loop avg_loss=0.282706 precision=89.9%
#
# Epoch 56/100
# @train_loop batch=    0 avrg_loss=0.268387 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.268953 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.264486 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.265750 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.265778 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.267054 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.271174 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.271705 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.271610 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.272903 processed samples= 90.2%
# @eval_loop avg_loss=0.194247 precision=92.7%
# @eval_loop avg_loss=0.277388 precision=90.2%
#
# Epoch 57/100
# @train_loop batch=    0 avrg_loss=0.259828 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.280379 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.286609 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.284922 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.278228 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.280372 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.276830 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.275978 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.275052 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.274875 processed samples= 90.2%
# @eval_loop avg_loss=0.196888 precision=92.6%
# @eval_loop avg_loss=0.285960 precision=90.0%
#
# Epoch 58/100
# @train_loop batch=    0 avrg_loss=0.330936 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.266774 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.274097 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.273661 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.274482 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.275116 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.276197 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.278384 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.276875 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.274575 processed samples= 90.2%
# @eval_loop avg_loss=0.188723 precision=93.0%
# @eval_loop avg_loss=0.277283 precision=90.4%
#
# Epoch 59/100
# @train_loop batch=    0 avrg_loss=0.404825 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.261409 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.272461 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.275329 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.278667 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.276108 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.275516 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.274368 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.271564 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.271622 processed samples= 90.2%
# @eval_loop avg_loss=0.204768 precision=92.2%
# @eval_loop avg_loss=0.286783 precision=89.8%
#
# Epoch 60/100
# @train_loop batch=    0 avrg_loss=0.321126 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.269430 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.273825 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.275237 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.274932 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.275190 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.273741 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.272272 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.269892 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.268419 processed samples= 90.2%
# @eval_loop avg_loss=0.211066 precision=91.8%
# @eval_loop avg_loss=0.304441 precision=89.3%
#
# Epoch 61/100
# @train_loop batch=    0 avrg_loss=0.237120 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.293185 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.278964 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.277441 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.275714 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.273235 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.272595 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.272000 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.274280 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.273085 processed samples= 90.2%
# @eval_loop avg_loss=0.195772 precision=92.6%
# @eval_loop avg_loss=0.280595 precision=90.1%
#
# Epoch 62/100
# @train_loop batch=    0 avrg_loss=0.195665 processed samples=  0.2%
# ...
# @train_loop batch=  480 avrg_loss=0.216313 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.214520 processed samples= 90.2%
# @eval_loop avg_loss=0.154985 precision=94.2%
# @eval_loop avg_loss=0.264353 precision=90.8%
#
# Epoch 81/100
# @train_loop batch=    0 avrg_loss=0.269765 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.200624 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.206722 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.213531 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.214972 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.215138 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.213116 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.214580 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.212584 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.213131 processed samples= 90.2%
# @eval_loop avg_loss=0.150900 precision=94.5%
# @eval_loop avg_loss=0.260136 precision=90.8%
#
# Epoch 82/100
# @train_loop batch=    0 avrg_loss=0.214673 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.220510 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.204973 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.203748 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.203038 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.207018 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.210319 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.211304 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.210461 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.209818 processed samples= 90.2%
# @eval_loop avg_loss=0.148734 precision=94.3%
# @eval_loop avg_loss=0.268172 precision=90.9%
#
# Epoch 83/100
# @train_loop batch=    0 avrg_loss=0.219725 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.180153 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.189197 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.199443 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.200199 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.204463 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.207241 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.207596 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.209265 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.209770 processed samples= 90.2%
# @eval_loop avg_loss=0.144397 precision=94.6%
# @eval_loop avg_loss=0.259269 precision=91.0%
#
# Epoch 84/100
# @train_loop batch=    0 avrg_loss=0.200857 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.195461 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.203034 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.209093 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.202604 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.203915 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.205519 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.205223 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.207612 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.208130 processed samples= 90.2%
# @eval_loop avg_loss=0.152222 precision=94.4%
# @eval_loop avg_loss=0.267694 precision=90.9%
#
# Epoch 85/100
# @train_loop batch=    0 avrg_loss=0.151088 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.203785 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.203242 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.203090 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.204730 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.207314 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.207906 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.208398 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.209689 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.210043 processed samples= 90.2%
# @eval_loop avg_loss=0.152744 precision=94.2%
# @eval_loop avg_loss=0.266040 precision=90.8%
#
# Epoch 86/100
# @train_loop batch=    0 avrg_loss=0.192969 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.207799 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.208095 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.213344 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.212467 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.213894 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.210104 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.209056 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.210105 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.209828 processed samples= 90.2%
# @eval_loop avg_loss=0.149345 precision=94.4%
# @eval_loop avg_loss=0.267443 precision=91.1%
#
# Epoch 87/100
# @train_loop batch=    0 avrg_loss=0.178303 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.200708 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.198942 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.200383 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.202434 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.202751 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.203989 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.203406 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.205388 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.207236 processed samples= 90.2%
# @eval_loop avg_loss=0.162129 precision=93.9%
# @eval_loop avg_loss=0.278428 precision=90.3%
#
# Epoch 88/100
# @train_loop batch=    0 avrg_loss=0.177167 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.198462 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.195410 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.200294 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.200469 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.199022 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.202048 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.202337 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.204587 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.204345 processed samples= 90.2%
# @eval_loop avg_loss=0.152294 precision=94.3%
# @eval_loop avg_loss=0.268303 precision=90.8%
#
# Epoch 89/100
# @train_loop batch=    0 avrg_loss=0.261527 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.199899 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.205398 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.209087 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.207857 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.206840 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.208844 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.208933 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.210188 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.208955 processed samples= 90.2%
# @eval_loop avg_loss=0.163543 precision=93.8%
# @eval_loop avg_loss=0.273023 precision=90.4%
#
# Epoch 90/100
# @train_loop batch=    0 avrg_loss=0.247346 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.203054 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.209589 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.208327 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.208167 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.209026 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.210097 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.209802 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.207595 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.205616 processed samples= 90.2%
# @eval_loop avg_loss=0.164779 precision=93.6%
# @eval_loop avg_loss=0.283620 precision=90.2%
#
# Epoch 91/100
# @train_loop batch=    0 avrg_loss=0.155860 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.199818 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.202742 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.200252 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.200652 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.207442 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.206663 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.206170 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.207897 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.208842 processed samples= 90.2%
# @eval_loop avg_loss=0.152435 precision=94.2%
# @eval_loop avg_loss=0.278751 precision=90.6%
#
# Epoch 92/100
# @train_loop batch=    0 avrg_loss=0.295271 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.202520 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.208180 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.204082 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.206938 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.209667 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.208488 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.206550 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.205747 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.204944 processed samples= 90.2%
# @eval_loop avg_loss=0.146763 precision=94.3%
# @eval_loop avg_loss=0.275256 precision=90.8%
#
# Epoch 93/100
# @train_loop batch=    0 avrg_loss=0.111079 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.194145 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.194384 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.194211 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.197042 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.197283 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.196615 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.199704 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.199619 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.200352 processed samples= 90.2%
# @eval_loop avg_loss=0.144375 precision=94.7%
# @eval_loop avg_loss=0.261443 precision=91.1%
#
# Epoch 94/100
# @train_loop batch=    0 avrg_loss=0.109355 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.197590 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.192390 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.192398 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.193917 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.193608 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.195792 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.196104 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.197696 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.197694 processed samples= 90.2%
# @eval_loop avg_loss=0.146084 precision=94.4%
# @eval_loop avg_loss=0.264809 precision=91.3%
#
# Epoch 95/100
# @train_loop batch=    0 avrg_loss=0.142834 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.198001 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.194093 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.200545 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.205605 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.204096 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.204718 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.206463 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.206183 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.204218 processed samples= 90.2%
# @eval_loop avg_loss=0.145541 precision=94.6%
# @eval_loop avg_loss=0.260058 precision=90.9%
#
# Epoch 96/100
# @train_loop batch=    0 avrg_loss=0.276170 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.190486 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.197491 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.197680 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.202933 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.201032 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.201682 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.201892 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.201992 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.202481 processed samples= 90.2%
# @eval_loop avg_loss=0.149070 precision=94.4%
# @eval_loop avg_loss=0.272308 precision=90.8%
#
# Epoch 97/100
# @train_loop batch=    0 avrg_loss=0.347545 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.211307 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.207437 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.209433 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.205522 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.205939 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.207130 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.207347 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.208451 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.207668 processed samples= 90.2%
# @eval_loop avg_loss=0.148307 precision=94.7%
# @eval_loop avg_loss=0.272330 precision=90.8%
#
# Epoch 98/100
# @train_loop batch=    0 avrg_loss=0.126246 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.186503 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.192616 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.194754 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.197732 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.200371 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.202561 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.204098 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.205276 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.206178 processed samples= 90.2%
# @eval_loop avg_loss=0.144154 precision=94.8%
# @eval_loop avg_loss=0.265430 precision=90.9%
#
# Epoch 99/100
# @train_loop batch=    0 avrg_loss=0.195091 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.201262 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.199543 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.202948 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.205692 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.208391 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.206706 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.204301 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.203368 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.202014 processed samples= 90.2%
# @eval_loop avg_loss=0.155713 precision=94.3%
# @eval_loop avg_loss=0.284085 precision=90.4%
#
# Epoch 100/100
# @train_loop batch=    0 avrg_loss=0.204741 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.199832 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.202692 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.202702 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.203371 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.203332 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.205017 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.204401 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.206275 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.204330 processed samples= 90.2%
# @eval_loop avg_loss=0.146691 precision=94.7%
# @eval_loop avg_loss=0.261517 precision=91.1%
# ✅ BLOQUE 2 CAPAS FINALIZADO

# %%
# -------------------------
# RESULTADOS FINALES
# -------------------------
print("\n============================")
print("   RESULTADOS FINALES BLOQUE 2 CAPAS")
print("============================")

final_results_2capas = {}

for exp in results_2capas:
    train_loss_final = results_2capas[exp]["train_loss"][-1]
    valid_loss_final = results_2capas[exp]["valid_loss"][-1]
    train_prec_final = results_2capas[exp]["train_precision"][-1]
    valid_prec_final = results_2capas[exp]["valid_precision"][-1]

    final_results_2capas[exp] = valid_prec_final

    print(f"\n--- {exp} ---")
    print(f"Train Loss final:       {train_loss_final:.4f}")
    print(f"Valid Loss final:       {valid_loss_final:.4f}")
    print(f"Train Precision final:  {train_prec_final:.4f}")
    print(f"Valid Precision final:  {valid_prec_final:.4f}")

# Elegir mejor experimento 2 capas
best_exp_2capas = max(final_results_2capas, key=final_results_2capas.get)
best_precision_2capas = final_results_2capas[best_exp_2capas]

print("\n============================")
print("   MEJOR EXPERIMENTO BLOQUE 2 CAPAS")
print("============================")
print(f"Ganador: {best_exp_2capas}")
print(f"Mejor Valid Precision: {best_precision_2capas:.4f}")
# Out:
# ============================
#    RESULTADOS FINALES BLOQUE 2 CAPAS
# ============================
#
# --- Exp1 ---
# Train Loss final:       0.1783
# Valid Loss final:       0.2885
# Train Precision final:  0.9321
# Valid Precision final:  0.9022
#
# --- Exp2 ---
# Train Loss final:       0.1502
# Valid Loss final:       0.2608
# Train Precision final:  0.9426
# Valid Precision final:  0.9091
#
# --- Exp3 ---
# Train Loss final:       0.1467
# Valid Loss final:       0.2615
# Train Precision final:  0.9475
# Valid Precision final:  0.9111
#
# ============================
#    MEJOR EXPERIMENTO BLOQUE 2 CAPAS
# ============================
# Ganador: Exp3
# Mejor Valid Precision: 0.9111

# %%
import matplotlib.pyplot as plt

# ----------------------------
#       GRÁFICO BLOQUE 2 CAPAS
# ----------------------------
exp_labels_2capas = {
    "Exp1": "Exp 1 (64-32)",
    "Exp2": "Exp 2 (128-64)",
    "Exp3": "Exp 3 (512-256)"
}

epoch = list(range(1, num_epochs + 1))

plt.figure(figsize=(8,5))
for exp in results_2capas:
    plt.plot(epoch, results_2capas[exp]["valid_loss"],
             label=f'{exp_labels_2capas[exp]} Valid loss', linestyle="-")
    plt.plot(epoch, results_2capas[exp]["train_loss"],
             label=f'{exp_labels_2capas[exp]} Train loss', linestyle=":")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Autoencoder + Clasificadora (2 capas)")
plt.legend()
plt.tight_layout()
plt.savefig("results/2capas/experimentos_loss_2capas.png")
plt.show()

# %%
import os
import pickle
import matplotlib.pyplot as plt

# ----------------------------
#      CARGA RESULTADOS
# ----------------------------

path_2 = "results/2capas/"
results_2capas = {}

if os.path.exists(path_2):
    for fname in os.listdir(path_2):
        if fname.endswith("_results.pkl"):
            exp_name = fname.replace("_results.pkl", "")
            with open(os.path.join(path_2, fname), "rb") as f:
                results_2capas[exp_name] = pickle.load(f)

exp_labels_2capas = {
    "Exp1": "Exp 1 (64-32)",
    "Exp2": "Exp 2 (128-64)",
    "Exp3": "Exp 3 (512-256)"
}

plt.figure(figsize=(8,5))

# Guardaremos el color usado para Exp3 para reutilizarlo
color_exp3 = None

for exp_idx, (exp, datos) in enumerate(results_2capas.items()):
    epochs = range(len(datos["valid_loss"]))

    # Color principal (para VALID y para la línea)
    color_valid = f"C{exp_idx}"

    # Guardar el color de Exp3
    if exp == "Exp3":
        color_exp3 = color_valid

    train = datos["train_loss"]
    valid = datos["valid_loss"]

    # ----------------------------
    #       Curvas
    # ----------------------------
    # VALID = línea sólida (color principal)
    plt.plot(
        epochs, valid,
        label=f'{exp_labels_2capas.get(exp, exp)} Valid',
        linestyle="-",
        color=color_valid
    )

    # TRAIN = línea punteada con alpha más bajo
    plt.plot(
        epochs, train,
        label=f'{exp_labels_2capas.get(exp, exp)} Train',
        linestyle=":",
        color=color_valid,
        alpha=0.40        # ← más translúcido
    )

# ----------------------------
#   LÍNEAS SOLO PARA EXPERIMENTO 3
#   (mismo color que la curva de Exp3, más marcado)
# ----------------------------
if "Exp3" in results_2capas and color_exp3 is not None:
    datos_exp3 = results_2capas["Exp3"]
    train_exp3 = datos_exp3["train_loss"]
    valid_exp3 = datos_exp3["valid_loss"]

    # Épocas donde dibujar líneas verticales
    extra_lines = [37, 60, 82, 97]

    for x_pos in extra_lines:
        if x_pos < len(train_exp3):
            train_y = train_exp3[x_pos]
            valid_y = valid_exp3[x_pos]

            plt.plot(
                [x_pos, x_pos],
                [train_y, valid_y],
                color=color_exp3,   # mismo color que la curva de Exp3
                linewidth=2.5,
                alpha=0.9
            )

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Autoencoder + Clasificadora (2 capas)\nLínea Train–Valid por experimento")
plt.legend()
plt.tight_layout()
plt.savefig("results/2capas/experimentos_loss_2capas_gap_correcto.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# ----------------------------
#       GRÁFICO ACCURACY BLOQUE 2 CAPAS
# ----------------------------
plt.figure(figsize=(8,5))
for exp in results_2capas:
    plt.plot(epoch, results_2capas[exp]["valid_precision"],
             label=f'{exp_labels_2capas[exp]} Valid', linestyle="-")
    plt.plot(epoch, results_2capas[exp]["train_precision"],
             label=f'{exp_labels_2capas[exp]} Train', linestyle=":")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Autoencoder + Clasificadora (2 capas)")
plt.legend()
plt.tight_layout()
plt.savefig("results/2capas/experimentos_accuracy_2capas.png")
plt.show()
