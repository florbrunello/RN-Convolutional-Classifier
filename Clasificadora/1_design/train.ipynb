# %% [markdown]
# # Aprendiendo Fashion-MNIST con PyTorch
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# Requirement already satisfied: torch in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (2.9.1)
# Requirement already satisfied: torchvision in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (0.24.1)
# Requirement already satisfied: torchaudio in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (2.9.1)
# Requirement already satisfied: torchviz in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (0.0.3)
# Requirement already satisfied: filelock in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.5.1)
# Requirement already satisfied: numpy in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: graphviz in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torchviz) (0.21)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torch) (3.5.1)
# Requirement already satisfied: numpy in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: graphviz in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from torchviz) (0.21)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/usuario/Documentos/RedesNeuronales/TPFinal/.venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme (i.e. normalize los valores de los pixeles) los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Explore algunos ejemplos de estos conjuntos. Que formato poseen?
#
# **3)** Visitando la página web de FashionMNIST, cree un diccionario de Python `Dict()` asociando cada categoría a un nombre adecuado de la misma.
#
# **4)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([
                                transforms.ToTensor()
                                ,transforms.Normalize((0.5,), (0.5,))
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
len(train_set),len(valid_set)
# Out:
# (60000, 10000)

# %%
i = np.random.randint(len(train_set))
print(f"i={i}")
image,label = train_set[i]
label
image.shape
# Out:
# i=11682
# torch.Size([1, 28, 28])

# %%
image.numpy().squeeze().shape
# Out:
# (28, 28)

# %%
plt.imshow(image.numpy().squeeze(),cmap='Greys_r')

# %%
# 2.3)
label_names = {
    0: "T-shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot"
}

# %%
# 2.4)
figure = plt.figure()
cols, rows = 3,3
for i in range(1, cols*rows+1):
  j = torch.randint(len(train_set), size=(1,)).item()
  image, label = train_set[j]
  figure.add_subplot(rows, cols, i)
  plt.title(label_names[label])
  plt.axis("off")
  plt.imshow(image.numpy().squeeze(), cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3)
#
# Creando un `DataLoader` para alimentar el modelo con batchs (lotes) de entrenamiento.
#
# **1)** Cree los `DataLoader`s para cada conjunto. Defínalos con un `batch_size` de 100 y con el flag `shuffle` seteado a `True`.
#
# **2)** Use uno de los `DataLoader`s creados anteriormente para explorar algunos elementos del conjunto.
#
# Notar que, el iterador devuelve el batch en un par `(image,label)`.
#
# El objeto `images` es un tensor de dimensiones `(100,1,28,28)`.
# El 100 es el tamaño del batch.
# El 1 porque hay un solo canal (en este caso, un canal de escala de grises, pero podría haber varios, p. ej. uno por cada color de {Red, Green Blue} en caso que fuesen imagenes a color).
# Luego, 28 y 28 porque cada imagen del dataset es de 28 x 28 píxeles.
#
# El objeto `labels` es un tensor de dimensiones `(100,)`.
# La $i$-ésima entrada `labels[i]` de `labels` es un número en $\{0,1,...,9\}$ indicando la categoría a la que pertenece la $i$-ésima imagen en el batch, guardada en `images[i]`.

# %%
# 3.1)
train_loader = torch.utils.data.DataLoader(train_set, batch_size = 100, shuffle = True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size = 100, shuffle = True)

# %%
# Cargar únicamente los pesos del Autoencoder preentrenado
import torch
from torch import nn
# Debes tener la misma definición de Autoencoder que se usó al entrenar
from autoencoder import Autoencoder  # o copia la clase Autoencoder a tu notebook

checkpoint_path = "/home/usuario/Documentos/RedesNeuronales/TPFinal/Clasificadora/1_design/autoencoder_fashionmnist.pt"
checkpoint = torch.load(checkpoint_path, map_location="cpu")

# Fijamos manualmente el hiperparámetro de dropout (por ejemplo 0.15)
dropout_autoencoder = 0.15
autoencoder = Autoencoder(dropout=dropout_autoencoder)
autoencoder.load_state_dict(checkpoint["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Ejercicio 4)
#
# Defina una red neuronal de 4 capas, una de entrada, dos ocultas de $n_1=128$ y $n_2=64$ neuronas, respectivamente, y una de salida de 10 neuronas.
#
# En las capas intermedias utilice neuronas tipo ReLU y agregueles un *dropout* de p=0.2.
# En la capa de salida no utilice funciones de activación ni dropout.
#
# Las capas sucesivas tienen que estar totalmente conectadas entre si.

# %%
class Clasificadora(nn.Module):
    def __init__(self, p, n1, n2, encoder=None):
        super().__init__()
        self._dropout = p
        self.encoder = encoder

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=64*7*7, out_features=n1),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(in_features=n1, out_features=n2),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Linear(in_features=n2, out_features=10)
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## Ejercicio 5)
#
# Entrenamos el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` a partir del `train_set` (conjunto de entranmiento) y del `valid_set` (conjunto de validación) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando la **Cross Entropy Loss**.
#
# **IMPORTANTE:** Notar que la **Cross Entropy Loss** aplica automáticamente una `log_softmax`.
#
# **5)** Cree un optimizador que utilice el método de **Stochastic Gradient Descent** con un learning rate igual a $10^{-3}$.
#
# **6)** Cree una instancia del modelo.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop de entrenamiento y validación que trabaje con el `train_loader` y el `valid_loader`, respectivamente, usando un numero arbitrario de épocas.
# Este loop debe guardar en cuatro listas los valores de los promedios del **Cross Entropy Loss** y las fracciones de clasificaciones correctas o **precisión** (accuracy) sobre el conjunto de **entrenamiento** y el de **validación**, respectivamente.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso anterior para graficar en función de las épocas la **Cross Entropy Loss** de **entrenamiento** y de **validación**.
# Realize un gráfico análogo pero con la **precisión**.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Repita los experimentos variando hiperparámetros. Por ejemplo:
#
# - El learning-rate.
# - El optimizador (ej. puede usar ADAM).
# - El valor de dropout.
# - El número de neuronas en las capas intermedias.
# - El número de épocas de entrenamiento.
# - El tamaño de los lotes.
#
# Discuta los resultados.

# %%
# 5.1)
# Definimos la función de entrenamiento
def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    for batch, (X, y) in enumerate(dataloader):
        X = X.to(device)
        y = y.to(device)
        batch_size = len(X)
        sum_samples += batch_size
        pred = model(X)
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sum_loss += loss.item()*batch_size
        sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
        if batch % (nun_batches/10) == 0:
            avrg_loss = sum_loss/sum_samples
            precision = sum_correct/sum_samples
            print(f"@train_loop batch={batch:>5d} avrg_loss={avrg_loss:>7f} processed samples={100*sum_samples/num_samples:>5.1f}%")
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    return avrg_loss, precision

# %%
# 5.2)
# Definimos la función de validación
def eval_loop(dataloader, model, loss_fn):
    model.eval()
    num_samples = len(dataloader.dataset)
    nun_batches = len(dataloader)
    sum_loss = 0
    sum_correct = 0
    sum_samples = 0

    with torch.no_grad():
        for X,y in dataloader:
          X = X.to(device)
          y = y.to(device)
          batch_size = len(X)
          sum_samples += batch_size
          pred = model(X)
          loss = loss_fn(pred,y)
          sum_loss += loss.item()*batch_size
          sum_correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    assert num_samples == sum_samples
    avrg_loss = sum_loss/sum_samples
    precision = sum_correct/sum_samples
    print(f"@eval_loop avg_loss={avrg_loss:>8f} precision={100*precision:>0.1f}%")
    return avrg_loss, precision

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True)

num_train_batches = len(train_loader)
num_valid_batches = len(valid_loader)
print(f'num_train_batches={num_train_batches}')
print(f'num_valid_batches={num_valid_batches}')
# Out:
# num_train_batches=600
# num_valid_batches=100

# %%
# 5.4)
loss_fn = nn.CrossEntropyLoss()

# %%
# 5.5)
# Ejemplo: pasar encoder a tu modelo Clasificadora con dropout fijo en la clasificadora
# p_dropout_clf = 0.2
# clasificador = Clasificadora(p=p_dropout_clf, n1=128, n2=64, encoder=autoencoder.encoder)

# %%
# 5.6)
#learning_rate = 1e-3
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.Adam(clasificador.classifier.parameters(), lr=learning_rate, eps=1e-08, weight_decay= 0, amsgrad= False)

# %%
# 5.7)
#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#clasificador = clasificador.to(device)

# %%
experimentos = {
    "Exp 1":  {"n1": 64,  "n2": 32},
    "Exp 2": {"n1": 128, "n2": 64},
    "Exp 3": {"n1": 512, "n2": 256}
}

p_dropout_clf = 0.2
learning_rate = 1e-3
num_epochs = 50

results = {}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# -------------------------
#   LOOP DE EXPERIMENTOS
# -------------------------
for nombre_exp, params in experimentos.items():
    print(f"\n============================")
    print(f"      EJECUTANDO {nombre_exp}")
    print(f"============================")

    # Crear clasificador con los n1, n2 correspondientes
    clasificador = Clasificadora(
        p=p_dropout_clf,
        n1=params["n1"],
        n2=params["n2"],
        encoder=autoencoder.encoder
    ).to(device)

    optimizer = torch.optim.Adam(
        clasificador.classifier.parameters(),
        lr=learning_rate,
        eps=1e-08,
        weight_decay=0,
        amsgrad=False
    )


    # Listas para métricas con tus nombres
    list_avg_train_loss_incorrecta = []
    list_avg_train_loss = []
    list_avg_valid_loss = []
    list_train_precision_incorrecta = []
    list_train_precision = []
    list_valid_precision = []

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}\n-------------------------------')

        # (1) TRAIN LOOP — actualiza pesos
        train_avg_loss_incorrecta, train_precision_incorrecta = train_loop(
            train_loader, clasificador, loss_fn, optimizer
        )

        # (2) EVAL LOOP — evalúa en train (sin actualizar)
        train_avg_loss, train_precision = eval_loop(
            train_loader, clasificador, loss_fn
        )

        # (3) VALID LOOP — evalúa en validación
        valid_avg_loss, valid_precision = eval_loop(
            valid_loader, clasificador, loss_fn
        )

        # Guardar métricas
        list_avg_train_loss_incorrecta.append(train_avg_loss_incorrecta)
        list_avg_train_loss.append(train_avg_loss)
        list_avg_valid_loss.append(valid_avg_loss)
        list_train_precision_incorrecta.append(train_precision_incorrecta)
        list_train_precision.append(train_precision)
        list_valid_precision.append(valid_precision)
        
    print(f"✔ Finalizado {nombre_exp}")

    # Guardar resultados del experimento
    results[nombre_exp] = {
        "train_loss": list_avg_train_loss,
        "valid_loss": list_avg_valid_loss,
        "train_precision": list_train_precision,
        "valid_precision": list_valid_precision
    }

print("\n============================")
print(" TODOS LOS EXPERIMENTOS FINALIZADOS ")
print("============================")
# Out:
# ============================
#       EJECUTANDO Exp 1
# ============================
# Epoch 1
# -------------------------------
# @train_loop batch=    0 avrg_loss=2.296616 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=1.459743 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=1.459743 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=1.176914 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=1.176914 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=1.037498 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=1.037498 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.953758 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.953758 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.891467 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.891467 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.843249 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.843249 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.807488 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.807488 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.778371 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.778371 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.755115 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.755115 processed samples= 90.2%
# @eval_loop avg_loss=0.410543 precision=85.0%
# @eval_loop avg_loss=0.410543 precision=85.0%
# @eval_loop avg_loss=0.438242 precision=83.9%
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.705623 processed samples=  0.2%
# @eval_loop avg_loss=0.438242 precision=83.9%
# Epoch 2
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.705623 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.544512 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.544512 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.532372 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.532372 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.528113 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.528113 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.529479 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.529479 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.525779 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.525779 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.518197 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.518197 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.515266 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.515266 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.511312 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.511312 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.508819 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.508819 processed samples= 90.2%
# @eval_loop avg_loss=0.362969 precision=87.0%
# @eval_loop avg_loss=0.362969 precision=87.0%
# @eval_loop avg_loss=0.401102 precision=85.4%
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.367302 processed samples=  0.2%
# @eval_loop avg_loss=0.401102 precision=85.4%
# Epoch 3
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.367302 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.473045 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.473045 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.464707 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.464707 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.463145 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.463145 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.467235 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.467235 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.465655 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.465655 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.461167 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.461167 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.458632 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.458632 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.458054 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.458054 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.455087 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.455087 processed samples= 90.2%
# @eval_loop avg_loss=0.339514 precision=87.8%
# @eval_loop avg_loss=0.339514 precision=87.8%
# @eval_loop avg_loss=0.381608 precision=86.2%
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.548302 processed samples=  0.2%
# @eval_loop avg_loss=0.381608 precision=86.2%
# Epoch 4
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.548302 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.423176 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.423176 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.426547 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.426547 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.419782 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.419782 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.427940 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.427940 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.427190 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.427190 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.425963 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.425963 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.428442 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.428442 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.428129 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.428129 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.429198 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.429198 processed samples= 90.2%
# @eval_loop avg_loss=0.321750 precision=88.3%
# @eval_loop avg_loss=0.321750 precision=88.3%
# @eval_loop avg_loss=0.364918 precision=86.6%
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.344270 processed samples=  0.2%
# @eval_loop avg_loss=0.364918 precision=86.6%
# Epoch 5
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.344270 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.431267 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.431267 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.425557 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.425557 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.418144 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.418144 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.419208 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.419208 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.414057 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.414057 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.411233 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.411233 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.409235 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.409235 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.410890 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.410890 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.410811 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.410811 processed samples= 90.2%
# @eval_loop avg_loss=0.301770 precision=89.0%
# @eval_loop avg_loss=0.301770 precision=89.0%
# @eval_loop avg_loss=0.349202 precision=87.6%
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.455678 processed samples=  0.2%
# @eval_loop avg_loss=0.349202 precision=87.6%
# Epoch 6
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.455678 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.388064 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.388064 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.390795 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.390795 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.396036 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.396036 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.399084 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.399084 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.396383 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.396383 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.398588 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.398588 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.396272 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.396272 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.396151 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.396151 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.398114 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.398114 processed samples= 90.2%
# @eval_loop avg_loss=0.301591 precision=88.9%
# @eval_loop avg_loss=0.301591 precision=88.9%
# @eval_loop avg_loss=0.360481 precision=87.0%
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.309634 processed samples=  0.2%
# @eval_loop avg_loss=0.360481 precision=87.0%
# Epoch 7
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.309634 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.370241 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.370241 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.370457 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.370457 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.378557 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.378557 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.384843 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.384843 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.383633 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.383633 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.383186 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.383186 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.384378 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.384378 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.387776 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.387776 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.391296 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.391296 processed samples= 90.2%
# @eval_loop avg_loss=0.295424 precision=89.3%
# @eval_loop avg_loss=0.295424 precision=89.3%
# @eval_loop avg_loss=0.345149 precision=87.9%
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.308540 processed samples=  0.2%
# @eval_loop avg_loss=0.345149 precision=87.9%
# Epoch 8
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.308540 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.367568 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.367568 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.370571 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.370571 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.375694 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.375694 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.376453 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.376453 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.379516 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.379516 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.379143 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.379143 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.378204 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.378204 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.378143 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.378143 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.379653 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.379653 processed samples= 90.2%
# @eval_loop avg_loss=0.309049 precision=88.7%
# @eval_loop avg_loss=0.309049 precision=88.7%
# @eval_loop avg_loss=0.369920 precision=86.9%
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.489635 processed samples=  0.2%
# @eval_loop avg_loss=0.369920 precision=86.9%
# Epoch 9
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.489635 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.348447 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.348447 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.357150 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.357150 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.363190 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.363190 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.364087 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.364087 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.366785 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.366785 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.369411 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.369411 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.368891 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.368891 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.369292 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.369292 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.368773 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.368773 processed samples= 90.2%
# @eval_loop avg_loss=0.268540 precision=90.0%
# @eval_loop avg_loss=0.268540 precision=90.0%
# @eval_loop avg_loss=0.329646 precision=87.9%
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.353308 processed samples=  0.2%
# @eval_loop avg_loss=0.329646 precision=87.9%
# Epoch 10
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.353308 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.370274 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.370274 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.365806 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.365806 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.367412 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.367412 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.367938 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.367938 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.367078 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.367078 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.367633 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.367633 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.369794 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.369794 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.371205 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.371205 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.371372 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.371372 processed samples= 90.2%
# @eval_loop avg_loss=0.265647 precision=90.3%
# @eval_loop avg_loss=0.265647 precision=90.3%
# @eval_loop avg_loss=0.328652 precision=88.4%
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.265371 processed samples=  0.2%
# @eval_loop avg_loss=0.328652 precision=88.4%
# Epoch 11
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.265371 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.351979 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.351979 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.351957 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.351957 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.353228 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.353228 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.355245 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.355245 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.357484 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.357484 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.356631 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.356631 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.356795 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.356795 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.359653 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.359653 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.358717 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.358717 processed samples= 90.2%
# @eval_loop avg_loss=0.280842 precision=89.7%
# @eval_loop avg_loss=0.280842 precision=89.7%
# @eval_loop avg_loss=0.340758 precision=87.8%
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.260427 processed samples=  0.2%
# @eval_loop avg_loss=0.340758 precision=87.8%
# Epoch 12
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.260427 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.355460 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.355460 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.349332 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.349332 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.353770 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.353770 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.353591 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.353591 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.356533 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.356533 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.355292 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.355292 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.356064 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.356064 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.355972 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.355972 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.356033 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.356033 processed samples= 90.2%
# @eval_loop avg_loss=0.272631 precision=89.7%
# @eval_loop avg_loss=0.272631 precision=89.7%
# @eval_loop avg_loss=0.336955 precision=87.7%
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.375206 processed samples=  0.2%
# @eval_loop avg_loss=0.336955 precision=87.7%
# Epoch 13
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.375206 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.345720 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.345720 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.349048 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.349048 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.349155 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.349155 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.345944 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.345944 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.342449 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.342449 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.344392 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.344392 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.344161 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.344161 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.345415 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.345415 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.345769 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.345769 processed samples= 90.2%
# @eval_loop avg_loss=0.260438 precision=90.5%
# @eval_loop avg_loss=0.260438 precision=90.5%
# @eval_loop avg_loss=0.337457 precision=87.9%
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.151290 processed samples=  0.2%
# @eval_loop avg_loss=0.337457 precision=87.9%
# Epoch 14
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.151290 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.337435 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.337435 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.340861 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.340861 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.341336 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.341336 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.340958 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.340958 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.340373 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.340373 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.343351 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.343351 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.342322 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.342322 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.344521 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.344521 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.345988 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.345988 processed samples= 90.2%
# @eval_loop avg_loss=0.242586 precision=91.0%
# @eval_loop avg_loss=0.242586 precision=91.0%
# @eval_loop avg_loss=0.315333 precision=89.1%
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.292689 processed samples=  0.2%
# @eval_loop avg_loss=0.315333 precision=89.1%
# Epoch 15
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.292689 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.328026 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.328026 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.337082 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.337082 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.334309 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.334309 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.338880 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.338880 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.339689 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.339689 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.339186 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.339186 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.338465 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.338465 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.339252 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.339252 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.340812 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.340812 processed samples= 90.2%
# @eval_loop avg_loss=0.249684 precision=90.6%
# @eval_loop avg_loss=0.249684 precision=90.6%
# @eval_loop avg_loss=0.320091 precision=88.7%
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.315458 processed samples=  0.2%
# @eval_loop avg_loss=0.320091 precision=88.7%
# Epoch 16
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.315458 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.353628 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.353628 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.322049 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.322049 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.323285 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.323285 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.323963 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.323963 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.326224 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.326224 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.329585 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.329585 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.335019 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.335019 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.335011 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.335011 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.334567 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.334567 processed samples= 90.2%
# @eval_loop avg_loss=0.251633 precision=90.7%
# @eval_loop avg_loss=0.251633 precision=90.7%
# @eval_loop avg_loss=0.323273 precision=88.4%
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.277906 processed samples=  0.2%
# @eval_loop avg_loss=0.323273 precision=88.4%
# Epoch 17
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.277906 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.311458 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.311458 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.328544 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.328544 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.329990 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.329990 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.328081 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.328081 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.328710 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.328710 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.334316 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.334316 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.336019 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.336019 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.335475 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.335475 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.337791 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.337791 processed samples= 90.2%
# @eval_loop avg_loss=0.238685 precision=91.2%
# @eval_loop avg_loss=0.238685 precision=91.2%
# @eval_loop avg_loss=0.317644 precision=89.0%
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.259987 processed samples=  0.2%
# @eval_loop avg_loss=0.317644 precision=89.0%
# Epoch 18
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.259987 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.329448 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.329448 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.320490 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.320490 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.321089 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.321089 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.320911 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.320911 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.321786 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.321786 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.324868 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.324868 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.324412 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.324412 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.323308 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.323308 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.325012 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.325012 processed samples= 90.2%
# @eval_loop avg_loss=0.254411 precision=90.6%
# @eval_loop avg_loss=0.254411 precision=90.6%
# @eval_loop avg_loss=0.323774 precision=88.5%
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.281662 processed samples=  0.2%
# @eval_loop avg_loss=0.323774 precision=88.5%
# Epoch 19
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.281662 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.334026 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.334026 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.324058 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.324058 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.324420 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.324420 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.321657 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.321657 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.322595 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.322595 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.322789 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.322789 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.325137 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.325137 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.322879 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.322879 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.325369 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.325369 processed samples= 90.2%
# @eval_loop avg_loss=0.231569 precision=91.4%
# @eval_loop avg_loss=0.231569 precision=91.4%
# @eval_loop avg_loss=0.312068 precision=89.0%
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.271666 processed samples=  0.2%
# @eval_loop avg_loss=0.312068 precision=89.0%
# Epoch 20
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.271666 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.315405 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.315405 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.317069 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.317069 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.310678 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.310678 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.313342 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.313342 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.315302 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.315302 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.315580 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.315580 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.319924 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.319924 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.321829 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.321829 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.321150 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.321150 processed samples= 90.2%
# @eval_loop avg_loss=0.239765 precision=91.1%
# @eval_loop avg_loss=0.239765 precision=91.1%
# @eval_loop avg_loss=0.315017 precision=88.9%
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.417922 processed samples=  0.2%
# @eval_loop avg_loss=0.315017 precision=88.9%
# Epoch 21
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.417922 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.327515 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.327515 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.332534 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.332534 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.331228 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.331228 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.327281 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.327281 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.325565 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.325565 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.324025 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.324025 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.325040 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.325040 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.328016 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.328016 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.327699 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.327699 processed samples= 90.2%
# @eval_loop avg_loss=0.236831 precision=91.5%
# @eval_loop avg_loss=0.236831 precision=91.5%
# @eval_loop avg_loss=0.310082 precision=88.9%
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.303087 processed samples=  0.2%
# @eval_loop avg_loss=0.310082 precision=88.9%
# Epoch 22
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.303087 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.295365 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.295365 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.315568 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.315568 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.318282 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.318282 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.318999 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.318999 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.317445 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.317445 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.318850 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.318850 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.320375 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.320375 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.321703 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.321703 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.322398 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.322398 processed samples= 90.2%
# @eval_loop avg_loss=0.230525 precision=91.4%
# @eval_loop avg_loss=0.230525 precision=91.4%
# @eval_loop avg_loss=0.311231 precision=88.8%
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.315110 processed samples=  0.2%
# @eval_loop avg_loss=0.311231 precision=88.8%
# Epoch 23
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.315110 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.319146 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.319146 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.320857 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.320857 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.323243 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.323243 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.316606 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.316606 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.316584 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.316584 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.318694 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.318694 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.318308 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.318308 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.320267 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.320267 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.319654 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.319654 processed samples= 90.2%
# @eval_loop avg_loss=0.223191 precision=91.7%
# @eval_loop avg_loss=0.223191 precision=91.7%
# @eval_loop avg_loss=0.307503 precision=89.3%
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.089416 processed samples=  0.2%
# @eval_loop avg_loss=0.307503 precision=89.3%
# Epoch 24
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.089416 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.286108 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.286108 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.301067 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.301067 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.301776 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.301776 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.305343 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.305343 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.308942 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.308942 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.309262 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.309262 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.313247 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.313247 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.315757 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.315757 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.318123 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.318123 processed samples= 90.2%
# @eval_loop avg_loss=0.225959 precision=91.7%
# @eval_loop avg_loss=0.225959 precision=91.7%
# @eval_loop avg_loss=0.308614 precision=89.1%
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.353850 processed samples=  0.2%
# @eval_loop avg_loss=0.308614 precision=89.1%
# Epoch 25
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.353850 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.302140 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.302140 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.303818 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.303818 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.317076 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.317076 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.312989 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.312989 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.309866 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.309866 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.311276 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.311276 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.312202 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.312202 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.309738 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.309738 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.308486 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.308486 processed samples= 90.2%
# @eval_loop avg_loss=0.227860 precision=91.5%
# @eval_loop avg_loss=0.227860 precision=91.5%
# @eval_loop avg_loss=0.319226 precision=88.8%
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.370525 processed samples=  0.2%
# @eval_loop avg_loss=0.319226 precision=88.8%
# Epoch 26
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.370525 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.296690 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.296690 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.302514 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.302514 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.305496 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.305496 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.305706 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.305706 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.310114 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.310114 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.309876 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.309876 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.308704 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.308704 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.311019 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.311019 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.311054 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.311054 processed samples= 90.2%
# @eval_loop avg_loss=0.223127 precision=91.6%
# @eval_loop avg_loss=0.223127 precision=91.6%
# @eval_loop avg_loss=0.311641 precision=89.1%
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.281889 processed samples=  0.2%
# @eval_loop avg_loss=0.311641 precision=89.1%
# Epoch 27
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.281889 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.304504 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.304504 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.304530 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.304530 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.307608 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.307608 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.306718 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.306718 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.307325 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.307325 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.308000 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.308000 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.309079 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.309079 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.308731 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.308731 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.308597 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.308597 processed samples= 90.2%
# @eval_loop avg_loss=0.218238 precision=91.8%
# @eval_loop avg_loss=0.218238 precision=91.8%
# @eval_loop avg_loss=0.306534 precision=89.0%
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.482359 processed samples=  0.2%
# @eval_loop avg_loss=0.306534 precision=89.0%
# Epoch 28
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.482359 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.294073 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.294073 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.299383 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.299383 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.304852 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.304852 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.310438 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.310438 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.311380 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.311380 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.312072 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.312072 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.311015 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.311015 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.310207 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.310207 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.309128 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.309128 processed samples= 90.2%
# @eval_loop avg_loss=0.216033 precision=91.9%
# @eval_loop avg_loss=0.216033 precision=91.9%
# @eval_loop avg_loss=0.306525 precision=89.3%
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.292399 processed samples=  0.2%
# @eval_loop avg_loss=0.306525 precision=89.3%
# Epoch 29
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.292399 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.307917 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.307917 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.308248 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.308248 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.307557 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.307557 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.301044 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.301044 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.299546 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.299546 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.300243 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.300243 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.302944 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.302944 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.303446 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.303446 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.302467 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.302467 processed samples= 90.2%
# @eval_loop avg_loss=0.241291 precision=91.0%
# @eval_loop avg_loss=0.241291 precision=91.0%
# @eval_loop avg_loss=0.320799 precision=88.3%
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.194469 processed samples=  0.2%
# @eval_loop avg_loss=0.320799 precision=88.3%
# Epoch 30
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.194469 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.306686 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.306686 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.306193 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.306193 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.307236 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.307236 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.304919 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.304919 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.303277 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.303277 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.301629 processed samples= 60.2%
# ...
# @train_loop batch=  180 avrg_loss=0.224490 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.224490 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.222973 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.222973 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.221744 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.221744 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.221302 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.221302 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.221366 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.221366 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.219473 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.219473 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.220451 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.220451 processed samples= 90.2%
# @eval_loop avg_loss=0.162889 precision=93.8%
# @eval_loop avg_loss=0.162889 precision=93.8%
# @eval_loop avg_loss=0.302368 precision=90.0%
# Epoch 42
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.204731 processed samples=  0.2%
# @eval_loop avg_loss=0.302368 precision=90.0%
# Epoch 42
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.204731 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.236868 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.236868 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.219485 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.219485 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.219362 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.219362 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.216598 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.216598 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.217535 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.217535 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.215389 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.215389 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.213960 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.213960 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.217707 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.217707 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.218402 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.218402 processed samples= 90.2%
# @eval_loop avg_loss=0.161506 precision=94.0%
# @eval_loop avg_loss=0.161506 precision=94.0%
# @eval_loop avg_loss=0.290497 precision=89.6%
# Epoch 43
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.161153 processed samples=  0.2%
# @eval_loop avg_loss=0.290497 precision=89.6%
# Epoch 43
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.161153 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.213658 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.213658 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.217703 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.217703 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.218549 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.218549 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.218188 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.218188 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.218111 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.218111 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.218918 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.218918 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.220852 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.220852 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.219404 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.219404 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.218048 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.218048 processed samples= 90.2%
# @eval_loop avg_loss=0.159462 precision=93.9%
# @eval_loop avg_loss=0.159462 precision=93.9%
# @eval_loop avg_loss=0.303786 precision=89.6%
# Epoch 44
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.365503 processed samples=  0.2%
# @eval_loop avg_loss=0.303786 precision=89.6%
# Epoch 44
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.365503 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.218943 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.218943 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.210588 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.210588 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.211447 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.211447 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.211991 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.211991 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.210741 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.210741 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.210552 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.210552 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.210029 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.210029 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.211002 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.211002 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.210497 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.210497 processed samples= 90.2%
# @eval_loop avg_loss=0.154156 precision=94.1%
# @eval_loop avg_loss=0.154156 precision=94.1%
# @eval_loop avg_loss=0.295612 precision=90.1%
# Epoch 45
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.150466 processed samples=  0.2%
# @eval_loop avg_loss=0.295612 precision=90.1%
# Epoch 45
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.150466 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.216973 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.216973 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.211992 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.211992 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.214689 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.214689 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.216195 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.216195 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.217065 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.217065 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.218894 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.218894 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.220021 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.220021 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.219045 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.219045 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.219791 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.219791 processed samples= 90.2%
# @eval_loop avg_loss=0.162930 precision=93.9%
# @eval_loop avg_loss=0.162930 precision=93.9%
# @eval_loop avg_loss=0.308335 precision=89.5%
# Epoch 46
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.144085 processed samples=  0.2%
# @eval_loop avg_loss=0.308335 precision=89.5%
# Epoch 46
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.144085 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.211530 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.211530 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.202949 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.202949 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.203121 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.203121 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.203960 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.203960 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.206248 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.206248 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.206455 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.206455 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.207911 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.207911 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.209652 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.209652 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.208941 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.208941 processed samples= 90.2%
# @eval_loop avg_loss=0.147289 precision=94.4%
# @eval_loop avg_loss=0.147289 precision=94.4%
# @eval_loop avg_loss=0.308877 precision=90.0%
# Epoch 47
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.159543 processed samples=  0.2%
# @eval_loop avg_loss=0.308877 precision=90.0%
# Epoch 47
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.159543 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.212632 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.212632 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.202775 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.202775 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.202475 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.202475 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.203119 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.203119 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.205390 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.205390 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.206728 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.206728 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.208187 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.208187 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.208758 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.208758 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.209906 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.209906 processed samples= 90.2%
# @eval_loop avg_loss=0.141147 precision=94.5%
# @eval_loop avg_loss=0.141147 precision=94.5%
# @eval_loop avg_loss=0.294889 precision=90.2%
# Epoch 48
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.142428 processed samples=  0.2%
# @eval_loop avg_loss=0.294889 precision=90.2%
# Epoch 48
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.142428 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.202225 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.202225 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.194773 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.194773 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.199671 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.199671 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.202732 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.202732 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.206288 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.206288 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.207332 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.207332 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.207877 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.207877 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.207399 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.207399 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.207812 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.207812 processed samples= 90.2%
# @eval_loop avg_loss=0.153067 precision=94.1%
# @eval_loop avg_loss=0.153067 precision=94.1%
# @eval_loop avg_loss=0.305190 precision=90.0%
# Epoch 49
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.194903 processed samples=  0.2%
# @eval_loop avg_loss=0.305190 precision=90.0%
# Epoch 49
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.194903 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.208092 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.208092 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.196168 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.196168 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.193576 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.193576 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.195842 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.195842 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.201291 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.201291 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.200950 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.200950 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.202737 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.202737 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.206265 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.206265 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.207449 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.207449 processed samples= 90.2%
# @eval_loop avg_loss=0.136674 precision=94.9%
# @eval_loop avg_loss=0.136674 precision=94.9%
# @eval_loop avg_loss=0.286055 precision=90.4%
# Epoch 50
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.129964 processed samples=  0.2%
# @eval_loop avg_loss=0.286055 precision=90.4%
# Epoch 50
# -------------------------------
# @train_loop batch=    0 avrg_loss=0.129964 processed samples=  0.2%
# @train_loop batch=   60 avrg_loss=0.198174 processed samples= 10.2%
# @train_loop batch=   60 avrg_loss=0.198174 processed samples= 10.2%
# @train_loop batch=  120 avrg_loss=0.205291 processed samples= 20.2%
# @train_loop batch=  120 avrg_loss=0.205291 processed samples= 20.2%
# @train_loop batch=  180 avrg_loss=0.201101 processed samples= 30.2%
# @train_loop batch=  180 avrg_loss=0.201101 processed samples= 30.2%
# @train_loop batch=  240 avrg_loss=0.200824 processed samples= 40.2%
# @train_loop batch=  240 avrg_loss=0.200824 processed samples= 40.2%
# @train_loop batch=  300 avrg_loss=0.202154 processed samples= 50.2%
# @train_loop batch=  300 avrg_loss=0.202154 processed samples= 50.2%
# @train_loop batch=  360 avrg_loss=0.203036 processed samples= 60.2%
# @train_loop batch=  360 avrg_loss=0.203036 processed samples= 60.2%
# @train_loop batch=  420 avrg_loss=0.202424 processed samples= 70.2%
# @train_loop batch=  420 avrg_loss=0.202424 processed samples= 70.2%
# @train_loop batch=  480 avrg_loss=0.203122 processed samples= 80.2%
# @train_loop batch=  480 avrg_loss=0.203122 processed samples= 80.2%
# @train_loop batch=  540 avrg_loss=0.206740 processed samples= 90.2%
# @train_loop batch=  540 avrg_loss=0.206740 processed samples= 90.2%
# @eval_loop avg_loss=0.146548 precision=94.5%
# @eval_loop avg_loss=0.146548 precision=94.5%
# @eval_loop avg_loss=0.290265 precision=90.1%
# ✔ Finalizado Exp 3
#
# ============================
#  TODOS LOS EXPERIMENTOS FINALIZADOS
# ============================
# @eval_loop avg_loss=0.290265 precision=90.1%
# ✔ Finalizado Exp 3
#
# ============================
#  TODOS LOS EXPERIMENTOS FINALIZADOS
# ============================

# %%
print("\n============================")
print("   RESULTADOS FINALES")
print("============================")

final_results = {}

for exp in results:
    train_loss_final = results[exp]["train_loss"][-1]
    valid_loss_final = results[exp]["valid_loss"][-1]
    train_prec_final = results[exp]["train_precision"][-1]
    valid_prec_final = results[exp]["valid_precision"][-1]

    final_results[exp] = valid_prec_final

    print(f"\n--- {exp} ---")
    print(f"Train Loss final:       {train_loss_final:.4f}")
    print(f"Valid Loss final:       {valid_loss_final:.4f}")
    print(f"Train Precision final:  {train_prec_final:.4f}")
    print(f"Valid Precision final:  {valid_prec_final:.4f}")

# ----------------------------------------------------
#   ELEGIR EL MEJOR EXPERIMENTO (mayor precisión valid)
# ----------------------------------------------------
best_exp = max(final_results, key=final_results.get)
best_precision = final_results[best_exp]

print("\n============================")
print("   MEJOR EXPERIMENTO")
print("============================")
print(f"Ganador: {best_exp}")
print(f"Mejor Valid Precision: {best_precision:.4f}")
# Out:
# ============================
#    RESULTADOS FINALES
# ============================
#
# --- Exp 1 ---
# Train Loss final:       0.1770
# Valid Loss final:       0.2960
# Train Precision final:  0.9326
# Valid Precision final:  0.8976
#
# --- Exp 2 ---
# Train Loss final:       0.1592
# Valid Loss final:       0.2923
# Train Precision final:  0.9387
# Valid Precision final:  0.9009
#
# --- Exp 3 ---
# Train Loss final:       0.1465
# Valid Loss final:       0.2903
# Train Precision final:  0.9447
# Valid Precision final:  0.9006
#
# ============================
#    MEJOR EXPERIMENTO
# ============================
# Ganador: Exp 2
# Mejor Valid Precision: 0.9009

# %%
exp_labels = {
    "Exp 1": "Exp 1 (64-32)",
    "Exp 2": "Exp 2 (128-64)",
    "Exp 3": "Exp 3 (512-256)"
}

epoch = list(range(1, num_epochs + 1))

# ----------------------------
#       GRÁFICO DE LOSS
# ----------------------------
plt.figure(figsize=(8,5))

for exp in results:
    plt.plot(epoch, results[exp]["valid_loss"],
             label=f'{exp_labels[exp]} Valid loss', linestyle="-")
    plt.plot(epoch, results[exp]["train_loss"],
             label=f'{exp_labels[exp]} Train loss', linestyle=":")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.savefig("experimentos_loss.png")
plt.show()

# %%
# ----------------------------
#     GRÁFICO DE ACCURACY
# ----------------------------
plt.figure(figsize=(8,5))

for exp in results:
    plt.plot(epoch, results[exp]["valid_precision"],
             label=f'{exp_labels[exp]} Valid precision', linestyle="-")
    plt.plot(epoch, results[exp]["train_precision"],
             label=f'{exp_labels[exp]} Train precision', linestyle=":")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.savefig("experimentos_accuracy.png")
plt.show()
